# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import pandas as pd
import numpy as np

# %% [markdown]
# ### MOVIE recommendation using MAML

# %%
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

# Load data and prepare genre mapping
def load_data(file_path):
    df = pd.read_csv(file_path)
    
    # Create a unique mapping for genres
    unique_genres = set()
    for genre_list in df['genres'].apply(lambda x: x.split('|')):
        unique_genres.update(genre_list)
    
    genre_to_idx = {genre: idx for idx, genre in enumerate(unique_genres)}
    
    # Map genres to integers and prepare tensors
    user_ids = torch.tensor(df['userId'].values, dtype=torch.long)
    movie_ids = torch.tensor(df['movieId'].values, dtype=torch.long)
    ratings = torch.tensor(df['rating'].values, dtype=torch.float)
    genres = torch.tensor(df['genres'].apply(lambda x: genre_to_idx[x.split('|')[0]]).values, dtype=torch.long)
    
    return user_ids, movie_ids, ratings, genres, genre_to_idx, list(unique_genres)

# Define a custom dataset for the movie recommendation task
class MovieDataset(Dataset):
    def __init__(self, user_ids, movie_ids, ratings, genres):
        self.user_ids = user_ids
        self.movie_ids = movie_ids
        self.ratings = ratings
        self.genres = genres

    def __len__(self):
        return len(self.user_ids)

    def __getitem__(self, idx):
        return self.user_ids[idx], self.movie_ids[idx], self.ratings[idx], self.genres[idx]

# Define the MetaRecModel class
class MetaRecModel(nn.Module):
    def __init__(self, num_users, num_items, embedding_dim, num_genres=None):
        super(MetaRecModel, self).__init__()
        self.user_embedding = nn.Embedding(num_users, embedding_dim)
        self.item_embedding = nn.Embedding(num_items, embedding_dim)
        self.has_genres = num_genres is not None
        
        if self.has_genres:
            self.genre_embedding = nn.Embedding(num_genres, embedding_dim)
            self.fc = nn.Linear(embedding_dim * 3, 1)  # With genre
        else:
            self.fc = nn.Linear(embedding_dim * 2, 1)  # Without genre

    def forward(self, user_id, item_id, genre_ids=None):
        user_embed = self.user_embedding(user_id)
        item_embed = self.item_embedding(item_id)
    
        if self.has_genres and genre_ids is not None:
            genre_embed = self.genre_embedding(genre_ids.unsqueeze(1)).mean(dim=1)
            x = torch.cat([user_embed, item_embed, genre_embed], dim=-1)
        else:
            x = torch.cat([user_embed, item_embed], dim=-1)
        return self.fc(x).squeeze()

# MAML training loop
def maml_train(model, datasets, inner_lr, outer_lr, inner_steps, outer_steps, batch_size, num_genres=None):
    outer_optimizer = optim.Adam(model.parameters(), lr=outer_lr)
    loss_fn = nn.MSELoss()

    for step in range(outer_steps):
        meta_loss = 0
        for domain_data in datasets:
            fast_model = MetaRecModel(model.user_embedding.num_embeddings, model.item_embedding.num_embeddings, model.user_embedding.embedding_dim, num_genres)
            fast_model.load_state_dict(model.state_dict())
            inner_optimizer = optim.SGD(fast_model.parameters(), lr=inner_lr)
            
            dataloader = DataLoader(domain_data, batch_size=batch_size, shuffle=True)
            for user_ids, movie_ids, ratings, genres in dataloader:
                predictions = fast_model(user_ids, movie_ids, genre_ids=genres)
                loss = loss_fn(predictions, ratings)
                
                inner_optimizer.zero_grad()
                loss.backward()
                inner_optimizer.step()

            meta_loss += loss_fn(fast_model(user_ids, movie_ids, genre_ids=genres), ratings)
        
        outer_optimizer.zero_grad()
        meta_loss.backward()
        outer_optimizer.step()

        print(f'Step {step+1}/{outer_steps}, Meta Loss: {meta_loss.item()}')

# Function to generate recommendations based on user-selected genre
def recommend(model, user_id, preferred_genre=None, genre_to_idx=None, num_recommendations=5):
    item_scores = []
    preferred_genre_id = genre_to_idx.get(preferred_genre) if preferred_genre else None

    for item_id in range(model.item_embedding.num_embeddings):
        genre_id = preferred_genre_id if preferred_genre_id is not None else 0
        score = model(torch.tensor([user_id]), torch.tensor([item_id]), genre_ids=torch.tensor([genre_id]))
        item_scores.append((item_id, score.item()))
    
    top_items = sorted(item_scores, key=lambda x: x[1], reverse=True)[:num_recommendations]
    return [item[0] for item in top_items]

# Load the dataset
file_path = "movie.csv"  # Specify the correct path to your dataset
user_ids, movie_ids, ratings, genres, genre_to_idx, unique_genres = load_data(file_path)

# Prompt user for genre preference
print("Available genres:", unique_genres)
preferred_genre = input("Enter your preferred genre from the above list: ")

# Create the dataset and model
dataset = MovieDataset(user_ids, movie_ids, ratings, genres)
num_users = max(user_ids) + 1
num_items = max(movie_ids) + 1
num_genres = max(genres) + 1
embedding_dim = 32
meta_model = MetaRecModel(num_users, num_items, embedding_dim, num_genres=num_genres)

# MAML training
datasets = [dataset]
maml_train(meta_model, datasets, inner_lr=0.01, outer_lr=0.001, inner_steps=1, outer_steps=5, batch_size=16, num_genres=num_genres)

# Generate recommendations for the specified user and genre
user_id = 2
recommendations = recommend(meta_model, user_id=user_id, preferred_genre=preferred_genre, genre_to_idx=genre_to_idx, num_recommendations=5)
print(f"Top recommendations for user in genre '{preferred_genre}':", recommendations)
# Out:
# Available genres: ['Thriller', 'Western', 'Children', 'Musical', 'Adventure', 'Sci-Fi', 'Comedy', 'Horror', 'Romance', 'Film-Noir', 'Animation', 'Drama', 'Crime', '(no genres listed)', 'Mystery', 'Fantasy', 'Action', 'War', 'IMAX', 'Documentary']
# Enter your preferred genre from the above list:  Action
# Step 1/5, Meta Loss: 1.6721354722976685
# Step 2/5, Meta Loss: 0.9503170251846313
# Step 3/5, Meta Loss: 1.4726827144622803
# Step 4/5, Meta Loss: 0.6329823732376099
# Step 5/5, Meta Loss: 0.43404367566108704
# Top recommendations for user in genre 'Action': [57426, 59125, 116022, 32981, 46320]

# %% [markdown]
# ### MUSIC recommendation using MAML

# %%
# Load the dataset and display unique artists
def load_data(file_path):
    df = pd.read_csv(file_path)
    
    # Extract unique artist names
    unique_artists = df['Artist'].unique()
    
    # Display unique artists
    print("Available artists:")
    for artist in unique_artists:
        print(artist)
    
    # Prompt the user to enter an artist name
    selected_artist = input("Enter an artist's name from the list above: ").strip()
    
    if selected_artist not in unique_artists:
        print("Artist not found. Please enter a valid artist name.")
        return None, None, None, None, None, None

    # Filter data based on the selected artist
    artist_data = df[df['Artist'] == selected_artist]
    user_to_idx = {username: idx for idx, username in enumerate(df['Username'].unique())}
    track_to_idx = {track: idx for idx, track in enumerate(df['Track'].unique())}

    user_ids = torch.tensor(artist_data['Username'].map(user_to_idx).values, dtype=torch.long)
    track_ids = torch.tensor(artist_data['Track'].map(track_to_idx).values, dtype=torch.long)
    ratings = torch.tensor(artist_data['rating'].values, dtype=torch.float)

    return user_ids, track_ids, ratings, user_to_idx, track_to_idx, selected_artist

# Define a custom dataset for the music recommendation task
class MusicDataset(Dataset):
    def __init__(self, user_ids, track_ids, ratings):
        self.user_ids = user_ids
        self.track_ids = track_ids
        self.ratings = ratings

    def __len__(self):
        return len(self.user_ids)

    def __getitem__(self, idx):
        return self.user_ids[idx], self.track_ids[idx], self.ratings[idx]

# Model definition
class RecModel(nn.Module):
    def __init__(self, num_users, num_tracks, embedding_dim):
        super(RecModel, self).__init__()
        self.user_embedding = nn.Embedding(num_users, embedding_dim)
        self.track_embedding = nn.Embedding(num_tracks, embedding_dim)
        self.fc = nn.Linear(embedding_dim * 2, 1)

    def forward(self, user_id, track_id):
        user_embed = self.user_embedding(user_id)
        track_embed = self.track_embedding(track_id)
        
        x = torch.cat([user_embed, track_embed], dim=-1)
        return self.fc(x).squeeze()

# Training function
def train_model(model, dataset, epochs, lr, batch_size):
    optimizer = optim.Adam(model.parameters(), lr=lr)
    loss_fn = nn.MSELoss()
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

    for epoch in range(epochs):
        total_loss = 0
        for user_ids, track_ids, ratings in dataloader:
            predictions = model(user_ids, track_ids)
            loss = loss_fn(predictions, ratings)
            
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            total_loss += loss.item()
        print(f'Epoch {epoch+1}/{epochs}, Loss: {total_loss / len(dataloader)}')

# Function to generate recommendations for a specific artist
def recommend(model, track_to_idx, selected_artist, num_recommendations=5):
    track_scores = []
    for track, track_idx in track_to_idx.items():
        track_id_tensor = torch.tensor([track_idx], dtype=torch.long)
        
        # We can assume a default user_id (e.g., 0) for recommendation purposes
        user_id_tensor = torch.tensor([0], dtype=torch.long)
        
        score = model(user_id_tensor, track_id_tensor)
        track_scores.append((track, score.item()))
    
    # Get the top recommended tracks
    top_tracks = sorted(track_scores, key=lambda x: x[1], reverse=True)[:num_recommendations]
    return [track[0] for track in top_tracks]

# Example usage
file_path = "C://Users//91829//Downloads//dataset_zip//dataset//Last.fm_data.csv"
user_ids, track_ids, ratings, user_to_idx, track_to_idx, selected_artist = load_data(file_path)

if user_ids is not None:
    # Create the dataset
    dataset = MusicDataset(user_ids, track_ids, ratings)

    # Initialize the model
    embedding_dim = 32
    num_users = len(user_to_idx)
    num_tracks = len(track_to_idx)
    model = RecModel(num_users, num_tracks, embedding_dim)

    # Train the model
    train_model(model, dataset, epochs=1, lr=0.001, batch_size=16)

    # Generate recommendations
    recommendations = recommend(model, track_to_idx, selected_artist, num_recommendations=5)
    print(f"Top recommendations for tracks by {selected_artist}:", recommendations)
# Out:
# Available artists:
# Isobel Campbell
# The Coral
# Gidge
# LNZNDRF
# Goat Girl
# Everything Everything
# serpentwithfeet
# Giggs
# The Koreatown Oddity
# Billy Ocean
# Pale Waves
# Khruangbin
# Bill Callahan
# Clean Bandit
# Rod Thomas
# Fela Kuti
# Jellyfish
# The Box Tops
# Rudimental
# Kacey Musgraves
# Florrie
# ROY3LS
# Black M
# Machel Montano
# LÉON
# Nelson Freitas
# Lonely The Brave
# Charlie Sloth
# Karen Harding
# Future Utopia
# Stephen Oaks
# Sonny Fodera
# Röyksopp
# R3hab
# Aluna
# Rat City
# Pink Sweat$
# Elliphant
# Rebecca Black
# Crafty 893
# Anitta
# Maluma
# Imelda May
# Lil Peep
# araabMUZIK
# Gary Bartz
# Gentleman's Dub Club
# The Smashing Pumpkins
# Wu-Tang Clan
# Salt-N-Pepa
# Felt
# Roméo Elvis
# Nick Cave & the Bad Seeds
# Fat Joe
# Dr. Dre
# Cage & Camu
# Postman
# Starflam
# LL Cool J
# Rodríguez
# Mr. Vegas
# Ghostface Killah
# Groundation
# Akhenaton
# Stephen Marley
# Fashawn
# Fantan Mojah
# Chimurenga Renaissance
# Emika
# Sizzla
# The Uncluded
# The Aggrolites
# Alpha 5.20
# FKA twigs
# Jah Cure
# Andrés Cotter
# Stikstof
# Romain Virgo
# Guru
# SOJA
# Daks
# Loyle Carner
# Vicious
# Buraka Som Sistema
# Damian Marley
# Buju Banton
# Flogging Molly
# Alborosie
# DJ Shadow
# Rootman J.
# Brent Faiyaz
# Niko Moon
# Erik Satie
# Jules Massenet
# Johann Sebastian Bach
# George Gershwin
# Edward Elgar
# Sergei Rachmaninoff
# Ludwig van Beethoven
# George Frideric Handel
# Ralph Vaughan Williams
# Fart Man
# The Internet
# Majid Jordan
# Lianne La Havas
# Alina Baraz
# Gramatik
# Sango
# Pascäal
# Anderson .Paak
# SZA
# HONNE
# Movement
# Matt Simons
# Saje
# Jamie Woon
# Thundercat
# FKJ
# Erykah Badu
# Nao
# Chet Faker
# Rhye
# Locked Groove
# Nora Van Elken
# Monkey Safari
# Fort Romeau
# Buddha-Bar
# HoneyDripper
# Bicep
# Sahar Z
# Sultan + Shepard
# Nina Kraviz
# boys be kko
# Fabio Aurea
# Tone Depth
# Andrea Oliva
# Tim Green
# Christian Löffler
# Selena
# will.i.am
# Dawn Richard
# Usher
# Rihanna
# Nielson
# Jessie J
# Little Mix
# Selah Sue
# Eminem
# Charlene
# Selena Gomez
# Volumia!
# Eve
# Katy B
# Live
# Enrique Iglesias
# Amy Winehouse
# Ciara
# Big Sean
# Luis Fonsi
# Fifth Harmony
# Davina Michelle
# Gabriella Cilmi
# Chris Brown
# All Saints
# Kiana Ledé
# Lady Gaga
# Nelly Furtado
# Backstreet Boys
# Demi Lovato
# Dua Lipa
# Michael Jackson
# Delilah
# Jennifer Lopez
# Ella Henderson
# Plan B
# Ariana Grande
# Drake
# DJ Cassidy
# Kane
# Holly Valance
# Labrinth
# Popcaan
# Sevana
# Shenseea
# Frisco Kid
# Jaz Elise
# Koffee
# Bou
# Meph luciano
# The MookMann
# Billie Eilish
# Cosha
# The Roots
# Loxy
# The Vaccines
# Jorja Smith
# Eesah
# Arca
# Mono
# Torii Wolf
# Diverse the Prodigy
# Dexta Daps
# Shaggy
# Burning Spear
# Barrington Levy
# Jigsy King
# Naomi Cowan
# Dre Island
# Elepohant Man
# Jaz Karis
# Lila Iké
# Billy Talent
# Yves Deruyter
# Rotterdam Termination Source
# Eagles of Death Metal
# Caesars
# Alter Ego
# Oxley
# deadmau5
# Maurizzio
# Sean Paul
# M-Beat
# Tiiwtiiw
# Luniz
# Lesley Gore
# Mama's Jasje
# Doemaardave
# Irene Cara
# Mason
# Groove Armada
# N.W.A.
# Henk Wijngaard
# De Marlets
# Goran Bregović
# WC Experience
# Carmen Waterslaeghers
# Faces
# GLASS WATERS
# Zebrahead
# Crystal Castles
# Puri
# Bronski Beat
# DJ Zinc
# Bolle Tito
# Studio Vibe
# America
# Rob De Nijs
# Nik Kershaw
# Huey Lewis & The News
# Brother Culture
# Steve Harley
# Falco
# Hosh
# Alex Mine
# Poldoore
# Petit Biscuit
# Stephane 1993
# Leonard Cohen
# Autechre
# Reinier Zonneveld
# Dusty Kid
# Fleur East
# Jess Glynne
# Freya Ridings
# Lewis Capaldi
# Dagny
# Illenium
# Marshmello
# The Avener
# EDX
# Vinil
# Sigala
# Midnight To Monaco
# Twelve
# Alesso
# Throttle
# MK
# Don Diablo
# The Him
# DubVision
# Loud Luxury
# Kelsy Karter
# Kygo
# Balkan Beat Box
# Young Israelites
# Maxi Priest
# Reggae Roast
# Beenie Man
# Christopher Ellis
# Chronixx
# Liam Bailey
# Busy Signal
# Kiko Bun
# Lila Ike
# Nathan Evans
# Madison Avenue
# Five
# S Club 7
# Britney Spears
# Christopher Tin
# Geoff Knorr
# Simon & Garfunkel
# Roland Rizzo
# The Calling
# Westlife
# Norah Jones
# Sophie Ellis-Bextor
# Nickelback
# Nelly
# Joel Corry
# Topic
# K-Ci & JoJo
# Syd
# Nayana Iz
# Mahalia
# Doja Cat
# TLC
# Summer Walker
# Ramz
# Mos Def
# Hi-Tek
# Lootpack
# J Dilla
# Kanye West
# A Tribe Called Quest
# Kendrick Lamar
# Michael Galasso
# Frank Ocean
# Air
# Bobmo
# James Yuill
# Deyah
# Nuyorican Soul
# Dan Kye
# Nicolas Jaar
# Blanco
# Joey Bada$$
# James Blake
# Don Toliver Remixed
# Shiv
# Pa Salieu
# Fred again..
# Moses Sumney
# Jordan Rakei
# The Pharcyde
# Isaiah Rashad
# The Sabres of Paradise
# Jacques Greene
# TOKiMONSTA
# Burna Boy
# Dave
# Stormzy
# Goody Grace
# Chip
# Gorgon City
# DJ Pioneer
# Foreign Beggars
# Ben Howard
# KIDKODDI
# Jax Jones
# Fredo
# Faouzia
# Bankulli
# sleep protocol
# Mayo
# Tissi
# sound butler
# Sileon
# Sunday Mode
# Hi Hat Henry
# Sam Cooke
# Stevie Wonder
# Barry White
# Harold Melvin & The Blue Notes
# Aretha Franklin
# The Supremes
# Al Green
# The O'Jays
# Marvin Gaye
# Otis Redding
# Bill Withers
# Gladys Knight & The Pips
# The Spinners
# Tavares
# Bee Gees
# Diana Ross
# Rose Royce
# Dionne Warwick
# Penny & the Quarters
# Curtis Mayfield
# Ben E. King
# Simply Red
# Four Tops
# Billy Paul
# Commodores
# The Temptations
# B.B. King
# Ann Sexton
# Samba
# Foo Fighters
# Kylie Minogue
# Holy Now
# Guds Pengar
# Eleven Pond
# Givers
# Das Kabinette
# Oskarova Fobija
# Oppenheimer Analysis
# Parade Ground
# Deux
# Techniques Berlin
# Futurisk
# Kym Amps
# The Tellers
# The Walkmen
# Funeral Suits
# The Cinematics
# NG3
# Radio 4
# Ian Taylor
# Circuit 7
# Degada Saf
# Luxury Stranger
# Medium Medium
# Kuruki
# The Ballad Bombs
# The KVB
# Monie Love
# Clout
# Kirsty MacColl
# The Mighty Wah!
# The Railway Children
# Belly
# Northside
# Depeche Mode
# The Course
# Conditioner Disco Group
# Kitchens of Distinction
# Sandie Shaw
# Vita Bergen
# The Pointer Sisters
# St. Jude the Obscure
# The Ordinary Boys
# Nick Lowe
# Girls At Our Best!
# The Charlatans
# Amanda Mair
# Beige Banquet
# Baio
# Lean Logic
# Always You
# Pylon
# Prince Daddy & The Hyena
# Save Face
# Orla Gartland
# Ashnikko
# Lana Del Rey
# lovelytheband
# Silk City
# 93FEETOFSMOKE
# Griff
# I DONT KNOW HOW BUT THEY FOUND ME
# Royal Blood
# JC Stewart
# Birdy
# Molly Burch
# MOD SUN
# dodie
# familypet
# Shinigami
# ONE OK ROCK
# Calvin Harris
# Silent Siren
# Kairiki Bear
# Tom Walker
# ATEEZ
# Bastille
# Suzi Island
# Shaed
# Neha Kakkar
# George Ezra
# syudou
# BLACKPINK
# Matchbox Twenty
# Fall Out Boy
# Shehnaz Kaur Gill
# Written by Wolves
# YOASOBI
# BACK-ON
# Gesu No Kiwami Otome
# [Alexandros]
# Dreamcatcher
# BLUE ENCOUNT
# Sam Tinnesz
# Panic! at the Disco
# twenty one pilots
# Kenshi Yonezu
# Metr
# Maggie Lindemann
# ZyniC
# Suicide Commando
# Beyond Obsession
# Elegant Machinery
# Red Cell
# Takatsugu Wakabayashi
# Capcom Sound Team / Re-Arranged By Masahiro Aoki
# Tha Trickaz x DJ Kentaro
# Junksista
# Blaqk Audio
# Trevor Something
# Galaxy Hunter
# Second Version
# Tashaki Miyaki
# Balvanera
# Antidote for Annie
# Gorillaz
# Duran Duran
# Kero Kero Bonito
# 100 gecs
# JPEGMAFIA
# Sophie
# Christina Aguilera
# Natasha Bedingfield
# Vanessa Carlton
# Mika
# Taylor Swift
# Sugababes
# Maroon 5
# Lou Bega
# Culture Club
# Mis-Teeq
# ABBA
# "Weird Al" Yankovic
# Candi Staton
# Omi
# Robbie Williams
# Shania Twain
# Justice
# Fergie
# Zara Larsson
# Barry Manilow
# Rick Springfield
# Dead or Alive
# Cher
# Oliver Cheatham
# Rizzle Kicks
# Vengaboys
# Busted
# Roll Deep
# Madonna
# JoJo
# Madcon
# Mary Mary
# Kate Bush
# Aggro Santos
# Beyoncé
# of Montreal
# Panchiko
# Rabbit Junk
# Cecile Believe
# The Dismemberment Plan
# Ella Lee
# Alice Glass
# Cassius
# Origami Angel
# Playboi Carti
# Ween
# Sidney Gish
# Blur
# Neutral Milk Hotel
# Grauzone
# Less Than Jake
# Pavement
# DJ Sabrina The Teenage DJ
# The Bats
# Foals
# Chairlift
# Tkay Maidza
# Logic
# Brother Ali
# Al Bairre
# Hatchie
# Jessie Ware
# Everclear
# G Flip
# Genesis Owusu
# KAYTRANADA
# Flight Facilities
# Bleachers
# Yumi Zouma
# Lola Marsh
# San Cisco
# Thelma Plum
# Dizzy
# Overcoats
# Mallrat
# Ocean Alley
# Spacey Jane
# Tame Impala
# Glass Animals
# Jason Isbell and The 400 Unit
# Sylvan Esso
# Powfu
# St. Lucia
# Small Black
# The New Division
# Geographer
# Wild Nothing
# Teen Daze
# Brothertiger
# CHVRCHES
# Joan
# Phoebe Bridgers
# James Hersey
# Rasmus Faber
# WØØLS
# Erlend Øye
# Billie Marten
# Pinegrove
# All Sons & Daughters
# POLIÇA
# Pedro the Lion
# Phil Collins
# SwuM
# The Undercover Dream Lovers
# Mosaic MSC
# Sunny Day Real Estate
# Steely Dan
# Trey Songz
# Rich Rocka
# The Go! Team
# Carly Rae Jepsen
# Plankeye
# Todd Terje
# Whiskeytown
# Bakermat
# Sasha Sloan
# Owl City
# Diskret
# The Kinks
# Jimmy Eat World
# Madlib
# Silkie
# maudlin of the Well
# 아버지
# Midori Takada
# Bluetile Lounge
# MGMT
# Ulver
# QT
# Loathe
# TR/ST
# Street Soldier
# Soen
# Queens of the Stone Age
# The Brian Jonestown Massacre
# Monsternaut
# Black Space Riders
# Valis
# Core
# Deville
# Vertical
# Fu Manchu
# Thee Oh Sees
# Monstroid
# Los Iracundos
# José Luis Perales
# Ana Gabriel
# Rocío Dúrcal
# Juan Gabriel
# Julio Jaramillo
# House of Harm
# Luis Miguel
# Muslim Magomayev
# Кипелов
# Aria
# Black Eyed Peas
# Nightwish
# Sirenia
# Lacuna Coil
# Within Temptation
# Xandria
# Nemesea
# Eluveitie
# Blackbriar
# After Forever
# The Gathering
# Delain
# Karol G
# Harry Styles
# System of a Down
# Epica
# Cardi B
# The Weeknd
# Katy Perry
# She Wants Revenge
# Slowdive
# Citizen
# La Dispute
# Deftones
# Cocteau Twins
# All That Remains
# Fields of the Nephilim
# This Mortal Coil
# The Cure
# Black Tape for a Blue Girl
# Dead Can Dance
# Siouxsie and the Banshees
# The Sisters of Mercy
# Type O Negative
# Bauhaus
# Diary of Dreams
# Joy Division
# Echo & the Bunnymen
# Twin Tribes
# HIM
# Cradle of Filth
# Sisters of Mercy
# Coil
# True Widow
# Godspeed You! Black Emperor
# Bohren & der Club of Gore
# King Dude
# David Lynch
# Chelsea Wolfe
# The Sound
# Heroin and Your Veins
# Can
# Duster
# Cranes
# Mark Lanegan
# Spell
# A Silver Mt. Zion
# Swans
# Einstürzende Neubauten
# Ludovico Einaudi
# Brambles
# Pencey Sloe
# Romeo Void
# Cloud Nothings
# Les Discrets
# Pulp
# Sneaker Pimps
# Mika Ogawa
# Seatbelts
# Manic Street Preachers
# IDLES
# Fugazi
# PJ Harvey
# Radiohead
# Elastica
# Bladee
# Christian Death
# Hole
# Agent Orange
# Portishead
# Fiona Apple
# Bratmobile
# Alien Sex Fiend
# Have a Nice Life
# The London Suede
# my bloody valentine
# Primal Scream
# Mazzy Star
# Elliott Smith
# Nico
# Angel Olsen
# McAlmont & Butler
# Johnny Marr
# The Afghan Whigs
# Suede
# Elbow
# Reeve Carney
# Eva Noblezada
# André De Shields
# Sherie René Scott
# Sherie Rene Scott
# Norbert Leo Butz
# Chad Kimball
# 'Come From Away' Band
# Ray Charles
# Murray Head
# Ava Max
# Nitzer Ebb
# Martin L. Gore
# Firevision
# Anastacia
# Mighty 44
# Arcade Fire
# Ugly Kid Joe
# Q Lazzarus
# Talking Heads
# Hullu Elämä
# Yö
# Mr. Bungle
# Carpenters
# Public Service Broadcasting
# Fleetwood Mac
# The Romantics
# Dire Straits
# The Beach Boys
# Oingo Boingo
# The Beatles
# Faith No More
# Vize
# Morrissey
# Waxahatchee
# St. Vincent
# Goldfrapp
# Tirzah
# Helena Deland
# MF DOOM
# Suzy
# pH-1
# HA:TFELT
# millic (밀릭) Millic
# ZICO
# Yubin
# MELODYDAY
# 이진아
# nafla
# Kid Milli
# 이바다
# 백예린
# Red Velvet
# Boa
# PER6IX
# April
# 현아
# Bytecon
# 植田真梨恵
# Cold Body Radiation
# Ambersmoke
# Planning for Burial
# Joan of Arc
# Mineral
# Elliott
# Wowod
# Divide and Dissolve
# Wreckless Eric
# Sub Focus
# M|O|O|N
# Ravxn
# Martha
# Audeka
# The Horrors
# The Wedding Present
# Bambara
# Heavenly
# Happydeadmen
# Hum
# Killing Joke
# Simple Minds
# The Soundcarriers
# Sad Lovers & Giants
# Black Flag
# The Gaslight Anthem
# Sweet Trip
# Gilla Band
# The Pains of Being Pure at Heart
# Alberich
# Brighter Death Now
# Atari Teenage Riot
# City Girls
# Nocturnal Emissions
# IRM
# C.C.C.C
# Deathpile
# Merzbow
# Trepaneringsritualen
# Sly & The Family Stone
# Metallica
# Nicki Minaj
# Space
# Coldcut
# Saloli
# Baths
# Mr FijiWiji
# Alix Perez
# Tycho
# VNV Nation
# Lane 8
# t e l e p a t h テレパシー能力者
# London Elektricity
# Icicle
# Moa Pillar
# Lemon Jelly
# Hex
# Avicii
# Shlohmo
# C418
# Daniel Avery
# Jean-Michel Jarre
# Jessy Lanza
# IZZARD
# Little People
# Gold Panda
# Swardy
# Vangelis
# Cosmic Gate
# The Future Sound of London
# Orbital
# The Durutti Column
# The Chemical Brothers
# Better Oblivion Community Center
# Armin van Buuren
# Zedd
# One Direction
# The Wrecks
# WSTR
# V V Brown
# Paramore
# Widowspeak
# Jay Som
# Peyton
# Rina Sawayama
# Masego
# Dent May
# Disclosure
# Grip
# JW Francis
# Arlo Parks
# Young Franco
# Jim-E Stack
# The Birthday Party
# Adam & The Ants
# The Damned
# Solar Flare And Her Trio Of Sheep
# Asphyx
# Amaranthe
# Björk
# Schammasch
# Strident
# Ayreon
# Mariah Carey & Whitney Houston
# Mariah Carey
# Miley Cyrus
# Victoria Monét
# Subp Yao
# Amon Tobin
# Two Fingers
# Darkside
# Machinecode
# Nino Rota
# Banda Ionica
# Rufus Thomas
# Stan Getz
# Drab City
# Pinkshinyultrablast
# Lusine
# JJ DOOM
# Post Animal
# TOPS
# Wondha Mountain
# Tennis
# Deerhoof
# Via App
# Why?
# Redveil
# KNOWER
# Jockstrap
# Minimal Man
# Rezzett
# Mr Twin Sister
# Candy Claws
# Soft Kill
# Grouper
# Nicole Sabouné
# Marie Davidson
# Beach House
# Easter
# Molchat Doma
# White Lies
# Motorama
# Future Islands
# Editors
# Bones
# Powell
# Hali Palombo
# Urban Village
# Kessler
# Dead Space Chamber Music
# Solatipour Reza
# Lars Bröndum
# Martyria
# Mombi Yuleman
# Nachtreich
# katie dey
# Heriot
# Perfume Genius
# U
# Ilya Kaler
# Feed Me To The Waves
# Arcade Player
# Crumb
# Bright Eyes
# The Backseat Lovers
# Alex G
# Silver Jews
# Yo La Tengo
# Broadcast
# The Replacements
# Jens Lekman
# Disco Inc.
# HOMESHAKE
# M.A.G.S.
# Days N' Daze
# Crass
# The Moldy Peaches
# bedside kites
# The Velvet Underground
# Small Crush
# Modern Baseball
# Beat Happening
# Ramones
# Belle & Sebastian
# The Softies
# Talulah Gosh
# Tiger Trap
# Hey Paulette
# Tortured Soul
# Claptone
# CeCe Peniston
# Junior Jack
# Armand van Helden
# Livin' Joy
# Everything But the Girl
# Ultra Naté
# Chris Lake
# Crystal Waters
# Duck Sauce
# Kings Of Tomorrow
# Rozalla
# Robin S
# The Bad Yard Club
# Róisín Murphy
# Henrik Schwarz
# Lou Hayter
# Charles Aznavour
# Stromae
# Serge Gainsbourg
# Édith Piaf
# Madeleine Peyroux
# Charles Trenet
# Joe Dassin
# Yves Montand
# Zaz
# Françoise Hardy
# Carla Bruni
# Kurt Weill
# Falle Nioke
# Astronauts, etc.
# Still Corners
# Anna Fox Rochinski
# Jeroen Dirrix
# Cass McCombs
# Nation of Language
# Men I Trust
# Tune-Yards
# Myd
# SMERZ
# Digitalism
# Altin Gün
# JennyLee
# Neil Frances
# Balthazar
# Car Seat Headrest
# 1 Trait Danger
# bałtyk
# American Holly
# Stef Chura
# Glaive
# gupi
# A. G. Cook
# fromtheheart
# Iglooghost
# GFOTY
# Alice Gas
# easyFun
# Thomston
# Moth
# Sabaton
# Galenskaparna & After Shave
# Linkin Park
# KUURO
# Jauz
# Lillasyster
# Skrillex
# John Williams
# 4 Non Blondes
# Teddybears
# Knife Party
# Frej Larsson
# Florence + the Machine
# The Rembrandts
# Partiet
# Lets Be Friends
# Disturbed
# Dion Timmer
# Icon for Hire
# Jaroslav Beck
# Loreen
# Electric Banana band
# HEALTH
# Hard Bass School
# Cults
# Living Hour
# Deerhunter
# Delvon Lamarr Organ Trio
# Blouse
# Pure Bathing Culture
# Sofia Reyes
# Shakira
# Anuel AA
# Rubi Rose
# Zion & Lennox
# Wisin & Yandel
# Eladio Carrion
# Daddy Yankee
# Manuel Turizo
# Sum 41
# The Red Jumpsuit Apparatus
# Green Day
# All Time Low
# Yellowcard
# The All-American Rejects
# Good Charlotte
# Weezer
# Simple Plan
# Ed Sheeran
# Michelle
# Evelyn "Champagne" King
# My Chemical Romance
# Mike Moonnight
# J Balvin
# Winifred Atwell
# Lele Pons
# Kevin Roldan
# Camilo
# Bad Bunny
# Marc Cohn
# Ozuna
# Christian Nodal
# Boza
# Rauw Alejandro
# Tainy
# Willy Moon
# Winston Samuels
# Violet Hall
# Winter Aid
# Vincent Brahn
# Camila Cabello
# Lil Tecca
# DJ Scheme
# Westside Gunn
# A$AP Ferg
# Future
# Lil Baby
# Polo G
# 21 Savage
# Migos
# A$AP Rocky
# A$AP Mob
# KYLE
# YG
# Smokepurpp
# A Boogie wit da Hoodie
# Jay Gwuapo
# Clay "Krucial" Perry III
# Yung Lean
# Jonatan Leandoer96
# Mac Miller
# Pantera
# Exodus
# Saxon
# Bolt Thrower
# DC Breaks
# Morbid Angel
# Firewind
# Vremya i Steklo
# DOROFEEVA
# The Hardkiss
# Kazka
# Favorite
# Saturday
# Marina
# Malía
# Teyana Taylor
# Chloe x Halle
# Saweetie
# DaBaby
# Solange
# Janelle Monáe
# Aminé
# Megan Thee Stallion
# Rico Nasty
# Kali Uchis
# Iyla
# The Jackson 5
# Nat King Cole
# Olivia Newton-John
# ROSALÍA
# Timbaland
# Pras, Ol' Dirty Bastard, Mya
# Toni Braxton
# Ol' Dirty Bastard
# JAY-Z
# Gunna
# Young Thug
# Quality Control
# Gucci Mane
# Lil Wayne
# Pop Smoke
# Vince Staples
# Dreamville
# Travis Scott
# Lil Uzi Vert
# J. Cole
# JACKBOYS
# Rich Gang
# Babyface Ray
# Yameii Online
# Charli XCX
# ericdoa
# Cuco
# Cautious Clay
# BENEE
# p4rkr
# Food House
# IU
# Daniel Caesar
# Danny L Harle
# Audrey Nuna
# Grimes
# Death Grips
# Clarence Clarity
# George Clanton
# Ty Dolla $ign
# Young Dolph
# Kid Cudi
# Jessie Reyez
# Jack Harlow
# PARTYNEXTDOOR
# Kamaiyah
# Flatbush ZOMBiES
# Iggy Azalea
# Ari Lennox
# Trippie Redd
# Rayana Jay
# Ta-ku
# Lorde
# Bruno Mars
# Kehlani
# Tia Carys
# Melanie Martinez
# blink-182
# Lil' Kim
# No Doubt
# Kim Petras
# The Pussycat Dolls
# Hannah Montana
# Ke$ha
# Kesha
# The Aquabats!
# Prince
# S-hot
# Odyssey
# Mtume
# Chemise
# Slave
# D-Train
# Alphabeat
# Ida Corr
# Yeah Yeah Yeahs
# Steve Angello
# Alice Deejay
# Daft Punk
# Stardust
# Paul Oakenfold
# Dave Armstrong
# Guru Josh Project
# Shapeshifters
# Ercola
# Alicia Keys
# Sir
# JID
# The Notorious B.I.G.
# Smino
# Aaliyah
# Jaden
# nasaan
# H.E.R.
# Jazmine Sullivan
# JAY-Z & Kanye West
# Lykke Li
# Mereba
# KIDS SEE GHOSTS
# Tyler, the Creator
# Raku-Nu
# Willow
# RÜFÜS DU SOL
# Bhaskar
# Tangerine Dream
# XTC
# RÜFÜS
# The Strokes
# Starset
# Arctic Monkeys
# Waterparks
# Muse
# BTS
# Nujabes
# bittymacbeth
# Peach Prc
# The New Respects
# Omar Apollo
# Mrs. Strange
# TiGERTOWN
# Empire of the Sun
# Flo Milli
# Phony Ppl
# Two Door Cinema Club
# CHUNG HA
# David Guetta
# LIZ
# Corpse
# Pentatonix
# Geho
# Machine Gun Kelly
# Olívia
# Rico Dalasam
# MC Soffia
# Zayn
# ABRONCA
# Tasha & Tracie
# Bruna Liz
# Shwayze
# Nabrisa
# YUNGBLUD
# Tove Lo
# The Pretty Reckless
# Rincon Sapiência
# Aviva
# Laysa
# Tropkillaz
# FBC
# Tate McRae
# Felipe Flip
# Killa Bi
# Victor Cronos
# DuSouto
# DEAD POET SOCIETY
# As Baías
# MC Robs
# Pabllo Vittar
# Jova
# Criolo
# Linn da Quebrada
# Duduzzone
# Years & Years
# Venvs
# The Veronicas
# AMARO
# Justin Bieber
# The 1975
# blackbear
# GoldLink
# Trevi Moran
# Armors
# Troye Sivan
# Louis Tomlinson
# Aidan Alexander
# Kid Travis
# Conan Gray
# Soccer Mommy
# Yves Tumor
# Mitski
# Father John Misty
# Donnie Trumpet & The Social Experiment
# Giveon
# Rex Orange County
# Chief Keef
# Ryan Beatty
# Death Cab for Cutie
# Keane
# ギルガメッシュ
# Blood Orange
# Cícero
# Phoenix
# Doves
# The Black Keys
# Cake
# The Killers
# Goldspot
# Stars
# Kaiser Chiefs
# Youth Group
# Rogue Wave
# LCD Soundsystem
# Shout Out Louds
# Kasabian
# The Subways
# Matt Pond PA
# Bell X1
# The Reindeer Section
# Aqueduct
# Modest Mouse
# Beck
# Flunk
# Sufjan Stevens
# A.C. Newman
# Pinback
# Maribou State
# Daedelus
# Knxwledge
# Jitwam
# Taylor McFerrin
# Robert Glasper
# Ras G
# Butcher Brown
# Her's
# Steve Lacy
# Raveena
# Hope Tala
# Greentea Peng
# Ms. Lauryn Hill
# Nação Zumbi
# Don Toliver
# Seu Jorge
# Luedji Luna
# Free Nationals
# Marcos Valle
# Yellow Days
# CLUB KURU
# Cronicas de Um Babaca
# Luiz Melodia
# Aaron May
# Trinidad Cardona
# Skinshape
# MC Hariel
# Mild Orange
# Dominic Fike
# Drugdealer
# LOVING
# The Walters
# Palehound
# Levitation Room
# Surf Curse
# Coin
# Emotional Oranges
# Mr Jukes
# Thyla
# Brittany Howard
# Jungle
# Requiem Inc.
# DEAN
# Catfish and the Bottlemen
# Alabama Shakes
# Kevin Michael
# Ezra Collective
# Snoh Aalegra
# J Lloyd
# Vivian Green
# Sophie Faith
# Foster the People
# Fitz and the Tantrums
# Ravyn Lenae
# Winnetka Bowling League
# Angela Muñoz
# Bad Suns
# Marian Hill
# HAIM
# Denitia and Sene
# Purity Ring
# Samira Close
# Michelle Gurevich
# BELLSAINT
# The Blow
# Jesse
# Dalida
# Bigbang
# Gabby Barrett
# Tenny
# The Last Shadow Puppets
# Alec Benjamin
# XXXTENTACION
# Epik High
# Franz Ferdinand
# Khalid
# Coldplay
# 2NE1
# Tablo
# G-Eazy
# SISTAR
# NCT 127
# FIL BO RIVA
# 5 Seconds of Summer
# The Neighbourhood
# Joji
# Adele
# P!nk
# Mag.Lo
# Winner
# Post Malone
# The Irrepressibles
# Of Monsters and Men
# Hana
# Kyle Dixon & Michael Stein
# Mac DeMarco
# Eric Jafet
# Yunk Vino
# Esteban Tavares
# KMFDM
# Sister Machine Gun
# Crywolf
# Shygirl
# LYZZA
# Amnesia Scanner
# siouxxie
# Y1640
# Crim3s
# Himera
# Alice Longyu Gao
# Eartheater
# M.I.A.
# Actress
# Tommy Cash
# Kerridge
# Filmmaker
# Lucky Daye
# Tinashe
# DDG
# DJ Khaled
# Lil Eazzyy
# Miguel
# Blake Shelton
# Wale
# Dej Loaf
# Jhené Aiko
# Childish Gambino
# Eric Bellinger
# Big Mali
# S3nsi Molly
# Celeste
# BANKS
# Tricky
# Kurt Baggaley
# Banyen Rak Kaen
# Jonny Olsen
# Teh Utain Prommin
# Zander Jazz Trio
# Dan Evans-Parker
# Southside Players
# Hudson Harris & Haim
# Louis Silva Band
# Greydon Park Band
# Eddie Harper
# Brad Mehldau Trio
# Enya
# Explosions in the Sky
# Sigur Rós
# M83
# We the Kings
# Gregory and the Hawk
# Youth Lagoon
# Iron & Wine
# Israel Kamakawiwo'ole
# Famy
# Placebo
# Pearl Jam
# The Dø
# Roxy Music
# Incubus
# Dave Gahan
# Nine Inch Nails
# Bruce Springsteen
# The Stooges
# R.E.M.
# Blondie
# Joe Bonamassa
# Scorpions
# Elvis Presley
# Red Hot Chili Peppers
# Nirvana
# Oasis
# The Chameleons
# The Byrds
# Bon Jovi
# The Animals
# Iggy Pop
# The Stranglers
# Garbage
# Feverkin
# Amber DeLaRosa
# Deb Never
# OTR
# London Grammar
# Edamame
# Oh Wonder
# Sidewalks and Skeletons
# Ford.
# Big Wild
# Kailee Morgue
# Au/Ra
# 4lienetic
# Charlie Crown
# Justin Caruso
# Porter Robinson
# Nebulae
# zabawa
# spencer.
# ODESZA
# Chloe Gendrow
# Annaland
# Bryce Vine
# Manila Killa
# Kllo
# Emmit Fenn
# Namara
# St. South
# Hop Along
# Geeta Dutt
# Shamshad Begum
# Bob Dylan
# Doug Martsch
# Nick Drake
# The Fall
# The Sea and Cake
# Pink Floyd
# The Halo Benders
# C.J. & CO.
# Hues Corporation
# S'Express
# McFadden & Whitehead
# Frankie Valli & the Four Seasons
# Kraftwerk
# Jocelyn Brown
# War
# Cameo
# Saint Etienne
# Showaddywaddy
# Wayne Smith
# Hall & Oates
# Elton John
# Carly Simon
# Chic
# George McCrae
# Electric Light Orchestra
# Limmie & The Family Cookin'
# Tom Tom Club
# Ian Dury and the Blockheads
# Combustible Edison
# The Besnard Lakes
# I, Ludicrous
# The Jesus and Mary Chain
# The Sea Urchins
# Close Lobsters
# The Popguns
# Robyn Hitchcock
# British India
# Mikkel Metal
# Cranker R
# Kryss Hypnowave
# Trajano
# Chronophone
# Advanced Dreams
# Valerio Vaudano
# PPM
# Gael F.S.
# S-Tek
# Nachtaktiv
# Babe Roots
# Float & Rütz
# Palindrom
# 2OMA
# Tender H
# Stanislav Vdovin
# HEAVENCHORD
# Deto & Gleam
# Matthias Springer
# Mitrica
# Igor Vlasov
# Gathaspar
# Giriu Dvasios
# Sonic Youth
# The Shangri-Las
# St Germain
# André Jolivet
# Marcel Landowski
# Big Black
# Helvetia
# Erasure
# Siouxsie & The Banshees
# Shellac
# Julianna Barwick
# Adrianne Lenker
# The Aliens
# Maps
# Andrew Bird
# Squirrel Flower
# Tim Heidecker
# Beirut
# Fleet Foxes
# Dirty Projectors
# Woods
# Flume
# Fink
# Grizzly Bear
# Casino Versus Japan
# Rivulets
# Julia Holter
# Olivia Rodrigo
# Bombay Bicycle Club
# Metronomy
# Camera Obscura
# Belle and Sebastian
# Hozier
# Albert Hammond, Jr.
# The Shins
# Pete Yorn
# Patrick Wolf
# Taken by Trees
# Laura Marling
# Alexz Johnson
# Wolfie
# Weyes Blood
# Local Natives
# Mumford & Sons
# Sydney Sprague
# Relient K
# Lonelyspeck
# Charlie Hickey
# Half Waif
# Eagle-Eye Cherry
# Motion City Soundtrack
# Slayyyter
# Katy Kirby
# Adult Mom
# Hand Habits
# Pompeii
# Daughter
# Young Rising Sons
# Tom Odell
# The Lumineers
# alt-J
# Alfie Templeman
# Vampire Weekend
# Gang of Youths
# Jeremy Young
# Keaton Henson
# Jackson Wang
# Stray Kids
# Seventeen
# GOT7
# GroovyRoom
# DAY6
# Yama
# Agust D
# Architects
# The Smiths
# Dio
# Black Sabbath
# Santana
# Tyga
# Kenny Wayne Shepherd
# Sonny Landreth
# Warren Haynes
# L7
# Shmu
# Fever The Ghost
# CRX
# Jlin
# The Jimi Hendrix Experience
# Jimi Hendrix
# David Bowie
# Sparks
# Syd Barrett
# Suburban Lawns
# The Weather Prophets
# The White Stripes
# The Radio Dept.
# jxdn
# P9
# Franz Liszt
# Gabriel Fauré
# Maurice Ravel
# The Jesus Lizard
# Butthole Surfers
# School of Seven Bells
# The Magnetic Fields
# Subsonic Eye
# Hazel English
# Tristen
# Mini Trees
# Hater
# Illuminati Hotties
# Slumber Party
# Geowulf
# The Raveonettes
# Barrie
# YOWLER
# Camera Shy
# Briana Marela
# Varsity
# Anna Burch
# Westkust
# Aldous Harding
# Frankie Cosmos
# Forth Wanderers
# Japanese Breakfast
# All Dogs
# The Wake
# Help Stamp Out Loneliness
# Echo Lake
# Alvvays
# The Flatmates
# Cumulus
# Alice Boman
# Beach Fossils
# Sambassadeur
# flatsound
# Bring Me the Horizon
# Asking Alexandria
# The Used
# The Style Council
# Pierce the Veil
# Mindless Self Indulgence
# Our Last Night
# Aiden
# Every Time I Die
# Sleeping with Sirens
# Earl Sweatshirt
# Pineapple StormTV
# Delacruz
# LUDMILLA
# Mc Beyonce
# OneRepublic
# The Chainsmokers
# Nothing But Thieves
# Halsey
# Dear Gravity
# Hallowell
# Holy Hope
# ReVamp
# Theatre of Tragedy
# Therion
# Elvellon
# Cellar Darling
# Amberian Dawn
# Elori Saxl
# Midlake
# Candidate
# Anna B Savage
# Niko
# âme
# Hello Seahorse!
# Gustavo Cerati
# beabadoobee
# Madame Récamier
# Mark Ronson
# Charlotte Gainsbourg
# Jess Williamson
# Basement Jaxx
# Mew
# The National
# Alizée
# Broods
# The Who
# New Order
# Flock of Dimes
# The Japanese House
# Pomplamoose
# Tomás Barreiro
# Jim Sturgess
# BØRNS
# Zoé
# Cami
# The Civil Wars
# Lous and The Yakuza
# Cat Power
# The Kooks
# Ennio Morricone
# Cavetown
# Laura Murcia
# Ace of Base
# Eric Clapton
# Enigma
# Aphex Twin
# Django Reinhardt
# Dizzy Gillespie
# Billie Holiday
# Ethel Waters
# Galt Macdermot
# Glenn Miller
# The Dave Brubeck Quartet
# Billy Strayhorn
# Oscar Peterson
# Duke Ellington
# Original Dixieland Jazz Band
# James Reese Europe
# Joanna Newsom
# Waylon Jennings & Willie Nelson
# Manaka Kataoka
# Joe Henderson & Alice Coltrane
# Alice Coltrane
# Celer
# Underworld
# Anna & Elizabeth
# Not Waving
# The Legendary Pink Dots
# Jesse Osborne-Lanthier
# Bathsheba
# Koudlam
# Radar Men from the Moon
# Clark
# Nev Cottee
# Charlie Hilton
# Martin Denny
# Scott Walker
# Jan Jelinek
# Susumu Yokota
# she-devils
# Miharu Koshi & Harry Hosono Jr.
# Miharu Koshi
# Flipper's Guitar
# Towa Tei
# Fishmans
# Kahimi Karie
# Helen Love
# Signal
# Piroshka
# Holy Fawn
# DIIV
# Puddle of Mudd
# The Clash
# Black Stone Cherry
# Tom Swoon, Kerano
# Kings of Leon
# Red
# The Cars
# The Knocks Feat. Sam Nelson Harris
# Plain White T's
# AWOLNATION
# For King And Country
# Emphatic
# Mount Farewell
# Frank Sinatra
# Sofi Tukker
# Civil Twilight
# The Icarus Account
# Royal Teeth Feat. Tunde Olaniran
# Kaleo
# Barnes Courtney
# Men at Work
# Canned Heat
# D.A. Wallach
# Mozart
# State of Sound
# Jess Kent
# Joseph
# The Lighthouse & The Whaler
# James Bay
# The Record Company
# Switchfoot
# Jeff Buckley
# The Alchemist
# Lupe Fiasco
# Alessandro Cortini
# Silver Mt. Zion
# Apparat
# Flying Lotus
# Oval
# The Tradewinds
# The Superfine Dandelion
# The Ballroom
# The Elastik Band
# The Aggregation
# Morning Glory
# Federal Duck
# Chaz Jankel
# Bill Nelson
# Patti Smith
# Cabaret Voltaire
# Chrome
# Current 93
# Mick Karn
# Trisomie 21
# Ryan Adams
# George Michael
# Alice in Chains
# Soundgarden
# Temple of the Dog
# Hayley Williams
# The Antlers
# Portugal. The Man
# Led Zeppelin
# Archive
# Blackfield
# U2
# King Gizzard And The Lizard Wizard
# Built to Spill
# Alex Ebert
# Roberta Costantino
# Quatuor Ébène
# John Lennon
# Yoko Ono
# Animal Collective
# Cate Le Bon
# Kevin Morby
# Bobby
# Alpha Wann
# Nekfeu
# Lesram
# Marie Laforêt
# Josephine Foster
# Cabane
# Mattiel
# Fontaines D.C.
# Amen Dunes
# Lebanon Hanover
# Nothing
# Los Outsaiders
# Márcio Local
# Morcheeba
# DEAD * POP
# Mystic Braves
# Palace
# Thom Yorke
# Richie Campbell
# The xx
# O Terno
# Neon Dominik
# Blossoms
# Natiruts
# John Mayer
# Spacemen 3
# Krakow Philharmonic Chorus
# Quantic
# Paul McCartney
# Vegyn
# Dennis Wilson
# Gia Margaret
# Joachim Cooder
# Black Country, New Road
# Other Lives
# Lanterns on the Lake
# The Innocence Mission
# Julian Lage
# The Meters
# Ann Peebles
# Funkadelic
# Dinah Washington
# Tito Puente
# Wes Montgomery
# Abbey Lincoln
# The Metronome All-Stars
# Tommy Flanagan Trio
# Louis Armstrong
# John Coltrane
# The Gil Evans Orchestra
# Thelonious Monk
# Sonny Clark
# Charles Mingus
# Peggy Lee
# Blundetto
# Nina Simone
# Chris Stapleton
# CCCP Fedeli Alla Linea
# Clams Casino & Imogen Heap
# Atoms for Peace
# Ella Fitzgerald & Louis Armstrong
# Jorge Ben
# The Cinematic Orchestra
# Cigarettes After Sex
# Gal Costa
# Secos e Molhados
# Szabó Benedek és a Galaxisok
# Mazzy Star, Hope Sandoval & David Roback
# City and Colour
# Luciano Ligabue
# Lescop
# CSS
# Sarah McLachlan
# Thea Gilmore
# Jen Cloher & The Endless Sea
# Tebi Rex
# Alanis Morissette
# Gemma dunleavy
# Ian Brown
# The Field Mice
# James
# Alex Turner
# The Rolling Stones
# Ella Fitzgerald
# Kevin Penkin
# She & Him
# Travis
# Chromatics
# Shushu
# Phill Niblock
# Horațiu Rădulescu
# Igor Stravinsky
# This Heat
# The Murder Capital
# Arthur Russell
# T-SQUARE
# Casiopea
# 岸正之
# チューリップ
# The Black Crowes
# Megadeth
# Tribulation
# Satchel
# Dead Kennedys
# Misfits
# T. Rex
# The Get Up Kids
# The County Liners
# Smog
# You Man
# Paul McCartney & Wings
# Electric Jalaba
# Chicarica
# Polocorp
# Melby
# SMANDEM.
# Pahua
# The Notwist
# Sibusile Xaba
# King Gizzard & The Lizard Wizard
# Xiu Xiu
# Amor
# Mindy Meng Wang 王萌
# The Afro Soul Prophecy
# 한상원
# 빛과 소금
# Madeline Kenney
# Nagasaki Swim
# No sé a quién matar
# Emily A. Sprague
# Gigi Masin
# Khotin
# Hiroshi Yoshimura
# Domenique Dumont
# Satoshi & Makoto
# Green-House
# Laraaji
# Suso Saiz
# Shinichi Atobe
# Yasuaki Shimizu
# Ulla
# Jonny Nash
# H.Takahashi
# Pauline Anna Strom
# FEMM
# Dokken
# No Buses
# Renata Przemyk
# Front 242
# Daria Zawiałow
# Clan of Xymox
# Aqua
# GusGus
# 2raumwohnung
# Jonathan Shelly
# The Daysleepers
# lovesliescrushing
# Noble Oak
# Dreams We've Had
# Sticky Patterns
# Auscultation
# Blood Cultures
# Hammock
# Lightcraft
# Glaciaere
# Skit
# Megabyte
# Raener
# e.vax
# Lux Ultra
# Com Truise
# Donkeyboy
# Lush
# Ilya Kuznetsov
# Henry Green
# River Tiber
# Matthew J. Rolin
# Harry Nilsson
# Gordon Lightfoot
# Nana Yamato
# Sharon Van Etten
# Karen Dalton
# Renée Reed
# Blanck Mass
# Rachika Nayar
# Cory Hanson
# Jessica Pratt
# The Avalanches
# Donor Lens
# Paul Simon
# Joni Mitchell
# Julie Byrne
# Dan Hicks & His Hot Licks
# Linda Perhacs
# Missy Elliott
# The Books
# Avey Tare's Slasher Flicks
# Battles
# Sleater-Kinney
# 斉藤ノブ
# Hiram Bullock
# 鳥山雄司
# Cesar Mariano & Cia.
# 森園勝敏
# Kiyoshi Sugimoto
# Terumasa Hino Quartet
# Hiroshi Fukumura & Sadao Watanabe
# Donald Byrd
# Prism
# JIRO INAGAKI & Soul Media
# Yoshihiro Naruse
# Jun Miyake
# Naoya Matsuoka & Hidefumi Toki
# Akira Wada
# You & Explosion Band
# Himiko Kikuchi (菊池ひみこ)
# Toshiyuki Honda
# Chikara Ueda & The Power Station
# Naniwa Express
# Boy Katindig
# NORIKI
# Colgen Band
# Yoshiaki Masuo
# 大村憲司
# Akira Ishikawa & Count Buffalos
# Toshiyuki Honda & Burning Waves
# Space Circus
# Black Fly
# Otto
# Cliff Martinez
# Riz Ortolani
# Electric Youth
# Desire
# Kavinsky
# Petey
# Special Interest
# Mother Mother
# Salem
# Zheani
# Ecco2K
# Shovels & Rope
# LustSickPuppy
# Juno Roome
# Jónsi
# Lovedrug
# Rickolus
# Eddy Baker
# Manuel Straube
# The Blaze
# Kishi Bashi
# Il Ghost
# Snakehips
# Big Thief
# Marteria
# Ethan Fields
# Poshlaja Molli
# Sheryl Crow
# Angèle
# Wild Rivers
# Sega Bodega
# Lake Street Dive
# Shawn Mendes
# Swan Lingo
# Nicholas Britell
# Pusha T
# St. Paul & The Broken Bones
# Mommy Long Legs
# Hurray For The Riff Raff
# Best Coast
# Killer Mike
# Run the Jewels
# BROCKHAMPTON
# Injury Reserve
# Joey Purp
# clipping.
# Czarface
# THEY.
# Stephen Barton
# They Might Be Giants
# Guided by Voices
# Marty Robbins
# White Reaper
# Plumtree
# Heatmiser
# Speedy Ortiz
# Charly Bliss
# Liz Phair
# Whitmer Thomas
# The Angels of Light
# Crash Test Dummies
# Delerium
# Hardwell
# Converge
# Eric B. & Rakim
# Bone Thugs-N-Harmony
# Big Daddy Kane
# Ice Cube
# Ice-T
# Eazy-E
# Souls of Mischief
# Pete Rock
# Artifacts
# GZA
# Gang Starr
# Mobb Deep
# Sir Mix-A-Lot
# Fugees
# Nas
# Scarface
# Danny Brown
# Bella Boo
# Ringo Deathstarr
# The Brat
# The Bilinda Butchers
# Laibach
# Jorge Elbrecht
# The Dead Texan
# Slim Guerilla
# Johanna's House of Glamour
# The Boo Radleys
# The United States of America
# Rumskib
# The Death Of Money
# Technotronic
# Akaitsuki
# Sewerslvt
# The Mamas & the Papas
# Lycia
# Crash City Saints
# Tegan Northwood
# Ariel Pink
# Lil B
# Mario Judah
# Marissa Nadler
# Lawrence Rothman
# Motörhead
# John Prine
# 池田典代
# Ino Hidefumi
# 松任谷由実
# S. Kiyotaka & Omega Tribe
# Akina Nakamori
# Momoko Kikuchi
# Akiko Wada
# Yuri Tanaka
# 杏里
# Kingo Hamada
# Naomi Akimoto
# Junko Ohashi
# Taeko Onuki
# Makoto Matsushita
# Sadistics
# MINAKO YOSHIDA
# 1986 OMEGA TRIBE
# Jamiroquai
# 工藤静香
# Sumiko Yamagata
# Junko Hirotani
# Yumi Murata
# 今井裕
# Masayoshi Takanaka
# Piper
# Akira Terao
# Yuki Saitou
# Iyo Matsumoto
# Yu Hayami
# Spectrum
# Kei Ishiguro
# Hiroshi Sato
# 尾崎亜美
# 秋元薫
# 鄧麗君
# 岩代太郎
# 장현
# 윤승희
# Banda Calypso
# MC Kevin O Chris
# O Playboy
# Bree Runway
# MC Loma e as Gêmeas Lacração
# MC Abalo
# Biel Xcamoso
# Santigold
# Banda Sentimentos
# Luísa Sonza
# Shevchenko e Elloco
# Ms Nina
# Sebastian Yatra
# Luísa e Os Alquimistas
# MC Dricka
# Jhay Cortez
# Os Barões Da Pisadinha
# Maria Gadú
# Dover
# Los Bravos
# Shamir
# cupcakKe
# Destiny's Child
# Mabel
# Caroline Polachek
# Kelela
# Hannah Diamond
# Stoned Mazes
# MØ
# Ross From Friends
# Shed
# Azealia Banks
# Claude Fontaine
# Adrenalize
# Bat for Lashes
# Dougal / Da Tweekaz
# Da Tweekaz / Code Black / GPF
# Rooler
# La Oreja de Van Gogh
# Bob Marley
# Nana Mouskouri
# IAM
# makla
# Carla dal Forno
# Kaoma
# Glee Cast
# Dan Black feat. Kelis
# Computer Magic
# Da Tweekaz
# Janie
# Céline Dion
# Greazy Puzzy Fuckerz
# Sickmode
# Bill Medley
# Psyko Punkz
# Major Lazer
# Jasper Forks
# Barely Alive
# Clara Luciani
# Sato Goldschlag
# MIZZ BEHAVE
# Lost Horizons
# LNY TNZ
# Jenny Lewis
# Inquisitive
# Ganges
# Funky Craig
# FRUTi
# DuckworthSound
# Dither
# Mourning A Blkstar
# Barker
# Peel Dream Magazine
# Moses Boyd
# His Name Is Alive
# Non Square
# ZELMA STONE
# omma
# Vula Viel
# Caribou
# Sky Civilian
# Rival Consoles
# Lightning Bug
# Fools
# Matt Karmil
# BOOF
# Beastie Boys
# Carne Doce
# Boy
# Boogarins
# Moby
# Little Dragon
# Johnny Hooker
# Djo
# Vanguart
# Tiago Iorc
# Rubel
# Onze:20
# 安東ウメ子
# 東海林修指揮 コロムビア・ミリオン・ポップ管弦楽団
# DATS
# Jesse Kivel
# SPC ECO
# Peace
# Beryl Booker
# The KLF
# The Justified Ancients of Mu Mu
# Blind Willie Johnson
# Mission of Burma
# Akhlys
# Oceansize
# Osi
# Riverside
# Katatonia
# Sandy Denny
# Marianne Faithfull
# Sinéad O'Connor
# Fotheringay
# Fairport Convention
# 秋本奈緒美
# Mico
# 南沙織
# The 5.6.7.8's
# Urszula Dudziak
# Basia
# 浜崎あゆみ
# Rosalia
# THE CARTERS
# Faith Evans
# EXO
# SHINee (샤이니)
# Grace Jones
# Utada Hikaru
# Paradis
# Crystal Kay
# Matsubara Miki
# Matsutoya Yumi
# 빈지노 (Beenzino)
# 프라이머리, 오혁
# Teyana Taylor, Kehlani
# 아이유
# 八神純子
# Alessandra Mussolini
# 国分友里恵
# Prefab Sprout
# Janet Jackson
# The Doors
# Biosphere
# Rachel's
# Laura Stevenson
# Molly Sarlé
# Mimi Gilbert
# Damien Jurado
# Samantha Crain
# The Slaps
# Hope Sandoval and The Warm Inventions
# Bon Iver
# Sun Kil Moon
# Black Marble
# Tears for Fears
# Deacon Blue
# Talk Talk
# Shriekback
# Propaganda
# Blancmange
# It's Immaterial
# Orchestral Manoeuvres in the Dark
# The Human League
# The Cult
# Frankie Goes to Hollywood
# Tubeway Army
# Ultravox
# Visage
# Mobiles
# Poco
# Seal
# Four Tet
# Macross 82-99
# The Rapture
# Eurythmics
# Natalie Imbruglia
# Roxette
# Chaka Khan
# Minnie Riperton
# Cheryl Lynn
# Matt Berninger
# Rubio
# Shy Boys
# Interpol
# Julia Stone
# The Postal Service
# The Cribs
# VENUS BLEEDS
# ✝✝✝ (Crosses)
# Lou Phelps
# Rainbow Kitten Surprise
# Andy Shauf
# Monocular Man
# Brooke Candy
# Ghostemane
# Kim Carnes
# Guy Mitchell
# Extreme
# Brides of Destruction
# Red Simpson
# Johnny Horton
# The Brothers Johnson
# Internet Money
# The Kid LAROI
# 6ix9ine
# Tommy Bolin
# Michael Angelo Batio
# Mr. Big
# White Lion
# Three Days Grace
# Breaking Benjamin
# Hinder
# Theory of a Deadman
# Slim Dusty
# Richard Pryor
# The 12th Man
# Rodney Rude
# The Meatmen
# The Gothic Archies
# The Stone Roses
# Courtney Love
# Velvet Revolver
# The ARC Gospel Choir
# Ed Askew
# Hackamore Brick
# Cheryl Dilcher
# Massacre
# Michael Brun
# Devil Sold His Soul
# Alcest
# Steven Wilson
# Bill Wurtz
# Melt Yourself Down
# KonstruKt
# Last Exit
# Albatre
# Merkabah
# Lonker See
# The Comet Is Coming
# Fire!
# Blood Quartet
# U.S. Maple
# Cardiacs
# Lena Raine
# Emilie Nicolas
# Joesef
# superb lyres
# Izumi Makura
# Charlotte dos Santos
# Henry Mancini
# Girls Names
# 小久保隆
# Warmth
# Lauren Auder
# Nathy Peluso
# John Carroll Kirby
# Alice Dj
# Television
# Katie Dey & Lonelyspeck
# Derrick Harriott
# Barry Biggs
# Dennis Brown
# Devon Russell
# Don Carlos
# Michael Kiwanuka
# Yves Jarvis
# Ana Roxanne
# Jyoti
# Buck Meek
# Lomelda
# Snow Patrol
# Dessa
# The Cranberries
# Cem Karaca
# Steve Earle
# Yellow Ostrich
# Amy Annelle
# Jason Isbell
# Small Faces
# The Amazing
# Son Volt
# Cody Canada & The Departed
# The Magic Numbers
# Doug Seegers
# Vic Chesnutt, Jack Logan, and Mr. and Mrs. Keneipp
# Plants and Animals
# Stone Temple Pilots
# The Kills
# The Thermals
# Dark Dark Dark
# Valerie June
# Stevie Ray Vaughan
# The Pines
# Laura Cantrell
# El-P
# Kula Shaker
# Sturgill Simpson
# Colvin & Earle
# Marshall Crenshaw
# Van Morrison
# Ezra Feinberg
# Carmen Villain
# Joséphine Baker
# Stephane Wrembel
# Jazz At Lincoln Center Orchestra
# Jimmy Smith
# Solomon Burke
# Crosby, Stills & Nash
# Martin Luther King, Jr.
# The Ink Spots
# Bronwynne Brent
# The War and Treaty
# James Carr
# Ted Lucas
# Rónán Ó Snodaigh
# The Fureys
# Thin Lizzy
# Stiff Little Fingers
# Dry Cleaning
# The Searchers
# Janis Joplin
# Orgone
# Los Lobos
# Novalima
# Nicola Cruz
# Nubya Garcia
# Amy Speace
# Dolly Parton
# The Osborne Brothers
# Balsam Range
# Doc Watson
# William Elliott Whitmore
# Bonnie Raitt
# Holly Golightly
# Courtney Marie Andrews
# Tim Easton
# Ana Egge
# Roo Panes
# Kurs Valüt
# Creedence Clearwater Revival
# Dear Reader
# BBC Radio 4
# Axel Flóvent
# Quickbeam
# Vivin
# Elder Island
# Tigers That Talked
# Golden Kanine
# VLMV
# Celestial Aeon Project
# Sleeping at Last
# Omar Linx
# BlackSilence
# viiGo
# Gil Glaze
# Betty Who
# Fisher
# Tanita Tikaram
# Melanie C
# Matt Fax
# Kaskade
# Harley Sanders
# Galardo
# Josh McKenzie
# Yotto
# Christian Burns
# Trilucid
# Ben Böhmer
# Klur
# Darla Jade
# Bandēs
# Praana
# Dezza
# Nora En Pure
# Estiva
# King & Early
# Passenger 10
# Ali Bakgor
# Cassian
# Terry Da Libra
# Tommy Baynen
# Henri (BR)
# Fulltone
# Gabriel & Dresden
# RAYE
# Afrojack
# Peking Duk
# Tinie Tempah
# Evvy
# Alex Adair
# Lauren Aquilina
# Giorgio Moroder
# Dr. Kucho!
# Shaun Frank
# TOO MANY ZOOZ
# Matthew Koma
# Rita Ora
# Amtrac
# Vice & Caitlyn Scarlett
# Dimitri Vegas & Like Mike
# Conrad Sewell
# Phases
# Sam Sure
# Borgeous
# Kevin Drew
# Lady Bee
# Eche Palante
# TCTS
# ZHU
# ATB
# Cazzette
# Meghan Trainor
# Bob Sinclar
# Iwona Węgrowska
# Miuosh
# Brathanki
# Bajm
# Sanah
# Savage Garden
# Marcin Sójka
# Grzegorz z Ciechowa
# Mylène Farmer
# Ricky Martin
# Golec uOrkiestra
# Kate Ryan
# Reyko
# Mary J. Blige
# No Angels
# Lady Pank
# Męskie Granie Orkiestra
# Katarzyna Skrzynecka
# Włodi
# Edyta Gorniak
# Andrzej Piaseczny
# Hey
# Dolores O'Riordan
# Anna Jantar
# Joanna Dark
# Sidney Polak
# Budka Suflera
# Sweet Noise
# Krzysztof Zalewski
# Józefina
# thekayetan
# Geri Halliwell
# Cheryl
# Siostry Melosik
# Gossip
# Eagles
# Junior Byles
# The Frightnrs
# Ansel Collins
# Phyllis Dillon
# Alton Ellis
# The Uniques
# Max Romeo
# Carlton and The Shoes
# Dandy Livingstone
# Cornell Campbell
# Kranium
# Tarrus Riley
# Jada Kingdom
# Kes
# Juicy J
# Jetty Bones
# hospital bracelet
# Bonsai Mammal
# Maverick Sabre
# Alok
# Bruno Martini
# Sam Feldt
# Terror Jr
# AlunaGeorge
# K/DA
# Hailee Steinfeld
# Benny Blanco
# DJ PoolBoi
# Nilüfer Yanya
# NewDad
# Beach Bunny
# Oscar Lang
# Bakar
# Dayglow
# Dylan Fraser
# Laura Elliott
# Lo Village
# Ron Gallo
# Anna of the North
# Amber Mark
# Marika Hackman
# Lord Huron
# Yoke Lore
# Trace
# The Marías
# Zella Day
# Kate Nash
# OK Go
# La Roux
# Cage the Elephant
# Hard-Fi
# The Hives
# The Fratellis
# Jamie T
# The Ting Tings
# Lauren Jauregui
# Carrie Underwood
# Maren Morris
# George Ezra, First Aid Kit
# Miriam Bryant
# Sara Bareilles
# Lana Del Rey, The Weeknd
# Beyoncé, Sharon Leal, Anika Noni Rose
# Blue Ivy, SAINt JHN, Beyoncé, WizKid
# Salatiel, Pharrell Williams, Beyoncé
# Beyoncé, Jay-Z & Childish Gambino feat. Oumou Sangare
# Beyoncé, Kendrick Lamar
# MUNA
# LE1F
# Jessica Winter
# Trophie
# Brevin Kim
# Declan McKenna
# Choir Boy
# Buddy ROSS
# DYLIS
# Wave Racer
# Princess Nokia
# Julian Lamadrid
# RMR
# Underscores
# Banoffee
# Girlpool
# Sad Night Dynamite
# Dobi
# Rosa Walton
# Nicholas Braun
# Bickle
# biianco
# The High Kings
# Howard Shore
# Natalia Gordienko
# Marvel83'
# MIRUD
# Raylee
# Zena
# Barbara Pravi
# Seemone
# Alma
# Patricia Kaas
# Damien Rice
# Bachelor Girl
# Whitney Houston
# Tina Arena
# Crowded House
# Delta Goodrem
# Gwen Stefani
# The Paper Kites
# No Mercy
# Amy Grant
# Leonardo's Bride
# Dido
# Natalie Merchant
# Human Nature
# Tony Bennett
# Wanessa Camargo
# Andrew W.K.
# The Presidents of the United States of America
# Electric Six
# Pixies
# Cut Copy
# Saint Motel
# Lefti
# Eleni Foureira
# Leni, Seppo ja Vuosaaren lastentarhan lapset
# Beatrich
# Monique
# Shy Luv
# Munamies
# Penguin Prison
# Suomalaisia Lastenlauluja
# Muuan Mies
# Mikko Alatalo
# Peter Bjorn and John
# potsu
# Imagine Dragons
# Creed
# Evanescence
# 3 Doors Down
# A Perfect Circle
# Puscifer
# Portwave
# Broken Back
# Hatari
# Mujuice
# NYVES
# TV on the Radio
# And One
# Sebastian
# Melodicka Bros
# The Birthday Massacre
# Emilie Autumn
# Baasch
# Aesthetic Perfection
# Zeromancer
# Cyber
# IAMX
# Spoon
# Fischerspooner
# Wulfband
# Kirin J Callinan
# Dernière Volonté
# Azyl P
# AD:keY
# Cabaret Nocturne
# Diane Shaw
# Davido
# Allen Stone
# oso oso
# India.Arie
# Moor Mother
# Galcher Lustwerk
# Lenny Kravitz
# Tonéx
# Ledisi
# Justin Nozuka
# Busta Rhymes
# Dondria
# Quavo
# Beyoncé, JAY-Z & Childish Gambino
# Sam Smith
# Rascal Flatts
# Joanna
# Saint DX
# Miel De Montagne
# Moussa
# Pierre Lapointe
# Foé
# Clement Bazin
# Pas Sages
# Bleu Toucan
# Claire Laffut
# Luxury Elite
# Thylacine
# Algora
# ionnalee
# Pouvoir Magique
# Real Lies
# Dance Yourself Clean
# Celli
# CURTIS WATERS
# Andy Stott
# Sault
# Regard
# Tones and I
# Windsor Drive
# Augustana
# Jeremy Zucker
# Angus Maude
# Hannah Grace
# The Knocks
# NOFX
# Flow
# Home Free
# Carousel Casualties
# Kina Grannis
# Bloc Party
# OutKast
# Klaxons
# The La's
# Tom Aspaul
# Georgia
# Gabrielle Aplin
# Ross Quinn
# Baby Queen
# Sonikku
# Bananarama
# Donna Lewis
# Girls Aloud
# Sophie B. Hawkins
# Cyndi Lauper
# Jessica Simpson
# Siobhan Donaghy
# Exposé
# Taylor Dayne
# Jellybean
# Evelyn Thomas
# Donna Summer
# King Princess
# Ambar Lucid
# Remi Wolf
# Rubblebucket
# Tash Sultana
# Nomi Ruiz
# En Vogue
# Litany
# Queen Latifah
# ELSZ
# PawPaw Rod
# 3LW
# Earth, Wind & Fire
# Lil Mosey
# Robin Schulz
# Village People
# Master KG
# Indochine
# Tal
# salem ilese
# Lara Fabian
# Kid Francescoli
# Zazie
# Louane
# Paul Woolford
# Will to Power
# Bon Entendeur
# Jessica Mauboy
# Jenifer
# Marc Lavoine
# Liam Payne
# Bigflo & Oli
# Martin Solveig
# The Paradise
# Blue Öyster Cult
# Makeup and Vanity Set
# Gemini Rising
# In the Valley Below
# Far Caspian
# Alicks
# peach tinted
# Void Vision
# De Lorra
# NAVVI
# Club Intl
# TREGS
# Jadu Heart
# weird inside
# ESPRIT 空想
# Kevin Krauter
# Gesaffelstein
# Admo
# Avril Lavigne
# Marina and the Diamonds
# Jax Jones & Au/Ra
# Allie X
# A Day to Remember
# Korn
# Dawid Podsiadło
# Clock Machine
# Ghost
# Ramin Djawadi
# Sia
# Tarja
# Farben Lehre
# Shinedown
# Kamp!
# New Years Day
# Five Finger Death Punch
# Larissa Manoela
# BFF Girls
# Taryn Szpilman
# Mariana Feo
# Cidalia Castro
# Carol & Vitoria
# Taryn Spilzman
# Myra Ruiz
# Any Gabrielly
# Lara Suleiman
# Daniel Garcia
# Now United
# I.M. YisraEl
# Cro
# Howard Carpendale
# Die Prinzen
# Yulianna Karaulova
# Iryna Fedyshyn
# Lauren Cimorelli
# Lina
# Gamazda
# DJ HARK
# Die Toten Hosen
# Julia Westlin
# Nick Howard
# Tyler Ward
# 48K
# Anna Graceman
# Taylor Davis
# Sabrina Carpenter
# Insane Driver
# Boyce Avenue
# Kristína
# KT Tunstall
# One Voice Children's Choir
# The Fray
# Christina Perri
# Bahamas
# Digable Planets
# Common
# The Greeting Committee
# Langhorne Slim
# Terrace Martin
# Mt. Joy
# Cat Clyde
# Lucius
# Rostam
# Hiss Golden Messenger
# I'm With Her
# The Wood Brothers
# Whitney
# Nathaniel Rateliff & the Night Sweats
# Punch Brothers
# Blackalicious
# Gregory Alan Isakov
# The New Basement Tapes
# Wilco
# Courtney Barnett
# Gillian Welch
# Dr. Dog
# The Secret Sisters
# The Avett Brothers
# Mountain Man
# The Head and the Heart
# Haley Heynderickx
# Loma
# British Theatre
# Vennart
# Son Lux
# Voyagers of Icarie
# Deradoorian
# Oneohtrix Point Never
# Beak>
# Pram
# Pose Dia
# The Soft Moon
# KAS:ST
# CamelPhat
# Fisz Emade Tworzywo
# Kapela ze wsi Warszawa
# Leon Bridges
# The Dear Hunter
# Polyphia
# Olly Steele
# Bonobo
# Blackbird Blackbird
# A. Nayaka
# $uicideboy$
# Juice WRLD
# Elephant Kind
# Sofia Mills
# Matter Mos
# Mario Zwinkle
# kevin b
# Laze
# Basboi
# Envy*
# Rich Brian
# Colorfactory
# Luke Faulkner
# olim
# Mario Viñuela
# Karen Kasper
# Ever So Blue
# Orlene de Brisay
# Maik Kuefer
# Jamie Bendrodt
# Valérie Beaumont
# Frederiq
# Echoes Red
# Zygmunt Czarnecki
# Jakob Ahlbom
# Leonardo Cupelli
# Mactominie
# Minnie Scolanti
# Nicola conti
# Demi Waters
# Fredrik Lundberg
# Lucién
# Carl Easterling
# Mauvais Roger
# Sub-City Keys
# Vita Menzer
# Sumsar
# Pacific Humble
# Crimson Memoirs
# Jacob LaVallee
# Carl Stark Willgold
# Clara Adeline
# Matthew Mor
# Steve Jones Swiff
# Geir Gudmundson
# Ava Cerasoli
# Ingegerd Margaux
# Csizmazia Etel
# Daniel Paterok
# Mark Mintuny
# Santo Trevisani
# Daniella Babbitt
# Esme Sanford
# Gavin Luke
# 21 Juin le Duo
# Big Daddy Karsten
# Casanova
# Gengahr
# Joe Goddard
# Moon Boots
# Cosmo's Midnight
# Will Joseph Cook
# Juliette Moraine
# Andriamad
# PONY X
# Laurel
# Biig Piig
# Christine and the Queens
# Miami Horror
# Leighton Meester
# Jake Owen
# Nikki Williams
# Gwyneth Paltrow
# Jim Croce
# Athlete
# Made famous by Black Eyed Peas
# Unnveig Aas
# Alex Vargas
# Marc Anthony
# Lostprophets
# Jack Savoretti
# Drexciya
# Elecktroids
# Transllusion
# Cygnus
# DMX Krew
# D'Arcangelo
# Der Zyklus
# LAUER
# Taz & Meeks
# A Sagittariun
# Mount Kimbie
# Aleksi Perälä
# WATCHING AIRPLANES
# Marco Bernardi
# The Abstract Eye
# Severed Heads
# object blue
# D'Marc Cantu
# Computer Says NO
# N.Y House'n Authroity
# Oliver Coates
# System Olympia
# Efdemin
# De Leon
# Madalyn Merkey
# AKSK
# Mansfield.TYA
# WWWater
# Charlotte Adigéry
# Lynks
# Leonie Pernet
# Okay Kaya
# Cindy
# Mica Levi
# Pampa Folks
# Chevalrex
# The Dogs
# Pascal Comelade & Richard Pinhas
# Jonathan Bree & Trztn
# Cool Sounds
# Water From Your Eyes
# Elles & Violet
# Shame
# Midnight Sister
# Alex Loveless
# Pom Poko
# Pillow Queens
# Badge Époque Ensemble
# Bill Callahan & Bonnie "Prince" Billy
# Landshapes
# B77
# Human Barbie
# Anne Sylvestre
# Tim McGraw
# Eric Paslay
# Chris Young
# Lindsay Ell
# #1 Garth Brooks Tribute Band
# Morgan Wallen
# Chase Rice
# Brett Young
# Ashley McBryde
# Jason Derulo
# Colbie Caillat
# Papon
# Dallas Smith
# Sonu Nigam
# Jason Aldean
# David Lee Murphy
# Chris Janson
# Jasmine Thompson
# Meghan Patrick
# Arijit Singh
# Luke Combs
# Loscil
# Machinefabriek
# José González
# Eels
# The War on Drugs
# Zero 7
# Pain of Salvation
# John Martyn
# High Skies
# Thomas Newman
# Liquid Tension Experiment
# Onda Vaga
# Nacho y Los Caracoles
# Devendra Banhart
# BaianaSystem
# Miike Snow
# Buddy Holly
# Boards of Canada
# Buscabulla
# Miles Davis
# Dave Brubeck
# Isaac Delusion
# Tegan and Sara
# La Femme
# Cazuza
# Angus & Julia Stone
# Foxygen
# Good Morning
# Big Star
# The Crystals
# The Flaming Lips
# Nouvelle Vague
# Lou Reed
# Frédéric Chopin
# The Ronettes
# Michael Thompson Band
# Harpers Bizarre
# Buffalo Springfield
# Moby Grape
# The Tikis
# The Beau Brummels
# The Darkness
# Fraidy Katt
# The Struts
# John Frusciante
# Hurricane
# Guns N' Roses
# Dirty Shirley
# Stand Atlantic
# Volbeat
# Hard-Ons
# Lynch Mob
# Thomas Zehetmair & Malcolm Frager
# Lo-tel
# Jason Bieler And The Baron Von Bielski Orchestra
# Tool
# Rage Against the Machine
# Slipknot
# Rammstein
# Death
# Gojira
# Slayer
# Ozzy Osbourne
# Kreator
# Iron Maiden
# Judas Priest
# Children of Bodom
# Necrophagist
# Opeth
# Animals as Leaders
# Deafheaven
# Neil Young
# Rush
# Break & DLR
# Matrix
# Bad Company UK
# Loxy & Ink
# Ram Trilogy
# Dub Elements & Flite
# Fred V
# Steve Earle & The Dukes
# Kataklysm
# Cannibal Corpse
# Meshuggah
# Limp Bizkit
# AC/DC
# Indila
# Maître Gims
# Videoclub
# Yelle
# Florina
# Neovaii
# Millbrook
# Axwell Λ Ingrosso
# Meltt
# The Babe Rainbow
# Blindside
# Fuel
# Hotwire
# The Professionals
# Deep Purple
# Boney M.
# Dennis Coffey & The Detroit Guitar Band
# volcano!
# Marnie Stern
# The Fall of Troy
# The Blood Brothers
# Melt-Banana
# Frances Quinlan
# The Lovely Eggs
# The Wanted
# Koop
# Charles Bradley
# The Police
# George Harrison
# Abhijeet Bhattacharya
# Cream
# Bazzi
# Mukesh
# Talat Mahmood
# Kishore Kumar
# Lata Mangeshkar
# Salma Agha
# Jagjit Singh
# Hemlata
# Kumar Sanu
# Mohammed Rafi
# Anup Ghoshal
# The Local train
# Lost Frequencies
# Kiko Barba
# Siouxsie
# Macklemore
# Sean Kingston
# Ahanu
# Brookes Brothers
# Bob Marley & The Wailers
# Etta James
# Bongeziwe Mabandla
# Calibre
# George Jackson
# Lee "Scratch" Perry
# Break
# Larkin Poe
# Brady Watt
# Jamie Cullum
# Bernard Purdie
# Andrew Jackman
# Sam & Dave
# Mac Ayres
# BJ The Chicago Kid
# JP Cooper
# Kiiara
# Jonas Blue
# Michael Bublé
# John Legend
# Kelly Clarkson
# Kungs
# Rag'n'Bone Man
# American Authors
# Jason Mraz
# Mr. Probz
# Calum Scott
# The Shortwave Set
# Avi Buffalo
# Baxter Dury
# Rolling Blackouts Coastal Fever
# The Earlies
# Pottery
# BC Camplight
# Porridge Radio
# Sir Was
# Do Nothing
# Sorry
# Sleaford Mods
# Sink Ya Teeth
# Whyte Horses
# Holy Fuck
# Methyl Ethel
# The Album Leaf
# Afterlife
# Big Boi
# Sheer Mag
# Grandaddy
# Chief $upreme
# Rich the Kid
# The 3rd Estate
# Clap Your Hands Say Yeah
# Mike Park
# Meek Mill
# Highup
# AA Sessions
# Hot Chip
# Chess Moves
# Navy Blue
# Dogs Die in Hot Cars
# Paul Simpson
# Dave Matthews Band
# Easy Life
# Renée Elise Goldsberry
# Lin-Manuel Miranda
# Anthony Ramos
# Phillipa Soo
# Original Broadway Cast of Hamilton
# Jonathan Groff
# Christopher Jackson
# Leslie Odom Jr.
# Daveed Diggs
# half•alive
# YEEK
# Oliver Tree
# Hippo Campus
# Still Woozy
# RAT BOY
# Goth Babe
# slowthai
# lausse the cat
# Muzz
# Bedouine
# Flyte
# Julia Jacklin
# Sarah Jaffe
# Starfucker
# Stella Donnelly
# STRFKR
# Wolf Parade
# Amo Amo
# Purple Mountains
# Lucy Park
# Arlo Leclerc
# Julie Doiron
# Parquet Courts
# Mount Eerie
# Life Without Buildings
# Dinosaur Jr.
# Charlotte Day Wilson
# Lia Ices
# Buzzy Lee
# Luke Sital-Singh
# The Orb
# Ride
# Apollo Brown
# Blue States
# Yppah
# Ghost Culture
# 6th Borough Project
# Nevermen
# Dorisburg
# Ulrich Schnauss
# Thorsten Quaeschning
# Plaid
# Project Pablo
# Skee Mask
# Session Victim
# Pye Corner Audio
# Unloved
# The Gaslamp Killer
# K-X-P
# Machinedrum
# Jon Gurd
# The City of Prague Philharmonic Orchestra
# Kriget
# Emma Ruth Rundle
# Portico Quartet
# Adam Horovitz
# Effe
# Kungens Män
# The Peacers
# Here Lies Man
# ///earth///
# Elvis Costello & The Attractions
# Yusuf / Cat Stevens
# The Hold Steady
# Samaris
# Ten Walls
# Bill Evans Trio
# The Weakerthans
# The Wailers
# Mathias Eick
# Jacques Palminger, Erobique
# John Lee Hooker
# MOMOLAND
# Andreya Triana
# MAMAMOO
# Treasure
# BAEKHYUN
# Ha Hyunsang
# Drauve
# Wilbur Soot
# TAEYEON
# HA SUNG WOON
# Esther Rose
# Loona
# Mino
# KARD
# Cubbi
# ONEUS
# Leyla Blue
# Golden Child
# John Splithoff
# Sakiler
# Renunciation
# Bloodkill
# Baest
# Curimus
# Arkayic Revolt
# Sadus
# Doll Skin
# The Misfits
# AFI
# Thursday
# Dope
# Fight Back Mountain
# grandson
# Neck Deep
# Jawbreaker
# Creeper
# Laura Jane Grace & the Devouring Mothers
# Leathermouth
# Enslaved
# Frank Iero
# letlive.
# Michael Nyman
# Edvard Grieg
# Hector Berlioz
# Jason Hawk Harris
# Jon Pardi
# Jesse Daniel
# Charley Crockett
# Mike and the Moonpies
# Randall King
# The Wilder Blue
# Brandi Carlile
# Kenny Chesney
# Brandy Clark
# Justin Moore
# Caleb Lee Hutchinson
# Zach Bryan
# Yola
# Charles Wesley Godwin
# Emily Scott Robinson
# Caitlyn Smith
# Tessy Lou Williams
# Brothers Osborne
# Cody Jinks
# American Aquarium
# Aaron Watson
# Vince Gill
# HARDY
# Jaime Wyatt
# John Baumann
# Eric Church
# Ruston Kelly
# Casey Donahew
# August Alsina
# Lucas Nord
# Agnez Mo
# Tiësto
# Flo Rida
# The Vamps
# Shakka
# Big Time Rush
# 3OH!3
# GASHI
# French Montana
# Bebe Rexha
# Jay Sean
# Tranell
# Tori Kelly
# Justin Timberlake
# Becky G
# Roy Woods
# Lil Tjay
# Chad Tepper
# Bad Child
# ONR
# Mobley
# AJR
# Christian Leave
# Orson Wilds
# YONAKA
# KennyHoopla
# Aaron
# Lupita's friends
# K!ngdom
# Natalia Lafourcade
# Taska Black
# The Royal Concept
# Clarice Jensen
# Tryo
# Love of Lesbian
# Hoshi
# Dreamers
# Papa Roach
# Nikone
# Nacho Vegas
# Hüsker Dü
# Counterparts
# Taking Back Sunday
# Sky Ferreira
# Bob Mould
# Senza
# Catherine Wheel
# Story of the Year
# Coheed and Cambria
# Bullet for My Valentine
# The Devil Wears Prada
# Poppy
# Circa Survive
# BABYMETAL
# PassCode
# Of Mice & Men
# Miss May I
# I See Stars
# Fred V & Grafix
# Macky Gee
# Andromedik
# Andy C
# Sushii Boiis
# Andrei
# Seum Dero
# Vonikk
# Han Young
# Ganja White Night
# Liquid Stranger
# Of the Trees
# Peekaboo
# Luzcid
# Shlump
# LSDREAM
# Mystic Grizzly
# Roney
# Layrz
# New Beat Order
# FELLA
# Nops
# Stefy De Cicco
# Player1
# Agatino Romero
# 24kGoldn
# Maxim Schunk
# Yves V
# Daz Hxxd
# Olivia
# Konomi Suzuki
# Amalee
# 7!!
# Jack's Mannequin
# Something Corporate
# Andrew McMahon in the Wilderness
# You Are Not So Smart
# Mayday Parade
# Jonathan Coulton
# Frank Turner
# Stephen
# The Ready Set
# Ninja Sex Party
# NONONO
# Echosmith
# Leona Lewis
# Renée Fleming
# Ibeyi
# The Decemberists
# Turnover
# Dum Dum Girls
# Band of Horses
# Rilo Kiley
# Against Me!
# Aurora
# Day Wave
# Fréhel
# Thao & The Get Down Stay Down
# Department of Eagles
# Maggie Rogers
# Michigander
# Sleigh Bells
# Spillage Village
# Minus the Bear
# The Range
# Ray LaMontagne
# Owen Pallett
# Neurosis
# The Mountain Goats
# My Little Airport
# U.S. Girls
# ...
# Violet Sands
# Exmag
# Sarah Shook & the Disarmers
# Latroit
# Vektroid
# Kara's Flowers
# The Manhattans
# Lou Rawls
# Earth, Wind  Fire
# Major Harris
# Sly  The Family Stone
# Phyllis Hyman
# Teddy Pendergrass
# Gladys Knight  The Pips
# The Stylistics
# Harold Melvin  The Blue Notes
# Andra Day
# Kimberose
# Sir Woman
# GA-20
# WAYI
# Radiant Children
# Doug Carn
# Angela Sommer-Bodenburg
# Trépano
# Tay Zonday
# Ronaldo e os Impedidos
# Aliados
# Kris Gruen
# INNELLEA
# Zoo Brazil
# Erol Alkan
# Herzel
# Phil Fearon
# NMR Digital
# George Howard
# Al Jarreau
# Kenny G
# Cool Million
# Kenia
# George White Group
# Bill Cantos
# Randy Crawford
# Rex Smith
# Nils
# Chuck Loeb
# Jackiem Joyner
# Brian Simpson
# Paul Hardcastle
# Alex Bugnon
# Norman Brown
# Chris Standring
# Avenue Blue (Featuring Jeff Golub)
# Eric Valentine
# Lee Ritenour
# 3rd Force
# Motiv
# Gydra
# L 33
# Psynchro
# DRS
# Maria Kelly
# Charlie Cunningham
# Vök
# Lew Howard All Stars
# Bob der Baumeister
# Klaus W. Hoffmann und Klaus Neuhaus
# Die Partykids
# Klaus & Klaus
# Derp Brothers
# HGich.T
# Sunbeam
# Future Breeze
# K2
# Les Humphries Singers
# Gus Backus
# Orchester Amper
# Udo Jürgens
# Ursula G. Bach
# Frank Und Seine Freunde
# Frank Zander
# BoomBaptist
# Hulk Hodn
# Elaquent
# Lindsay Munroe
# Ocean Sounds
# Natural White Noise Relaxation
# Rogerio Tutti
# Thomas Tallis
# Joseph Canteloube
# Peter Jacobs
# Ensemble La Partita
# Alexander Glazunov
# DJ Blyatman
# Napom
# Soulji
# Mel Blanc
# Seán Cullen
# Rodney Carrington
# Denis Leary
# Spinal Tap
# Gopnik McBlyat
# davay
# Chesky Records
# John Henry
# Jason Segel
# Elaine Paige
# Cast of RENT
# Bns.
# The Haggis Horns
# Infaas
# Harris Jayaraj
# La Bambas
# Erotic Lounge Buddha Chill Out Music Cafe
# Lord Echo
# Corrine Almeida
# A Man Called Adam
# 80s Casual
# Matty Valentino
# E.M.D.
# Syntax Records
# RedCloud
# FUTURE SHOCK
# Phantom Planet
# Grace City
# Sam Hart
# Stacie Orrico
# The Braids
# Hazel Dickens
# Cary Ann Hearst
# Kenna
# Henry Nowhere
# Paco Versailles
# Mont Duamel
# Running Touch
# Breton
# Kris Bowers
# Jacques Offenbach
# The Jealous Sound
# Knapsack
# Los Fresones Rebeldes
# La Gossa Sorda
# Band à Part
# Paté de Fuá
# La La Love You
# Ellos
# Sílvia Pérez Cruz
# Los Manolos
# Albert Pla
# Profesor Popsnuggle
# Anna Roig i L’ombre de ton chien
# Papa Topo
# Julianne Hough
# Ben Platt
# Ladilla Rusa
# The Voices Of Walter Schumann
# Pee Wee Hunt
# San-Bao
# Maria Daniela Y Su Sonido Lasser
# Carolina Durante
# La Bien Querida
# Antònia Font
# Hidrogenesse
# Axolotes Mexicanos
# Asunción
# The Secret Society
# María José Llergo
# Dani Llamas
# Belako
# Corizonas
# Los Estanques
# Derby Motoreta’s Burrito Kachimba
# Tycho Jones
# merci, mercy
# Pixey
# Master Peace
# Ponme Pepino
# Madee
# The New Raemon
# Miss Caffeina
# Supersubmarina
# Agua Bendita
# Hank
# Fun People
# Gino Paoli
# Urge Overkill
# _juno
# Lluis Llach
# Los Planetas
# Sexy Sadie
# Pleasant Dreams
# Furious Planet
# Violet Cold
# Hands Like Houses
# Future Palace
# Adelyn
# Venues
# Flash Forward
# Our Mirage
# The Beautiful Monument
# Nine Lashes
# Anti-Flag
# Wolf & Bear
# I Am Abomination
# The Bunny the Bear
# Joshua Travis
# Deep as Ocean
# Cane Hill
# FigureItOut
# If I Die First
# Keep Me Alive
# X-Rl7
# Jenny and Johnny
# Danza Reggeton
# Lorna
# Jannette
# Mainstay
# Captain Tractor
# First to Eleven
# Forever the Sickest Kids
# Green River Ordinance
# Falconer
# Fraser Edwards
# Thompson Square
# Barenaked Ladies & The Persuasions
# Darren Styles & Re-con
# Re-Con
# Re-Con & Demand
# Re-Con & Klubfiller
# Clear Vu
# Re-Con, Gammer & Klubfiller
# Darren Styles
# DSR LINES
# Black Machine
# Stats
# Charles B
# Klein & M.B.O.
# The Avalanches; Tricky
# The Avalanches; Sananda Maitreya; Vashti Bunyan
# The Avalanches; Rivers Cuomo; Pink Siifu
# The Avalanches; Pink Siifu
# The Avalanches; Perry Farrell
# Sir Neville Marriner
# Brian Eno / Roger Eno
# Philadelphia Orchestra/Riccardo Muti
# Swing Out Sister
# Dennis Waterman
# Gruff Rhys
# The Christians
# Paul Young
# Mindless Drug Hoover
# Joe McElderry
# Camille and Kennerly
# The Sevateem
# NateWantsToBattle
# Carl Bagge Trio
# Claus Waidtløw
# Trois Amis
# James Jackson Jazz Trio
# Alan Pasqua
# Wildflower Trio
# Holborns
# robert elovsson
# Anita Rosswell
# Marcin Wasilewski
# Lydia Baskow Trio
# Sixth Street Quartet
# The City of Birches
# Marc Copland
# Asi Kaplan Jazz Band
# Rossdale Junction
# The Midnight Quartet
# Henry Lindon
# Keith Jarrett Trio
# Novo Stella
# Fulton Street Players
# Juraj Stanik Trio
# Duponte et Duponte
# Sunday Morning Jazz
# Relajacion Del Mar
# Joel Rosenberger
# the ambient visitor
# Bing Satellites
# Solar Quest
# Dakota Suite
# The Vandellas
# Hattie Littles
# The Sweethearts
# The Surf Bunnies
# The Rev-Lons
# Pat Hunt
# Othello Robertson
# The Mirettes
# Tour-Maubourg
# Nutia
# TEYMORI
# Alligator
# Xenia Rubinos
# sniffle party
# Sharon Forrester
# A.R. Kane
# Evinha
# Portico
# Joe Crepúsculo
# Xoel López
# Zahara
# Kult
# Raz Dwa Trzy
# Nosowska
# siah
# Fabri
# Amanda Shires
# PK tha Finesser
# Melpo Mene
# Sid The Great
# Lyric Jones
# 9th Wonder
# Mama Odé, Reginald Omas Mamode IV & Jeen Bassa
# Maleke O'Ney & DJ Applejac
# Shafiq Husayn
# Busta Rhymes & Q-Tip
# Georgia Anne Muldrow
# Madvillain, Madlib & MF DOOM
# Mike Phillips
# Tall Black Guy Productions
# Dinner Party, Terrace Martin, Robert Glasper, 9th Wonder & Kamasi Washington
# BusCrates
# Tendavillage
# RAE KHALIL
# Potatohead People
# Chris Turner
# Roane Namuh
# Children Of Zeus
# Salaam Remi
# X-Clan
# King Dream Chorus & The Holiday Crew
# PJ Morton
# Donnie
# Pharoahe Monch
# Doug Hammond
# Madeleine Cocolas
# Traces
# Noah B
# Kromestar
# Headhunter
# Harvey Danger
# Richard Bona
# Chuck Brown and the Soul Searchers
# Chuck Brown
# Giles Peterson
# Noro Morales
# Jake One
# N.O.I.A.
# The Vryll Society
# Pigs Pigs Pigs Pigs Pigs Pigs Pigs
# Daniel Johnston
# Black Box Recorder
# Peter Maxwell Davies
# Crushed Beaks
# Andy Bell
# Hella
# Margaret Y Ya
# MC Yogi
# OakTree
# Idioma
# Fyze
# Akal Dub
# Yoni Yarchi
# Goopsteppa
# Aperio
# Totally Enormous Extinct Dinosaurs
# Halogenix
# Ivy Lab
# Terrorizer
# Tim Reaper
# Demolition Hammer
# Necrophagia
# The Physics House Band
# Gray
# Profile, Traumatize
# Rivers Cuomo
# Scarlett Johansson
# Taron Egerton
# Nick Kroll
# Atom TM
# Sing Cast
# Reese Witherspoon
# Hugh Tracey
# Pups Superstars
# Soul Control
# Nathaniel Rateliff
# Tadao Hayashi
# Mitsuaki Kanno
# Microlith
# Jamie Vexd
# Roly Porter
# Malombo Jazz, Malombo
# kirilik
# Binker and Moses
# Alex Banks
# Dark
# Spiral Mercury Chicago / São Paulo Underground Feat. Pharoah Sanders
# Those Poor Bastards
# The Grascals
# Barton Carroll
# Daniel Bachman
# George Thorogood & The Destroyers
# Jerry Reed
# The Earls Of Leicester
# Rebel Son
# Slobberbone
# James McMurtry And The Heartless Bastards
# Lincoln Durham
# Rachel Brooke
# Ylvis
# Lonesome Wyatt and the Holy Spooks
# Lonesome Wyatt
# Modern Mal
# The Dirt Daubers
# Jaran Hereid
# Palodine
# The Handsome Family
# Bob Wayne
# Myssouri
# Walking Backwards
# Oliver Schories & Jan Blomqvist
# Selling, Gold Panda, Jas Shaw
# Galactic Cowboys
# 33.3
# ZX Spectrum Orchestra
# The De Luca Brothers, Alex Britten
# Remnant
# Telstar Ponies
# oMMM
# Baby Chaos
# DJ /rupture
# Add N To (X)
# The Ramones
# 30 Amp Fuse
# Aube
# The Shaggs
# Los Del Rio
# commonalex_
# PSYCHIC LCD
# メガゾーン EX
# Jimpster
# NYKDLN, Linckoln, 회사AUTO, & Psychic LCD
# Mutant Freak
# VANITAS命死
# Pentagram
# OutKast feat. Slimm Calhoun, C-Bone & T-Mo Goodie
# Is Tropical
# Les Savy Fav
# David Rees
# Farees
# James Dean Bradfield
# Plastilina Mosh
# Eskorzo
# Boris Vian
# Celso Piña
# Caos
# Los Amigos Invisibles
# Inspector
# Amistades Peligrosas
# La Mosca Tse-Tse
# Nortec: Bostich + Fussible
# Maldita Vecindad Y Los Hijos Del 5to. Patio
# Illya Kuryaki & The Valderramas
# Fobia
# La Lupita
# Zurdok
# My darling YOU!
# Jerskin Fendrix
# Mo Troper
# Hit The Button Karaoke
# Varry Brava
# Valira
# Moon Taxi
# Kris Kross Amsterdam
# Nek
# Feid
# Juanes
# Addal
# Raumakustik
# Saurom
# Calo
# young tender
# Esteman
# Fanny Lu
# Red Hardin
# Tito "El Bambino"
# Sara Kays
# Jessia
# Wishbone Ash
# Big Little Lions
# Münchener Freiheit
# Climax Blues Band
# Michael McDonald
# Christopher Cross
# tofubeats
# OKAMOTO'S
# mitsume
# odd foot works
# Omoinotake
# DISH//
# chelmico
# クボタカイ
# Kaho Nakamura
# She Her Her Hers
# BREIMEN
# yonawo
# The Sunnys
# Dannie May
# Yusuke Ono
# Nao Kodama
# DADARAY
# TATEANAS
# Tendre
# Mizuki Ohira
# New oil deals
# DinoJr.
# illiomote
# Fyfe
# Low Roar
# Odezenne
# Feu! Chatterton
# Oklou
# Girl Ray
# Saya
# The Bad Plus
# Daniel T.
# Babe Corner
# Monogem
# Lee SuHyun
# Xelli Island
# 171
# Tommy Genesis
# Marcy Playground
# Rodox
# Malfunkshun
# Menswear
# Social Distortion
# THE MARIACHIS
# Urban Dance Squad
# Love Battery
# Seven Mary Three
# Pirâmide Perdida
# Djonga
# Filhos da Grávida de Taubaté
# Sr. Nescau
# DJ Gabriel Do Borel
# Josh Levi
# Santino Le Saint
# Chasinbens
# Bionic
# PriyaTheMystic
# Almondmilkhunni
# Um Milkshake Chamado Wanda
# Igor
# FP do Trem bala
# Needle Points
# The King Khan & BBQ Show
# Broncho
# Spendtime Palace
# The Wytches
# The Strange Boys
# Wavves
# The Shivas
# sandy pussy
# The Black Angels
# Hinds
# Dumbo Gets Mad
# The Spyrals
# Summer Salt
# The Black Belles
# King Tuff
# Tijuana Panthers
# Gap Dream
# Dan Luke and the Raid
# Good Shoes
# Nio Garcia
# Paulo Londra
# dj Luian
# Nicky Jam
# Jay Wheeler
# Metro Station
# Soulja Boy
# House Boulevard
# Jamie Foxx
# Yves Larock feat. Jaba
# LMFAO
# Tina Charles
# Sanny X
# Ms Project
# L'Orchestra Cinematique
# Chor Filharmonii Narodowej
# Indigo Girls
# Noah Guthrie
# Faith Hill
# Glen Hansard
# Tyler Hilton & Bethany Joy Lenz
# The Davey Brothers
# Random Soul
# Musti
# B-Boy Myhre
# Kapteinen
# Henrik Felipe
# Briskeby
# Emily Osment
# Hawthorne Heights
# Vanessa Rangel
# Vitroles
# Carriages
# TransViolet
# The Pack A.D.
# Maurice Williams & The Zodiacs
# Turbowolf
# KingJet
# Pickwick
# Bruce Channel
# Johnny Cosmic
# The Red Arrows
# Dwight Yoakam
# Alison Krauss
# The Reminders
# breathe.
# Xperience
# Ghetto Kumbé
# Iska Dhaaf
# Daisies
# Shade Sheist
# Murs
# Non Phixion
# Styles
# Screwball
# Bahamadia
# Phat Kat
# Paula Perry
# Mood
# Jaz-O & The Immobilarie
# Saukrates
# D.I.T.C.
# Frankie Rose
# MUNYA
# Yeah But No
# THE DIABOLICAL LIBERTIES
# Holy Wave
# COUSIN KULA
# LEADWASH
# Otzeki
# Lyrica Anderson
# Justine Skye
# Chiiild
# Ralph Tresvant
# DJ Chose
# Fivio Foreign
# Camp Lo
# Durand Bernarr
# DaniLeigh
# Ann Marie
# Givēon
# Styles P
# Ella Mai
# Summer Walker, London On Da Track & Chris Brown
# Larry June & Harry Fraud
# Dave East
# Ne-Yo & Jeremih
# Jeremih & Ty Dolla $ign
# PRINCESS PRINCESS
# LINDBERG
# TRF
# Sam Brookes
# Beta Radio
# Mighty Oaks
# Sons of the East
# Blanco White
# Eddie Berman
# Adam French
# Allman Brown
# Duke Boara
# Ezequiel Arias
# Braxton
# Nox Vahn
# Focal Sun
# The Bellamy Brothers
# Captain & Tennille
# Anne Murray
# Lewis Carroll
# Elizabeth Falconer
# David Shaw-Parker
# Beatrix Potter
# Roald Dahl
# Eve Karpf
# Rendezvous At Two
# Jeff Bernat
# Kolateral
# Ivy Sole
# Eryn Allen Kane
# Coeli
# Cid
# Makaya McCraven
# Wynton Marsalis
# Belong
# Glenn Astro
# Carsten Jost
# Indian Wells
# Barney Mcall
# Bruce MacCombie
# Jackson and His Computer Band
# Prodigal
# Kindred The Family Soul
# Kaidi Tatham
# Mike Will Made-It
# Juventa
# Pet Lions
# Amaury Faye Trio
# Cootie Williams & his Rug Cutters
# Barney Bigard & His Jazzopators
# Rex Stewart & His 52nd St. Stompers
# Fletcher Henderson
# Fletcher Henderson & His Orchestra
# Duke Ellington And His Kentucky Club Orchestra
# Duke Ellington & His Harlem Footwarmers
# Mills' Ten Black Berries
# Duke Ellington & His Washingtonians
# Clifford Jordan
# Gene Ammons
# Dizzy Reece
# Clifford Brown
# Dexter Gordon
# Jackie McLean
# Pete La Roca
# Tina Brooks
# Cliff Jordan
# Freddie Redd
# Nat Adderley
# 鈴木 弘
# Marvel Boy
# Simon la letra
# La propia
# Hot16
# Natural Child
# Widespread Panic
# Ulrika Spacek
# Fly Golden Eagle
# Porno for Pyros
# The Glands
# Oliver Wilde
# Thurston Moore
# Future Funk Squad
# The Symposium
# Inner Wave
# Asian Dub Foundation
# Datassette
# Any Trouble
# Future Generations
# Clubfeet
# Young Galaxy
# Brad Sucks
# Janelle Monae
# Realpeople
# The Mavericks
# Van She
# Psychic Twin
# Mark Lee Scott
# Peter Lang
# Stark Sands with Punch Brothers
# Incredible Hog
# Fort Worth Doughboys
# East River Pipe
# Dead Moon
# Souled American
# King Nawahi's Hawaiians
# The Donner Party
# Elmore Williams
# Jonathan Richman
# Sam Dees
# Mason Ruffner
# Madisonville String Band
# Keith Tippett
# Walter And Family
# Roy Smeck
# John Fahey as Blind Thomas
# Willard Grant Conspiracy
# Captain Beefheart and the Magic Band
# Larry Williams
# Ian Hunter
# The Crooked Jades
# Ass Ponys
# Jennifer Gentle
# Opal
# The Stumblin Blox
# Nicki Minaj & Anuel AA
# Dave Edmunds (The Stray Cats)
# Split Ends
# Bonde do Role
# The Canadian Squires
# The Be Good Tanyas
# Marion
# Northern Uproar
# Shed Seven
# Mike Viola
# Gigolo Aunts
# Cleaners From Venus
# The Rulers
# General Public
# Ash
# Christoph Willibald Gluck
# Regina Carter
# The Modern Jazz Quartet
# Eddie Daniels
# David Hazeltine
# Cover Kid
# Loony
# Art Blakey & The Jazz Messengers
# Mal Waldron
# Dave Holland Quartet
# Geotic
# Gatas Parlament
# Strauss Sr.
# Karen O and the Kids
# Handel
# Kikujiro
# Fresku
# Alex Kresovich
# Bill Staines
# The Hood Internet
# Rick Zieff
# Kat Cressida
# Eternal Tapestry
# Umberto
# Life Coach
# Marisa Anderson
# Plankton Wat
# Sarah Louise
# George Clanton, Nick Hexum
# Donell Jones
# Sisqo
# Covet
# Title Fight
# Patti Lasalle
# *Ancients
# Anja Schneider
# Casey Edwards
# Stone from the Sky
# Radio Bagdad
# Už Jsme Doma
# Melissa Etheridge
# Joseph Arthur
# Mike Mains & The Branches
# Minmae
# Spoek Mathambo
# Xperiment
# Tyagaraja
# Thee Headcoatees
# Masked Intruder
# The Interrupters
# Carlos Ponce
# Example
# Bowland
# Måneskin
# Erreway
# Robosonic
# Jonathan Johansson
# Menahan Street Band
# Dorothy Ashby
# David Axelrod
# Powder! Go Away
# Mekong Airlines
# Slow Grave
# When the Sky Sleeps
# Exxasens
# hubris.
# Tesa
# Distant Dream
# DJ Didilong
# Shanique Marie
# Ani Glass
# Alemayehu Eshete
# salami rose joe louis
# Låpsley
# Tanerélle
# phazz
# CRÁNEO
# Cupido
# Soto Asa
# Pimp Flaco
# Lindsay Lohan
# Asobi Seksu
# Miserable
# Horse Jumper of Love
# Mannequin Pussy
# Tyler Burkhart
# Salvia Plath
# John Andrews & The Yawns
# Cullen Omori
# The Moore Family Band
# Carlos Casas
# Wynonna
# Nate Trillo
# SuBoi
# Bhai Avtar Singh Ragi
# Taylor Deupree & Marcus Fischer
# Paul Schütze
# Bodywash
# Alex Metric
# The Galleria
# White Poppy
# Elkka
# Jasmine Infiniti
# Catch Fire
# throes
# The Offering
# Bury Me Alive
# The Bottom Line
# Lost in Life
# Lena, Felix & die Kita-Kids
# Deutsche Laichen
# Delta Sleep
# Defying Decay
# Deafhex
# KitschKrieg
# Anna Ternheim
# London Symphony Orchestra
# Dolce Diablo
# Chris Jeday
# Sky Rompiendo
# Sfera Ebbasta
# Rainer Brüninghaus
# Steve Roden
# Aoki Takamasa
# Gaetano Partipilo
# Denys Lable
# Louis V Vierk
# Donnacha Dennehy
# The Fear Ratio
# Stella Vander
# Belarisk
# Wouter Veldhuis
# Loess
# Downliners Sekt
# Mad Season
# peter zimmermann
# 1000 Homo DJs
# Spiritual Beggars
# James Ferraro
# Fastgraph
# The Hacker
# Japanese Telecom
# Station Rose
# Pezet-Noon
# Renata Lewandowska
# Les Rythmes Digitales
# Darwin Deez
# D.A.R.K.
# Sr. Chinarro
# Extremoduro
# El Último Vecino
# Cosmen Adelaida
# Cut Your Hair
# Crystal Fighters
# Bran Van 3000
# Tiny Tim
# Phil Phillips & The Twilights
# The Fleetwoods
# Johnny Tillotson
# Ricky Nelson
# Cookiee Kawaii
# Drakkar Nowhere
# Jazz Katt Louis Barnsånger
# Cybotron
# Merit Hemmingson
# Lisa Ekdahl
# Babblarna
# Mora Träsk
# Kompisbandet
# Jujja och Tomas Wieslander
# Astrid Lindgren
# Bjorn Palmberg
# Elever ur Täby Musikklasser
# Homayra
# Elodie Lauten
# Harmonia & Eno '76
# Grace Mitchell
# Max Manie
# Straitjacket Fits
# Hi-5
# Chucho
# Count Basie with His Orchestra
# Andy Ash
# Ike Quebec
# The Night Monitor
# Furniture
# Skylar Gudasz
# Illiterate Light
# Dale Hollow
# Vincent Neil Emerson
# Low Cut Connie
# Aaron Lee Tasjan
# Corb Lund
# Waylon Payne
# Logan Ledger
# The Dirty Knobs
# The Band of Heathens
# Claire Guerreso
# Star Anna
# Les Ya Toupas du Zaire
# Shooter Jennings
# BassBoy
# Anabel Englund
# Reason
# Strawberry Guy
# Tia Gostelow
# The Ben Shapiro Show
# The Postmarks
# Peter Case
# Ben Harper and The Innocent Criminals
# Samson & Gert
# moscoman
# Cam Cole
# illuminati hotties
# Novo Amor
# Gurrumul
# Kučka
# baiuca
# Roma Radz
# Steel Banglez
# Deptford Goth
# Solid Fever
# Bell Orchestre
# Donovan Woods
# Karen Gwyer
# Blood Sport
# Harald Grosskopf
# Skúli Sverrisson
# Frankie Reyes
# Anne Briggs
# Bridget St. John
# Issam Hajali
# Off Course
# Trace Mountains
# Golden
# jerkcurb
# Ace Enders and a Million Different People
# Lydia
# Channing Cope
# Better Off
# Hot Mulligan
# Star You Star Me
# Morgan Geist
# Minizza
# Ricardo Villalobos; Robag Wruhme
# Skatebård
# Justus Köhncke
# Uusi Fantasia
# Sebastian Maschat
# Eliza Legzdina
# Millencolin
# Broken Records
# Girls
# Jimmy Shand
# Lonnie Smith
# Dr. Lonnie Smith
# Kurt Cobain
# Modern Nature
# Factory Seconds
# Timo Lassy
# Anna Domino
# edwynn page
# Roy Montgomery
# DJ Spooky
# Enter an artist's name from the list above:  Anna Domino
# C:\Users\91829\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\loss.py:538: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch 1/1, Loss: 34.02828598022461
# Top recommendations for tracks by Anna Domino: ['Juliet', 'In This Moment', 'In the Moment - Monrroe Remix', 'attitude', "Gary's Theme - Remastered"]

# %% [markdown]
# ### BOOK recommendation using MAML

# %%
# Load the dataset
def load_data(file_path):
    df = pd.read_csv(file_path)
    
    # Ensure that 'average_rating' is a float, handling non-numeric values
    df['average_rating'] = pd.to_numeric(df['average_rating'], errors='coerce')
    df['average_rating'] = df['average_rating'].fillna(df['average_rating'].mean())  # Fill NaNs with mean rating
    
    # Create unique mappings for users and books
    user_to_idx = {user_id: idx for idx, user_id in enumerate(df['userId'].unique())}
    book_to_idx = {book_id: idx for idx, book_id in enumerate(df['bookID'].unique())}
    
    # Map users and books to indices
    user_ids = torch.tensor(df['userId'].map(user_to_idx).values, dtype=torch.long)
    book_ids = torch.tensor(df['bookID'].map(book_to_idx).values, dtype=torch.long)
    ratings = torch.tensor(df['average_rating'].values, dtype=torch.float)
    
    return user_ids, book_ids, ratings, user_to_idx, book_to_idx, df

# Define custom Dataset class
class BookDataset(Dataset):
    def __init__(self, user_ids, book_ids, ratings):
        self.user_ids = user_ids
        self.book_ids = book_ids
        self.ratings = ratings

    def __len__(self):
        return len(self.user_ids)

    def __getitem__(self, idx):
        return self.user_ids[idx], self.book_ids[idx], self.ratings[idx]

# Model definition
class RecModel(nn.Module):
    def __init__(self, num_users, num_books, embedding_dim):
        super(RecModel, self).__init__()
        self.user_embedding = nn.Embedding(num_users, embedding_dim)
        self.book_embedding = nn.Embedding(num_books, embedding_dim)
        self.fc = nn.Linear(embedding_dim * 2, 1)  # Concatenate user and book embeddings

    def forward(self, user_id, book_id):
        user_embed = self.user_embedding(user_id)
        book_embed = self.book_embedding(book_id)
        
        x = torch.cat([user_embed, book_embed], dim=-1)
        return self.fc(x).squeeze()

# Training function
def train_model(model, dataset, epochs, lr, batch_size):
    optimizer = optim.Adam(model.parameters(), lr=lr)
    loss_fn = nn.MSELoss()
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

    for epoch in range(epochs):
        total_loss = 0
        for user_ids, book_ids, ratings in dataloader:
            predictions = model(user_ids, book_ids)
            loss = loss_fn(predictions, ratings)
            
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            total_loss += loss.item()
        print(f'Epoch {epoch+1}/{epochs}, Loss: {total_loss / len(dataloader)}')

# Function to generate recommendations based on user-defined rating threshold
def recommend(model, user_id, book_to_idx, df, rating_threshold=4.0, num_recommendations=5):
    book_scores = []
    for book, book_idx in book_to_idx.items():
        book_id_tensor = torch.tensor([book_idx], dtype=torch.long)
        user_id_tensor = torch.tensor([user_id], dtype=torch.long)
        
        score = model(user_id_tensor, book_id_tensor)
        book_scores.append((book, score.item()))
    
    # Filter books that meet or exceed the rating threshold
    recommended_books = [(book, score) for book, score in book_scores if score >= rating_threshold]
    
    # Sort and get top recommended books
    top_books = sorted(recommended_books, key=lambda x: x[1], reverse=True)[:num_recommendations]
    
    # Retrieve the book titles from the original dataframe
    top_book_titles = df[df['bookID'].isin([book[0] for book in top_books])]['title'].tolist()
    return top_book_titles

# Example usage
file_path = "C:\\Users\\91829\\Downloads\\dataset_zip\\dataset\\Book.csv"  # Path to your dataset file
user_ids, book_ids, ratings, user_to_idx, book_to_idx, df = load_data(file_path)

# Create dataset
dataset = BookDataset(user_ids, book_ids, ratings)

# Initialize the model
embedding_dim = 32
num_users = len(user_to_idx)
num_books = len(book_to_idx)
model = RecModel(num_users, num_books, embedding_dim)

# Train the model
train_model(model, dataset, epochs=5, lr=0.001, batch_size=16)

# Prompt user for rating threshold and recommend books
rating_threshold = float(input("Enter your preferred minimum average rating (e.g., 4.0): "))
user_id = user_to_idx[1]  # Assuming user with ID 1
recommendations = recommend(model, user_id, book_to_idx, df, rating_threshold=rating_threshold, num_recommendations=5)

print(f"Top recommendations for user with a minimum rating of {rating_threshold}:", recommendations)
# Out:
# Epoch 1/5, Loss: 6.310076052751178
# Epoch 2/5, Loss: 0.7211456100895316
# Epoch 3/5, Loss: 0.21767909295492988
# Epoch 4/5, Loss: 0.15106595597690206
# Epoch 5/5, Loss: 0.13186917024471895
# Enter your preferred minimum average rating (e.g., 4.0):  4.0
# Top recommendations for user with a minimum rating of 4.0: ['A Book of Common Prayer', 'The Assignation: Stories', 'Goddess of the Sea (Goddess Summoning  #1)', "Sunny Chandler's Return", 'Practical DV Filmmaking']

# %% [markdown]
# ### BOOK recommendation using REPTILE

# %%
# Load your dataset from a CSV file
df = pd.read_csv('book.csv')  # Replace 'your_dataset.csv' with your actual file name

# Create user and book index mappings
user_to_idx = {user: idx for idx, user in enumerate(df['userId'].unique())}
book_to_idx = {book: idx for idx, book in enumerate(df['bookID'].unique())}

# Recommender Model Definition
class RecommenderModel(nn.Module):
    def __init__(self, n_users, n_books, embedding_dim=8):
        super(RecommenderModel, self).__init__()
        self.user_embedding = nn.Embedding(n_users, embedding_dim)
        self.book_embedding = nn.Embedding(n_books, embedding_dim)
        self.fc = nn.Linear(embedding_dim * 2, 1)  # Output layer for rating prediction

    def forward(self, user_ids, book_ids):
        user_embeds = self.user_embedding(user_ids)
        book_embeds = self.book_embedding(book_ids)
        concatenated = torch.cat([user_embeds, book_embeds], dim=-1)
        return self.fc(concatenated)

# Reptile Class Definition
class Reptile:
    def __init__(self, model, inner_lr, inner_steps):
        self.model = model
        self.inner_lr = inner_lr
        self.inner_steps = inner_steps

    def inner_update(self, task_data, task_labels):
        user_ids, book_ids = task_data  # Unpack the task data
        # Create a new instance of the model for inner update
        task_model = RecommenderModel(n_users, n_books)
        task_model.load_state_dict(self.model.state_dict())
        optimizer = optim.SGD(task_model.parameters(), lr=self.inner_lr)

        for _ in range(self.inner_steps):
            # Forward pass and loss calculation
            predictions = task_model(user_ids, book_ids)
            loss = nn.MSELoss()(predictions.squeeze(), task_labels.float())  # Adjust to squeeze for loss

            # Backward pass
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        return task_model

    def train(self, tasks):
        batch_task_models = []
        for task_data, task_labels in tasks:
            task_model = self.inner_update(task_data, task_labels)
            batch_task_models.append(task_model)

        # Here you can implement the meta-update logic for model aggregation across tasks

# Sample task sampling function
def sample_task(df, user_to_idx, book_to_idx, task_size=5):
    """Sample a task of user and book pairs."""
    sampled_users = df['userId'].sample(task_size).map(user_to_idx).astype(int)  # Ensure integer type
    
    # Sample books
    sampled_books = df['bookID'].sample(task_size).map(book_to_idx)
    sampled_books = pd.to_numeric(sampled_books, errors='coerce')  # Convert to numeric, setting non-convertible values to NaN
    sampled_books = sampled_books.dropna().astype(int)  # Drop NaN values and convert to integer

   

    # Ensure that the index of sampled_books corresponds to df
    if len(sampled_users) != len(sampled_books):
        print("Warning: Mismatch in number of users and books!")
        return None, None  # Or handle the size mismatch according to your logic

    # Get labels and convert to numeric
    labels = df.loc[sampled_books.index, 'average_rating'].values
    labels = pd.to_numeric(labels, errors='coerce')  # Convert to numeric

    # Use NumPy to filter out NaN values
    labels = labels[~np.isnan(labels)]  # Keep only non-NaN labels

    # Convert to PyTorch tensors
    try:
        user_tensor = torch.tensor(sampled_users.values, dtype=torch.long)
        book_tensor = torch.tensor(sampled_books.values, dtype=torch.long)
        labels_tensor = torch.tensor(labels, dtype=torch.float32)
    except Exception as e:
        
        raise e  # Re-raise the exception to stop execution

    return (user_tensor, book_tensor), labels_tensor



# Hyperparameters
num_epochs = 10
tasks_per_epoch = 5
task_size = 5

# Initialize model
n_users = len(user_to_idx)
n_books = len(book_to_idx)
model = RecommenderModel(n_users, n_books)

# Set hyperparameters for Reptile
inner_lr = 0.01  # Inner learning rate
inner_steps = 5  # Inner update steps

# Initialize the Reptile instance
reptile = Reptile(model, inner_lr, inner_steps)

# Training loop
for epoch in range(num_epochs):
    tasks = []
    for _ in range(tasks_per_epoch):
        task_data, task_labels = sample_task(df, user_to_idx, book_to_idx, task_size=task_size)
        tasks.append((task_data, task_labels))
    
    reptile.train(tasks)
    print(f"Epoch {epoch + 1}/{num_epochs} completed.")

# Function to recommend books for a specific user
# Function to recommend books for a specific user based on a rating threshold
# Ensure 'average_rating' is converted to a float and replace non-numeric values with NaN
df['average_rating'] = pd.to_numeric(df['average_rating'], errors='coerce')
df['average_rating'] = df['average_rating'].fillna(df['average_rating'].mean())  # Fill NaNs with the mean rating

# Function to recommend books for a specific user based on a rating threshold
def recommend_books(user_id, min_avg_rating=3.5, n_recommendations=3):
    # Convert user_id to internal index
    user_idx = user_to_idx.get(user_id)
    if user_idx is None:
        print("User ID not found in dataset.")
        return None

    # Filter books based on the average rating threshold
    high_rating_books = df[df['average_rating'] >= min_avg_rating]
    if high_rating_books.empty:
        print(f"No books found with an average rating of {min_avg_rating} or higher.")
        return None

    # Map book IDs to indices and keep only those with valid book indices
    valid_books = high_rating_books['bookID'].apply(lambda book: book_to_idx.get(book)).dropna().astype(int)
    book_indices = torch.tensor(valid_books.values, dtype=torch.long)
    
    # Prepare user input tensor with the same size as book_indices
    user_input = torch.full((book_indices.size(0),), user_idx, dtype=torch.long)
    
    # Predict ratings for each book
    with torch.no_grad():
        predictions = model(user_input, book_indices).squeeze()
    
    # Sort and select top N recommendations
    top_indices = torch.argsort(predictions, descending=True)[:n_recommendations]
    recommended_books = high_rating_books.iloc[top_indices.numpy()]
    
    return recommended_books[['bookID', 'title', 'average_rating']]

# Example usage:
min_avg_rating = float(input("Enter the minimum average rating for recommendations: "))
recommended_books = recommend_books(user_id=1, min_avg_rating=min_avg_rating, n_recommendations=3)
print("\nRecommended Books based on rating:")
print(recommended_books)
# Out:
# Epoch 1/10 completed.
# Epoch 2/10 completed.
# Epoch 3/10 completed.
# Epoch 4/10 completed.
# Epoch 5/10 completed.
# Epoch 6/10 completed.
# Epoch 7/10 completed.
# Epoch 8/10 completed.
# Epoch 9/10 completed.
# Epoch 10/10 completed.
# Enter the minimum average rating for recommendations:  4
# Recommended Books based on rating:
#       bookID                                              title  \
# 8856   34247                 200 Quilt Blocks: To Mix and Match
# 3106   11431       The Red Gloves Collection (Red Gloves  #1-4)
# 481     1533  The Suppliant Maidens/The Persians/Seven again...
#
#       average_rating
# 8856            4.09
# 3106            4.49
# 481             4.10

# %% [markdown]
# ### MUSIC recommendation using REPTILE

# %%
# Load your dataset from a CSV file
df = pd.read_csv("C://Users//91829//Downloads//dataset_zip//dataset//Last.fm_data.csv")  # Replace 'music.csv' with your actual file name

# Create user and track index mappings
user_to_idx = {user: idx for idx, user in enumerate(df['Username'].unique())}
track_to_idx = {track: idx for idx, track in enumerate(df['Track'].unique())}

# Recommender Model Definition
class RecommenderModel(nn.Module):
    def __init__(self, n_users, n_tracks, embedding_dim=8):
        super(RecommenderModel, self).__init__()
        self.user_embedding = nn.Embedding(n_users, embedding_dim)
        self.track_embedding = nn.Embedding(n_tracks, embedding_dim)
        self.fc = nn.Linear(embedding_dim * 2, 1)  # Output layer for rating prediction

    def forward(self, user_ids, track_ids):
        user_embeds = self.user_embedding(user_ids)
        track_embeds = self.track_embedding(track_ids)
        concatenated = torch.cat([user_embeds, track_embeds], dim=-1)
        return self.fc(concatenated)

# Reptile Class Definition
class Reptile:
    def __init__(self, model, inner_lr, inner_steps):
        self.model = model
        self.inner_lr = inner_lr
        self.inner_steps = inner_steps

    def inner_update(self, task_data, task_labels):
        user_ids, track_ids = task_data  # Unpack the task data
        # Create a new instance of the model for inner update
        task_model = RecommenderModel(n_users, n_tracks)
        task_model.load_state_dict(self.model.state_dict())
        optimizer = optim.SGD(task_model.parameters(), lr=self.inner_lr)

        for _ in range(self.inner_steps):
            # Forward pass and loss calculation
            predictions = task_model(user_ids, track_ids)
            loss = nn.MSELoss()(predictions.squeeze(), task_labels.float())  # Adjust to squeeze for loss

            # Backward pass
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        return task_model

    def train(self, tasks):
        for task_data, task_labels in tasks:
            task_model = self.inner_update(task_data, task_labels)

# Sample task sampling function
def sample_task(df, user_to_idx, track_to_idx, task_size=5):
    """Sample a task of user and track pairs."""
    sampled_users = df['Username'].sample(task_size).map(user_to_idx).astype(int)
    sampled_tracks = df['Track'].sample(task_size).map(track_to_idx).astype(int)

    # Ensure that the sampled indices are valid
    sampled_users = sampled_users[~sampled_users.isna()]
    sampled_tracks = sampled_tracks[~sampled_tracks.isna()]

    # Get labels
    labels = df.loc[sampled_users.index, 'rating'].values
    labels = pd.to_numeric(labels, errors='coerce')
    labels = labels[~np.isnan(labels)]

    if len(sampled_users) != len(sampled_tracks) or len(sampled_users) != len(labels):
        print("Warning: Mismatch in number of users, tracks, and labels!")
        return None, None  # Or handle the size mismatch according to your logic

    # Convert to PyTorch tensors
    user_tensor = torch.tensor(sampled_users.values, dtype=torch.long)
    track_tensor = torch.tensor(sampled_tracks.values, dtype=torch.long)
    labels_tensor = torch.tensor(labels, dtype=torch.float32)

    return (user_tensor, track_tensor), labels_tensor

# Hyperparameters
num_epochs = 10
tasks_per_epoch = 5
task_size = 5

# Initialize model
n_users = len(user_to_idx)
n_tracks = len(track_to_idx)
model = RecommenderModel(n_users, n_tracks)

# Set hyperparameters for Reptile
inner_lr = 0.01  # Inner learning rate
inner_steps = 5  # Inner update steps

# Initialize the Reptile instance
reptile = Reptile(model, inner_lr, inner_steps)

# Training loop
for epoch in range(num_epochs):
    tasks = []
    for _ in range(tasks_per_epoch):
        task_data, task_labels = sample_task(df, user_to_idx, track_to_idx, task_size=task_size)
        if task_data is not None and task_labels is not None:
            tasks.append((task_data, task_labels))
    
    if tasks:
        reptile.train(tasks)
        print(f"Epoch {epoch + 1}/{num_epochs} completed.")

# Function to recommend tracks for a specific user
def recommend_tracks(username, n_recommendations=3):
    user_idx = user_to_idx[username]
    # Get all track indices
    track_indices = torch.tensor(list(track_to_idx.values()))
    # Prepare the user input
    user_input = torch.full((track_indices.size(0),), user_idx)
    # Get predictions
    with torch.no_grad():
        predictions = model(user_input, track_indices).squeeze()
    # Get top n recommendations
    top_indices = torch.argsort(predictions, descending=True)[:n_recommendations]
    recommended_tracks = df.iloc[top_indices.numpy()]
    return recommended_tracks[['Track', 'Artist', 'Album', 'rating']]

# Example of recommending tracks for a user
recommended_tracks = recommend_tracks('Babs_05')
print("\nRecommended Tracks for Babs_05:")
print(recommended_tracks)
# Out:
# Unique artists available:
# 1. Isobel Campbell
# 2. The Coral
# 3. Gidge
# 4. LNZNDRF
# 5. Goat Girl
# 6. Everything Everything
# 7. serpentwithfeet
# 8. Giggs
# 9. The Koreatown Oddity
# 10. Billy Ocean
# 11. Pale Waves
# 12. Khruangbin
# 13. Bill Callahan
# 14. Clean Bandit
# 15. Rod Thomas
# 16. Fela Kuti
# 17. Jellyfish
# 18. The Box Tops
# 19. Rudimental
# 20. Kacey Musgraves
# 21. Florrie
# 22. ROY3LS
# 23. Black M
# 24. Machel Montano
# 25. LÉON
# 26. Nelson Freitas
# 27. Lonely The Brave
# 28. Charlie Sloth
# 29. Karen Harding
# 30. Future Utopia
# 31. Stephen Oaks
# 32. Sonny Fodera
# 33. Röyksopp
# 34. R3hab
# 35. Aluna
# 36. Rat City
# 37. Pink Sweat$
# 38. Elliphant
# 39. Rebecca Black
# 40. Crafty 893
# 41. Anitta
# 42. Maluma
# 43. Imelda May
# 44. Lil Peep
# 45. araabMUZIK
# 46. Gary Bartz
# 47. Gentleman's Dub Club
# 48. The Smashing Pumpkins
# 49. Wu-Tang Clan
# 50. Salt-N-Pepa
# 51. Felt
# 52. Roméo Elvis
# 53. Nick Cave & the Bad Seeds
# 54. Fat Joe
# 55. Dr. Dre
# 56. Cage & Camu
# 57. Postman
# 58. Starflam
# 59. LL Cool J
# 60. Rodríguez
# 61. Mr. Vegas
# 62. Ghostface Killah
# 63. Groundation
# 64. Akhenaton
# 65. Stephen Marley
# 66. Fashawn
# 67. Fantan Mojah
# 68. Chimurenga Renaissance
# 69. Emika
# 70. Sizzla
# 71. The Uncluded
# 72. The Aggrolites
# 73. Alpha 5.20
# 74. FKA twigs
# 75. Jah Cure
# 76. Andrés Cotter
# 77. Stikstof
# 78. Romain Virgo
# 79. Guru
# 80. SOJA
# 81. Daks
# 82. Loyle Carner
# 83. Vicious
# 84. Buraka Som Sistema
# 85. Damian Marley
# 86. Buju Banton
# 87. Flogging Molly
# 88. Alborosie
# 89. DJ Shadow
# 90. Rootman J.
# 91. Brent Faiyaz
# 92. Niko Moon
# 93. Erik Satie
# 94. Jules Massenet
# 95. Johann Sebastian Bach
# 96. George Gershwin
# 97. Edward Elgar
# 98. Sergei Rachmaninoff
# 99. Ludwig van Beethoven
# 100. George Frideric Handel
# 101. Ralph Vaughan Williams
# 102. Fart Man
# 103. The Internet
# 104. Majid Jordan
# 105. Lianne La Havas
# 106. Alina Baraz
# 107. Gramatik
# 108. Sango
# 109. Pascäal
# 110. Anderson .Paak
# 111. SZA
# 112. HONNE
# 113. Movement
# 114. Matt Simons
# 115. Saje
# 116. Jamie Woon
# 117. Thundercat
# 118. FKJ
# 119. Erykah Badu
# 120. Nao
# 121. Chet Faker
# 122. Rhye
# 123. Locked Groove
# 124. Nora Van Elken
# 125. Monkey Safari
# 126. Fort Romeau
# 127. Buddha-Bar
# 128. HoneyDripper
# 129. Bicep
# 130. Sahar Z
# 131. Sultan + Shepard
# 132. Nina Kraviz
# 133. boys be kko
# 134. Fabio Aurea
# 135. Tone Depth
# 136. Andrea Oliva
# 137. Tim Green
# 138. Christian Löffler
# 139. Selena
# 140. will.i.am
# 141. Dawn Richard
# 142. Usher
# 143. Rihanna
# 144. Nielson
# 145. Jessie J
# 146. Little Mix
# 147. Selah Sue
# 148. Eminem
# 149. Charlene
# 150. Selena Gomez
# 151. Volumia!
# 152. Eve
# 153. Katy B
# 154. Live
# 155. Enrique Iglesias
# 156. Amy Winehouse
# 157. Ciara
# 158. Big Sean
# 159. Luis Fonsi
# 160. Fifth Harmony
# 161. Davina Michelle
# 162. Gabriella Cilmi
# 163. Chris Brown
# 164. All Saints
# 165. Kiana Ledé
# 166. Lady Gaga
# 167. Nelly Furtado
# 168. Backstreet Boys
# 169. Demi Lovato
# 170. Dua Lipa
# 171. Michael Jackson
# 172. Delilah
# 173. Jennifer Lopez
# 174. Ella Henderson
# 175. Plan B
# 176. Ariana Grande
# 177. Drake
# 178. DJ Cassidy
# 179. Kane
# 180. Holly Valance
# 181. Labrinth
# 182. Popcaan
# 183. Sevana
# 184. Shenseea
# 185. Frisco Kid
# 186. Jaz Elise
# 187. Koffee
# 188. Bou
# 189. Meph luciano
# 190. The MookMann
# 191. Billie Eilish
# 192. Cosha
# 193. The Roots
# 194. Loxy
# 195. The Vaccines
# 196. Jorja Smith
# 197. Eesah
# 198. Arca
# 199. Mono
# 200. Torii Wolf
# 201. Diverse the Prodigy
# 202. Dexta Daps
# 203. Shaggy
# 204. Burning Spear
# 205. Barrington Levy
# 206. Jigsy King
# 207. Naomi Cowan
# 208. Dre Island
# 209. Elepohant Man
# 210. Jaz Karis
# 211. Lila Iké
# 212. Billy Talent
# 213. Yves Deruyter
# 214. Rotterdam Termination Source
# 215. Eagles of Death Metal
# 216. Caesars
# 217. Alter Ego
# 218. Oxley
# 219. deadmau5
# 220. Maurizzio
# 221. Sean Paul
# 222. M-Beat
# 223. Tiiwtiiw
# 224. Luniz
# 225. Lesley Gore
# 226. Mama's Jasje
# 227. Doemaardave
# 228. Irene Cara
# 229. Mason
# 230. Groove Armada
# 231. N.W.A.
# 232. Henk Wijngaard
# 233. De Marlets
# 234. Goran Bregović
# 235. WC Experience
# 236. Carmen Waterslaeghers
# 237. Faces
# 238. GLASS WATERS
# 239. Zebrahead
# 240. Crystal Castles
# 241. Puri
# 242. Bronski Beat
# 243. DJ Zinc
# 244. Bolle Tito
# 245. Studio Vibe
# 246. America
# 247. Rob De Nijs
# 248. Nik Kershaw
# 249. Huey Lewis & The News
# 250. Brother Culture
# 251. Steve Harley
# 252. Falco
# 253. Hosh
# 254. Alex Mine
# 255. Poldoore
# 256. Petit Biscuit
# 257. Stephane 1993
# 258. Leonard Cohen
# 259. Autechre
# 260. Reinier Zonneveld
# 261. Dusty Kid
# 262. Fleur East
# 263. Jess Glynne
# 264. Freya Ridings
# 265. Lewis Capaldi
# 266. Dagny
# 267. Illenium
# 268. Marshmello
# 269. The Avener
# 270. EDX
# 271. Vinil
# 272. Sigala
# 273. Midnight To Monaco
# 274. Twelve
# 275. Alesso
# 276. Throttle
# 277. MK
# 278. Don Diablo
# 279. The Him
# 280. DubVision
# 281. Loud Luxury
# 282. Kelsy Karter
# 283. Kygo
# 284. Balkan Beat Box
# 285. Young Israelites
# 286. Maxi Priest
# 287. Reggae Roast
# 288. Beenie Man
# 289. Christopher Ellis
# 290. Chronixx
# 291. Liam Bailey
# 292. Busy Signal
# 293. Kiko Bun
# 294. Lila Ike
# 295. Nathan Evans
# 296. Madison Avenue
# 297. Five
# 298. S Club 7
# 299. Britney Spears
# 300. Christopher Tin
# 301. Geoff Knorr
# 302. Simon & Garfunkel
# 303. Roland Rizzo
# 304. The Calling
# 305. Westlife
# 306. Norah Jones
# 307. Sophie Ellis-Bextor
# 308. Nickelback
# 309. Nelly
# 310. Joel Corry
# 311. Topic
# 312. K-Ci & JoJo
# 313. Syd
# 314. Nayana Iz
# 315. Mahalia
# 316. Doja Cat
# 317. TLC
# 318. Summer Walker
# 319. Ramz
# 320. Mos Def
# 321. Hi-Tek
# 322. Lootpack
# 323. J Dilla
# 324. Kanye West
# 325. A Tribe Called Quest
# 326. Kendrick Lamar
# 327. Michael Galasso
# 328. Frank Ocean
# 329. Air
# 330. Bobmo
# 331. James Yuill
# 332. Deyah
# 333. Nuyorican Soul
# 334. Dan Kye
# 335. Nicolas Jaar
# 336. Blanco
# 337. Joey Bada$$
# 338. James Blake
# 339. Don Toliver Remixed
# 340. Shiv
# 341. Pa Salieu
# 342. Fred again..
# 343. Moses Sumney
# 344. Jordan Rakei
# 345. The Pharcyde
# 346. Isaiah Rashad
# 347. The Sabres of Paradise
# 348. Jacques Greene
# 349. TOKiMONSTA
# 350. Burna Boy
# 351. Dave
# 352. Stormzy
# 353. Goody Grace
# 354. Chip
# 355. Gorgon City
# 356. DJ Pioneer
# 357. Foreign Beggars
# 358. Ben Howard
# 359. KIDKODDI
# 360. Jax Jones
# 361. Fredo
# 362. Faouzia
# 363. Bankulli
# 364. sleep protocol
# 365. Mayo
# 366. Tissi
# 367. sound butler
# 368. Sileon
# 369. Sunday Mode
# 370. Hi Hat Henry
# 371. Sam Cooke
# 372. Stevie Wonder
# 373. Barry White
# 374. Harold Melvin & The Blue Notes
# 375. Aretha Franklin
# 376. The Supremes
# 377. Al Green
# 378. The O'Jays
# 379. Marvin Gaye
# 380. Otis Redding
# 381. Bill Withers
# 382. Gladys Knight & The Pips
# 383. The Spinners
# 384. Tavares
# 385. Bee Gees
# 386. Diana Ross
# 387. Rose Royce
# 388. Dionne Warwick
# 389. Penny & the Quarters
# 390. Curtis Mayfield
# 391. Ben E. King
# 392. Simply Red
# 393. Four Tops
# 394. Billy Paul
# 395. Commodores
# 396. The Temptations
# 397. B.B. King
# 398. Ann Sexton
# 399. Samba
# 400. Foo Fighters
# 401. Kylie Minogue
# 402. Holy Now
# 403. Guds Pengar
# 404. Eleven Pond
# 405. Givers
# 406. Das Kabinette
# 407. Oskarova Fobija
# 408. Oppenheimer Analysis
# 409. Parade Ground
# 410. Deux
# 411. Techniques Berlin
# 412. Futurisk
# 413. Kym Amps
# 414. The Tellers
# 415. The Walkmen
# 416. Funeral Suits
# 417. The Cinematics
# 418. NG3
# 419. Radio 4
# 420. Ian Taylor
# 421. Circuit 7
# 422. Degada Saf
# 423. Luxury Stranger
# 424. Medium Medium
# 425. Kuruki
# 426. The Ballad Bombs
# 427. The KVB
# 428. Monie Love
# 429. Clout
# 430. Kirsty MacColl
# 431. The Mighty Wah!
# 432. The Railway Children
# 433. Belly
# 434. Northside
# 435. Depeche Mode
# 436. The Course
# 437. Conditioner Disco Group
# 438. Kitchens of Distinction
# 439. Sandie Shaw
# 440. Vita Bergen
# 441. The Pointer Sisters
# 442. St. Jude the Obscure
# 443. The Ordinary Boys
# 444. Nick Lowe
# 445. Girls At Our Best!
# 446. The Charlatans
# 447. Amanda Mair
# 448. Beige Banquet
# 449. Baio
# 450. Lean Logic
# 451. Always You
# 452. Pylon
# 453. Prince Daddy & The Hyena
# 454. Save Face
# 455. Orla Gartland
# 456. Ashnikko
# 457. Lana Del Rey
# 458. lovelytheband
# 459. Silk City
# 460. 93FEETOFSMOKE
# 461. Griff
# 462. I DONT KNOW HOW BUT THEY FOUND ME
# 463. Royal Blood
# 464. JC Stewart
# 465. Birdy
# 466. Molly Burch
# 467. MOD SUN
# 468. dodie
# 469. familypet
# 470. Shinigami
# 471. ONE OK ROCK
# 472. Calvin Harris
# 473. Silent Siren
# 474. Kairiki Bear
# 475. Tom Walker
# 476. ATEEZ
# 477. Bastille
# 478. Suzi Island
# 479. Shaed
# 480. Neha Kakkar
# 481. George Ezra
# 482. syudou
# 483. BLACKPINK
# 484. Matchbox Twenty
# 485. Fall Out Boy
# 486. Shehnaz Kaur Gill
# 487. Written by Wolves
# 488. YOASOBI
# 489. BACK-ON
# 490. Gesu No Kiwami Otome
# 491. [Alexandros]
# 492. Dreamcatcher
# 493. BLUE ENCOUNT
# 494. Sam Tinnesz
# 495. Panic! at the Disco
# 496. twenty one pilots
# 497. Kenshi Yonezu
# 498. Metr
# 499. Maggie Lindemann
# 500. ZyniC
# 501. Suicide Commando
# 502. Beyond Obsession
# 503. Elegant Machinery
# 504. Red Cell
# 505. Takatsugu Wakabayashi
# 506. Capcom Sound Team / Re-Arranged By Masahiro Aoki
# 507. Tha Trickaz x DJ Kentaro
# 508. Junksista
# 509. Blaqk Audio
# 510. Trevor Something
# 511. Galaxy Hunter
# 512. Second Version
# 513. Tashaki Miyaki
# 514. Balvanera
# 515. Antidote for Annie
# 516. Gorillaz
# 517. Duran Duran
# 518. Kero Kero Bonito
# 519. 100 gecs
# 520. JPEGMAFIA
# 521. Sophie
# 522. Christina Aguilera
# 523. Natasha Bedingfield
# 524. Vanessa Carlton
# 525. Mika
# 526. Taylor Swift
# 527. Sugababes
# 528. Maroon 5
# 529. Lou Bega
# 530. Culture Club
# 531. Mis-Teeq
# 532. ABBA
# 533. "Weird Al" Yankovic
# 534. Candi Staton
# 535. Omi
# 536. Robbie Williams
# 537. Shania Twain
# 538. Justice
# 539. Fergie
# 540. Zara Larsson
# 541. Barry Manilow
# 542. Rick Springfield
# 543. Dead or Alive
# 544. Cher
# 545. Oliver Cheatham
# 546. Rizzle Kicks
# 547. Vengaboys
# 548. Busted
# 549. Roll Deep
# 550. Madonna
# 551. JoJo
# 552. Madcon
# 553. Mary Mary
# 554. Kate Bush
# 555. Aggro Santos
# 556. Beyoncé
# 557. of Montreal
# 558. Panchiko
# 559. Rabbit Junk
# 560. Cecile Believe
# 561. The Dismemberment Plan
# 562. Ella Lee
# 563. Alice Glass
# 564. Cassius
# 565. Origami Angel
# 566. Playboi Carti
# 567. Ween
# 568. Sidney Gish
# 569. Blur
# 570. Neutral Milk Hotel
# 571. Grauzone
# 572. Less Than Jake
# 573. Pavement
# 574. DJ Sabrina The Teenage DJ
# 575. The Bats
# 576. Foals
# 577. Chairlift
# 578. Tkay Maidza
# 579. Logic
# 580. Brother Ali
# 581. Al Bairre
# 582. Hatchie
# 583. Jessie Ware
# 584. Everclear
# 585. G Flip
# 586. Genesis Owusu
# 587. KAYTRANADA
# 588. Flight Facilities
# 589. Bleachers
# 590. Yumi Zouma
# 591. Lola Marsh
# 592. San Cisco
# 593. Thelma Plum
# 594. Dizzy
# 595. Overcoats
# 596. Mallrat
# 597. Ocean Alley
# 598. Spacey Jane
# 599. Tame Impala
# 600. Glass Animals
# 601. Jason Isbell and The 400 Unit
# 602. Sylvan Esso
# 603. Powfu
# 604. St. Lucia
# 605. Small Black
# 606. The New Division
# 607. Geographer
# 608. Wild Nothing
# 609. Teen Daze
# 610. Brothertiger
# 611. CHVRCHES
# 612. Joan
# 613. Phoebe Bridgers
# 614. James Hersey
# 615. Rasmus Faber
# 616. WØØLS
# 617. Erlend Øye
# 618. Billie Marten
# 619. Pinegrove
# 620. All Sons & Daughters
# 621. POLIÇA
# 622. Pedro the Lion
# 623. Phil Collins
# 624. SwuM
# 625. The Undercover Dream Lovers
# 626. Mosaic MSC
# 627. Sunny Day Real Estate
# 628. Steely Dan
# 629. Trey Songz
# 630. Rich Rocka
# 631. The Go! Team
# 632. Carly Rae Jepsen
# 633. Plankeye
# 634. Todd Terje
# 635. Whiskeytown
# 636. Bakermat
# 637. Sasha Sloan
# 638. Owl City
# 639. Diskret
# 640. The Kinks
# 641. Jimmy Eat World
# 642. Madlib
# 643. Silkie
# 644. maudlin of the Well
# 645. 아버지
# 646. Midori Takada
# 647. Bluetile Lounge
# 648. MGMT
# 649. Ulver
# 650. QT
# 651. Loathe
# 652. TR/ST
# 653. Street Soldier
# 654. Soen
# 655. Queens of the Stone Age
# 656. The Brian Jonestown Massacre
# 657. Monsternaut
# 658. Black Space Riders
# 659. Valis
# 660. Core
# 661. Deville
# 662. Vertical
# 663. Fu Manchu
# 664. Thee Oh Sees
# 665. Monstroid
# 666. Los Iracundos
# 667. José Luis Perales
# 668. Ana Gabriel
# 669. Rocío Dúrcal
# 670. Juan Gabriel
# 671. Julio Jaramillo
# 672. House of Harm
# 673. Luis Miguel
# 674. Muslim Magomayev
# 675. Кипелов
# 676. Aria
# 677. Black Eyed Peas
# 678. Nightwish
# 679. Sirenia
# 680. Lacuna Coil
# 681. Within Temptation
# 682. Xandria
# 683. Nemesea
# 684. Eluveitie
# 685. Blackbriar
# 686. After Forever
# 687. The Gathering
# 688. Delain
# 689. Karol G
# 690. Harry Styles
# 691. System of a Down
# 692. Epica
# 693. Cardi B
# 694. The Weeknd
# 695. Katy Perry
# 696. She Wants Revenge
# 697. Slowdive
# 698. Citizen
# 699. La Dispute
# 700. Deftones
# 701. Cocteau Twins
# 702. All That Remains
# 703. Fields of the Nephilim
# 704. This Mortal Coil
# 705. The Cure
# 706. Black Tape for a Blue Girl
# 707. Dead Can Dance
# 708. Siouxsie and the Banshees
# 709. The Sisters of Mercy
# 710. Type O Negative
# 711. Bauhaus
# 712. Diary of Dreams
# 713. Joy Division
# 714. Echo & the Bunnymen
# 715. Twin Tribes
# 716. HIM
# 717. Cradle of Filth
# 718. Sisters of Mercy
# 719. Coil
# 720. True Widow
# 721. Godspeed You! Black Emperor
# 722. Bohren & der Club of Gore
# 723. King Dude
# 724. David Lynch
# 725. Chelsea Wolfe
# 726. The Sound
# 727. Heroin and Your Veins
# 728. Can
# 729. Duster
# 730. Cranes
# 731. Mark Lanegan
# 732. Spell
# 733. A Silver Mt. Zion
# 734. Swans
# 735. Einstürzende Neubauten
# 736. Ludovico Einaudi
# 737. Brambles
# 738. Pencey Sloe
# 739. Romeo Void
# 740. Cloud Nothings
# 741. Les Discrets
# 742. Pulp
# 743. Sneaker Pimps
# 744. Mika Ogawa
# 745. Seatbelts
# 746. Manic Street Preachers
# 747. IDLES
# 748. Fugazi
# 749. PJ Harvey
# 750. Radiohead
# 751. Elastica
# 752. Bladee
# 753. Christian Death
# 754. Hole
# 755. Agent Orange
# 756. Portishead
# 757. Fiona Apple
# 758. Bratmobile
# 759. Alien Sex Fiend
# 760. Have a Nice Life
# 761. The London Suede
# 762. my bloody valentine
# 763. Primal Scream
# 764. Mazzy Star
# 765. Elliott Smith
# 766. Nico
# 767. Angel Olsen
# 768. McAlmont & Butler
# 769. Johnny Marr
# 770. The Afghan Whigs
# 771. Suede
# 772. Elbow
# 773. Reeve Carney
# 774. Eva Noblezada
# 775. André De Shields
# 776. Sherie René Scott
# 777. Sherie Rene Scott
# 778. Norbert Leo Butz
# 779. Chad Kimball
# 780. 'Come From Away' Band
# 781. Ray Charles
# 782. Murray Head
# 783. Ava Max
# 784. Nitzer Ebb
# 785. Martin L. Gore
# 786. Firevision
# 787. Anastacia
# 788. Mighty 44
# 789. Arcade Fire
# 790. Ugly Kid Joe
# 791. Q Lazzarus
# 792. Talking Heads
# 793. Hullu Elämä
# 794. Yö
# 795. Mr. Bungle
# 796. Carpenters
# 797. Public Service Broadcasting
# 798. Fleetwood Mac
# 799. The Romantics
# 800. Dire Straits
# 801. The Beach Boys
# 802. Oingo Boingo
# 803. The Beatles
# 804. Faith No More
# 805. Vize
# 806. Morrissey
# 807. Waxahatchee
# 808. St. Vincent
# 809. Goldfrapp
# 810. Tirzah
# 811. Helena Deland
# 812. MF DOOM
# 813. Suzy
# 814. pH-1
# 815. HA:TFELT
# 816. millic (밀릭) Millic
# 817. ZICO
# 818. Yubin
# 819. MELODYDAY
# 820. 이진아
# 821. nafla
# 822. Kid Milli
# 823. 이바다
# 824. 백예린
# 825. Red Velvet
# 826. Boa
# 827. PER6IX
# 828. April
# 829. 현아
# 830. Bytecon
# 831. 植田真梨恵
# 832. Cold Body Radiation
# 833. Ambersmoke
# 834. Planning for Burial
# 835. Joan of Arc
# 836. Mineral
# 837. Elliott
# 838. Wowod
# 839. Divide and Dissolve
# 840. Wreckless Eric
# 841. Sub Focus
# 842. M|O|O|N
# 843. Ravxn
# 844. Martha
# 845. Audeka
# 846. The Horrors
# 847. The Wedding Present
# 848. Bambara
# 849. Heavenly
# 850. Happydeadmen
# 851. Hum
# 852. Killing Joke
# 853. Simple Minds
# 854. The Soundcarriers
# 855. Sad Lovers & Giants
# 856. Black Flag
# 857. The Gaslight Anthem
# 858. Sweet Trip
# 859. Gilla Band
# 860. The Pains of Being Pure at Heart
# 861. Alberich
# 862. Brighter Death Now
# 863. Atari Teenage Riot
# 864. City Girls
# 865. Nocturnal Emissions
# 866. IRM
# 867. C.C.C.C
# 868. Deathpile
# 869. Merzbow
# 870. Trepaneringsritualen
# 871. Sly & The Family Stone
# 872. Metallica
# 873. Nicki Minaj
# 874. Space
# 875. Coldcut
# 876. Saloli
# 877. Baths
# 878. Mr FijiWiji
# 879. Alix Perez
# 880. Tycho
# 881. VNV Nation
# 882. Lane 8
# 883. t e l e p a t h テレパシー能力者
# 884. London Elektricity
# 885. Icicle
# 886. Moa Pillar
# 887. Lemon Jelly
# 888. Hex
# 889. Avicii
# 890. Shlohmo
# 891. C418
# 892. Daniel Avery
# 893. Jean-Michel Jarre
# 894. Jessy Lanza
# 895. IZZARD
# 896. Little People
# 897. Gold Panda
# 898. Swardy
# 899. Vangelis
# 900. Cosmic Gate
# 901. The Future Sound of London
# 902. Orbital
# 903. The Durutti Column
# 904. The Chemical Brothers
# 905. Better Oblivion Community Center
# 906. Armin van Buuren
# 907. Zedd
# 908. One Direction
# 909. The Wrecks
# 910. WSTR
# 911. V V Brown
# 912. Paramore
# 913. Widowspeak
# 914. Jay Som
# 915. Peyton
# 916. Rina Sawayama
# 917. Masego
# 918. Dent May
# 919. Disclosure
# 920. Grip
# 921. JW Francis
# 922. Arlo Parks
# 923. Young Franco
# 924. Jim-E Stack
# 925. The Birthday Party
# 926. Adam & The Ants
# 927. The Damned
# 928. Solar Flare And Her Trio Of Sheep
# 929. Asphyx
# 930. Amaranthe
# 931. Björk
# 932. Schammasch
# 933. Strident
# 934. Ayreon
# 935. Mariah Carey & Whitney Houston
# 936. Mariah Carey
# 937. Miley Cyrus
# 938. Victoria Monét
# 939. Subp Yao
# 940. Amon Tobin
# 941. Two Fingers
# 942. Darkside
# 943. Machinecode
# 944. Nino Rota
# 945. Banda Ionica
# 946. Rufus Thomas
# 947. Stan Getz
# 948. Drab City
# 949. Pinkshinyultrablast
# 950. Lusine
# 951. JJ DOOM
# 952. Post Animal
# 953. TOPS
# 954. Wondha Mountain
# 955. Tennis
# 956. Deerhoof
# 957. Via App
# 958. Why?
# 959. Redveil
# 960. KNOWER
# 961. Jockstrap
# 962. Minimal Man
# 963. Rezzett
# 964. Mr Twin Sister
# 965. Candy Claws
# 966. Soft Kill
# 967. Grouper
# 968. Nicole Sabouné
# 969. Marie Davidson
# 970. Beach House
# 971. Easter
# 972. Molchat Doma
# 973. White Lies
# 974. Motorama
# 975. Future Islands
# 976. Editors
# 977. Bones
# 978. Powell
# 979. Hali Palombo
# 980. Urban Village
# 981. Kessler
# 982. Dead Space Chamber Music
# 983. Solatipour Reza
# 984. Lars Bröndum
# 985. Martyria
# 986. Mombi Yuleman
# 987. Nachtreich
# 988. katie dey
# 989. Heriot
# 990. Perfume Genius
# 991. U
# 992. Ilya Kaler
# 993. Feed Me To The Waves
# 994. Arcade Player
# 995. Crumb
# 996. Bright Eyes
# 997. The Backseat Lovers
# 998. Alex G
# 999. Silver Jews
# 1000. Yo La Tengo
# 1001. Broadcast
# 1002. The Replacements
# 1003. Jens Lekman
# 1004. Disco Inc.
# 1005. HOMESHAKE
# 1006. M.A.G.S.
# 1007. Days N' Daze
# 1008. Crass
# 1009. The Moldy Peaches
# 1010. bedside kites
# 1011. The Velvet Underground
# 1012. Small Crush
# 1013. Modern Baseball
# 1014. Beat Happening
# 1015. Ramones
# 1016. Belle & Sebastian
# 1017. The Softies
# 1018. Talulah Gosh
# 1019. Tiger Trap
# 1020. Hey Paulette
# 1021. Tortured Soul
# 1022. Claptone
# 1023. CeCe Peniston
# 1024. Junior Jack
# 1025. Armand van Helden
# 1026. Livin' Joy
# 1027. Everything But the Girl
# 1028. Ultra Naté
# 1029. Chris Lake
# 1030. Crystal Waters
# 1031. Duck Sauce
# 1032. Kings Of Tomorrow
# 1033. Rozalla
# 1034. Robin S
# 1035. The Bad Yard Club
# 1036. Róisín Murphy
# 1037. Henrik Schwarz
# 1038. Lou Hayter
# 1039. Charles Aznavour
# 1040. Stromae
# 1041. Serge Gainsbourg
# 1042. Édith Piaf
# 1043. Madeleine Peyroux
# 1044. Charles Trenet
# 1045. Joe Dassin
# 1046. Yves Montand
# 1047. Zaz
# 1048. Françoise Hardy
# 1049. Carla Bruni
# 1050. Kurt Weill
# 1051. Falle Nioke
# 1052. Astronauts, etc.
# 1053. Still Corners
# 1054. Anna Fox Rochinski
# 1055. Jeroen Dirrix
# 1056. Cass McCombs
# 1057. Nation of Language
# 1058. Men I Trust
# 1059. Tune-Yards
# 1060. Myd
# 1061. SMERZ
# 1062. Digitalism
# 1063. Altin Gün
# 1064. JennyLee
# 1065. Neil Frances
# 1066. Balthazar
# 1067. Car Seat Headrest
# 1068. 1 Trait Danger
# 1069. bałtyk
# 1070. American Holly
# 1071. Stef Chura
# 1072. Glaive
# 1073. gupi
# 1074. A. G. Cook
# 1075. fromtheheart
# 1076. Iglooghost
# 1077. GFOTY
# 1078. Alice Gas
# 1079. easyFun
# 1080. Thomston
# 1081. Moth
# 1082. Sabaton
# 1083. Galenskaparna & After Shave
# 1084. Linkin Park
# 1085. KUURO
# 1086. Jauz
# 1087. Lillasyster
# 1088. Skrillex
# 1089. John Williams
# 1090. 4 Non Blondes
# 1091. Teddybears
# 1092. Knife Party
# 1093. Frej Larsson
# 1094. Florence + the Machine
# 1095. The Rembrandts
# 1096. Partiet
# 1097. Lets Be Friends
# 1098. Disturbed
# 1099. Dion Timmer
# 1100. Icon for Hire
# 1101. Jaroslav Beck
# 1102. Loreen
# 1103. Electric Banana band
# 1104. HEALTH
# 1105. Hard Bass School
# 1106. Cults
# 1107. Living Hour
# 1108. Deerhunter
# 1109. Delvon Lamarr Organ Trio
# 1110. Blouse
# 1111. Pure Bathing Culture
# 1112. Sofia Reyes
# 1113. Shakira
# 1114. Anuel AA
# 1115. Rubi Rose
# 1116. Zion & Lennox
# 1117. Wisin & Yandel
# 1118. Eladio Carrion
# 1119. Daddy Yankee
# 1120. Manuel Turizo
# 1121. Sum 41
# 1122. The Red Jumpsuit Apparatus
# 1123. Green Day
# 1124. All Time Low
# 1125. Yellowcard
# 1126. The All-American Rejects
# 1127. Good Charlotte
# 1128. Weezer
# 1129. Simple Plan
# 1130. Ed Sheeran
# 1131. Michelle
# 1132. Evelyn "Champagne" King
# 1133. My Chemical Romance
# 1134. Mike Moonnight
# 1135. J Balvin
# 1136. Winifred Atwell
# 1137. Lele Pons
# 1138. Kevin Roldan
# 1139. Camilo
# 1140. Bad Bunny
# 1141. Marc Cohn
# 1142. Ozuna
# 1143. Christian Nodal
# 1144. Boza
# 1145. Rauw Alejandro
# 1146. Tainy
# 1147. Willy Moon
# 1148. Winston Samuels
# 1149. Violet Hall
# 1150. Winter Aid
# 1151. Vincent Brahn
# 1152. Camila Cabello
# 1153. Lil Tecca
# 1154. DJ Scheme
# 1155. Westside Gunn
# 1156. A$AP Ferg
# 1157. Future
# 1158. Lil Baby
# 1159. Polo G
# 1160. 21 Savage
# 1161. Migos
# 1162. A$AP Rocky
# 1163. A$AP Mob
# 1164. KYLE
# 1165. YG
# 1166. Smokepurpp
# 1167. A Boogie wit da Hoodie
# 1168. Jay Gwuapo
# 1169. Clay "Krucial" Perry III
# 1170. Yung Lean
# 1171. Jonatan Leandoer96
# 1172. Mac Miller
# 1173. Pantera
# 1174. Exodus
# 1175. Saxon
# 1176. Bolt Thrower
# 1177. DC Breaks
# 1178. Morbid Angel
# 1179. Firewind
# 1180. Vremya i Steklo
# 1181. DOROFEEVA
# 1182. The Hardkiss
# 1183. Kazka
# 1184. Favorite
# 1185. Saturday
# 1186. Marina
# 1187. Malía
# 1188. Teyana Taylor
# 1189. Chloe x Halle
# 1190. Saweetie
# 1191. DaBaby
# 1192. Solange
# 1193. Janelle Monáe
# 1194. Aminé
# 1195. Megan Thee Stallion
# 1196. Rico Nasty
# 1197. Kali Uchis
# 1198. Iyla
# 1199. The Jackson 5
# 1200. Nat King Cole
# 1201. Olivia Newton-John
# 1202. ROSALÍA
# 1203. Timbaland
# 1204. Pras, Ol' Dirty Bastard, Mya
# 1205. Toni Braxton
# 1206. Ol' Dirty Bastard
# 1207. JAY-Z
# 1208. Gunna
# 1209. Young Thug
# 1210. Quality Control
# 1211. Gucci Mane
# 1212. Lil Wayne
# 1213. Pop Smoke
# 1214. Vince Staples
# 1215. Dreamville
# 1216. Travis Scott
# 1217. Lil Uzi Vert
# 1218. J. Cole
# 1219. JACKBOYS
# 1220. Rich Gang
# 1221. Babyface Ray
# 1222. Yameii Online
# 1223. Charli XCX
# 1224. ericdoa
# 1225. Cuco
# 1226. Cautious Clay
# 1227. BENEE
# 1228. p4rkr
# 1229. Food House
# 1230. IU
# 1231. Daniel Caesar
# 1232. Danny L Harle
# 1233. Audrey Nuna
# 1234. Grimes
# 1235. Death Grips
# 1236. Clarence Clarity
# 1237. George Clanton
# 1238. Ty Dolla $ign
# 1239. Young Dolph
# 1240. Kid Cudi
# 1241. Jessie Reyez
# 1242. Jack Harlow
# 1243. PARTYNEXTDOOR
# 1244. Kamaiyah
# 1245. Flatbush ZOMBiES
# 1246. Iggy Azalea
# 1247. Ari Lennox
# 1248. Trippie Redd
# 1249. Rayana Jay
# 1250. Ta-ku
# 1251. Lorde
# 1252. Bruno Mars
# 1253. Kehlani
# 1254. Tia Carys
# 1255. Melanie Martinez
# 1256. blink-182
# 1257. Lil' Kim
# 1258. No Doubt
# 1259. Kim Petras
# 1260. The Pussycat Dolls
# 1261. Hannah Montana
# 1262. Ke$ha
# 1263. Kesha
# 1264. The Aquabats!
# 1265. Prince
# 1266. S-hot
# 1267. Odyssey
# 1268. Mtume
# 1269. Chemise
# 1270. Slave
# 1271. D-Train
# 1272. Alphabeat
# 1273. Ida Corr
# 1274. Yeah Yeah Yeahs
# 1275. Steve Angello
# 1276. Alice Deejay
# 1277. Daft Punk
# 1278. Stardust
# 1279. Paul Oakenfold
# 1280. Dave Armstrong
# 1281. Guru Josh Project
# 1282. Shapeshifters
# 1283. Ercola
# 1284. Alicia Keys
# 1285. Sir
# 1286. JID
# 1287. The Notorious B.I.G.
# 1288. Smino
# 1289. Aaliyah
# 1290. Jaden
# 1291. nasaan
# 1292. H.E.R.
# 1293. Jazmine Sullivan
# 1294. JAY-Z & Kanye West
# 1295. Lykke Li
# 1296. Mereba
# 1297. KIDS SEE GHOSTS
# 1298. Tyler, the Creator
# 1299. Raku-Nu
# 1300. Willow
# 1301. RÜFÜS DU SOL
# 1302. Bhaskar
# 1303. Tangerine Dream
# 1304. XTC
# 1305. RÜFÜS
# 1306. The Strokes
# 1307. Starset
# 1308. Arctic Monkeys
# 1309. Waterparks
# 1310. Muse
# 1311. BTS
# 1312. Nujabes
# 1313. bittymacbeth
# 1314. Peach Prc
# 1315. The New Respects
# 1316. Omar Apollo
# 1317. Mrs. Strange
# 1318. TiGERTOWN
# 1319. Empire of the Sun
# 1320. Flo Milli
# 1321. Phony Ppl
# 1322. Two Door Cinema Club
# 1323. CHUNG HA
# 1324. David Guetta
# 1325. LIZ
# 1326. Corpse
# 1327. Pentatonix
# 1328. Geho
# 1329. Machine Gun Kelly
# 1330. Olívia
# 1331. Rico Dalasam
# 1332. MC Soffia
# 1333. Zayn
# 1334. ABRONCA
# 1335. Tasha & Tracie
# 1336. Bruna Liz
# 1337. Shwayze
# 1338. Nabrisa
# 1339. YUNGBLUD
# 1340. Tove Lo
# 1341. The Pretty Reckless
# 1342. Rincon Sapiência
# 1343. Aviva
# 1344. Laysa
# 1345. Tropkillaz
# 1346. FBC
# 1347. Tate McRae
# 1348. Felipe Flip
# 1349. Killa Bi
# 1350. Victor Cronos
# 1351. DuSouto
# 1352. DEAD POET SOCIETY
# 1353. As Baías
# 1354. MC Robs
# 1355. Pabllo Vittar
# 1356. Jova
# 1357. Criolo
# 1358. Linn da Quebrada
# 1359. Duduzzone
# 1360. Years & Years
# 1361. Venvs
# 1362. The Veronicas
# 1363. AMARO
# 1364. Justin Bieber
# 1365. The 1975
# 1366. blackbear
# 1367. GoldLink
# 1368. Trevi Moran
# 1369. Armors
# 1370. Troye Sivan
# 1371. Louis Tomlinson
# 1372. Aidan Alexander
# 1373. Kid Travis
# 1374. Conan Gray
# 1375. Soccer Mommy
# 1376. Yves Tumor
# 1377. Mitski
# 1378. Father John Misty
# 1379. Donnie Trumpet & The Social Experiment
# 1380. Giveon
# 1381. Rex Orange County
# 1382. Chief Keef
# 1383. Ryan Beatty
# 1384. Death Cab for Cutie
# 1385. Keane
# 1386. ギルガメッシュ
# 1387. Blood Orange
# 1388. Cícero
# 1389. Phoenix
# 1390. Doves
# 1391. The Black Keys
# 1392. Cake
# 1393. The Killers
# 1394. Goldspot
# 1395. Stars
# 1396. Kaiser Chiefs
# 1397. Youth Group
# 1398. Rogue Wave
# 1399. LCD Soundsystem
# 1400. Shout Out Louds
# 1401. Kasabian
# 1402. The Subways
# 1403. Matt Pond PA
# 1404. Bell X1
# 1405. The Reindeer Section
# 1406. Aqueduct
# 1407. Modest Mouse
# 1408. Beck
# 1409. Flunk
# 1410. Sufjan Stevens
# 1411. A.C. Newman
# 1412. Pinback
# 1413. Maribou State
# 1414. Daedelus
# 1415. Knxwledge
# 1416. Jitwam
# 1417. Taylor McFerrin
# 1418. Robert Glasper
# 1419. Ras G
# 1420. Butcher Brown
# 1421. Her's
# 1422. Steve Lacy
# 1423. Raveena
# 1424. Hope Tala
# 1425. Greentea Peng
# 1426. Ms. Lauryn Hill
# 1427. Nação Zumbi
# 1428. Don Toliver
# 1429. Seu Jorge
# 1430. Luedji Luna
# 1431. Free Nationals
# 1432. Marcos Valle
# 1433. Yellow Days
# 1434. CLUB KURU
# 1435. Cronicas de Um Babaca
# 1436. Luiz Melodia
# 1437. Aaron May
# 1438. Trinidad Cardona
# 1439. Skinshape
# 1440. MC Hariel
# 1441. Mild Orange
# 1442. Dominic Fike
# 1443. Drugdealer
# 1444. LOVING
# 1445. The Walters
# 1446. Palehound
# 1447. Levitation Room
# 1448. Surf Curse
# 1449. Coin
# 1450. Emotional Oranges
# 1451. Mr Jukes
# 1452. Thyla
# 1453. Brittany Howard
# 1454. Jungle
# 1455. Requiem Inc.
# 1456. DEAN
# 1457. Catfish and the Bottlemen
# 1458. Alabama Shakes
# 1459. Kevin Michael
# 1460. Ezra Collective
# 1461. Snoh Aalegra
# 1462. J Lloyd
# 1463. Vivian Green
# 1464. Sophie Faith
# 1465. Foster the People
# 1466. Fitz and the Tantrums
# 1467. Ravyn Lenae
# 1468. Winnetka Bowling League
# 1469. Angela Muñoz
# 1470. Bad Suns
# 1471. Marian Hill
# 1472. HAIM
# 1473. Denitia and Sene
# 1474. Purity Ring
# 1475. Samira Close
# 1476. Michelle Gurevich
# 1477. BELLSAINT
# 1478. The Blow
# 1479. Jesse
# 1480. Dalida
# 1481. Bigbang
# 1482. Gabby Barrett
# 1483. Tenny
# 1484. The Last Shadow Puppets
# 1485. Alec Benjamin
# 1486. XXXTENTACION
# 1487. Epik High
# 1488. Franz Ferdinand
# 1489. Khalid
# 1490. Coldplay
# 1491. 2NE1
# 1492. Tablo
# 1493. G-Eazy
# 1494. SISTAR
# 1495. NCT 127
# 1496. FIL BO RIVA
# 1497. 5 Seconds of Summer
# 1498. The Neighbourhood
# 1499. Joji
# 1500. Adele
# 1501. P!nk
# 1502. Mag.Lo
# 1503. Winner
# 1504. Post Malone
# 1505. The Irrepressibles
# 1506. Of Monsters and Men
# 1507. Hana
# 1508. Kyle Dixon & Michael Stein
# 1509. Mac DeMarco
# 1510. Eric Jafet
# 1511. Yunk Vino
# 1512. Esteban Tavares
# 1513. KMFDM
# 1514. Sister Machine Gun
# 1515. Crywolf
# 1516. Shygirl
# 1517. LYZZA
# 1518. Amnesia Scanner
# 1519. siouxxie
# 1520. Y1640
# 1521. Crim3s
# 1522. Himera
# 1523. Alice Longyu Gao
# 1524. Eartheater
# 1525. M.I.A.
# 1526. Actress
# 1527. Tommy Cash
# 1528. Kerridge
# 1529. Filmmaker
# 1530. Lucky Daye
# 1531. Tinashe
# 1532. DDG
# 1533. DJ Khaled
# 1534. Lil Eazzyy
# 1535. Miguel
# 1536. Blake Shelton
# 1537. Wale
# 1538. Dej Loaf
# 1539. Jhené Aiko
# 1540. Childish Gambino
# 1541. Eric Bellinger
# 1542. Big Mali
# 1543. S3nsi Molly
# 1544. Celeste
# 1545. BANKS
# 1546. Tricky
# 1547. Kurt Baggaley
# 1548. Banyen Rak Kaen
# 1549. Jonny Olsen
# 1550. Teh Utain Prommin
# 1551. Zander Jazz Trio
# 1552. Dan Evans-Parker
# 1553. Southside Players
# 1554. Hudson Harris & Haim
# 1555. Louis Silva Band
# 1556. Greydon Park Band
# 1557. Eddie Harper
# 1558. Brad Mehldau Trio
# 1559. Enya
# 1560. Explosions in the Sky
# 1561. Sigur Rós
# 1562. M83
# 1563. We the Kings
# 1564. Gregory and the Hawk
# 1565. Youth Lagoon
# 1566. Iron & Wine
# 1567. Israel Kamakawiwo'ole
# 1568. Famy
# 1569. Placebo
# 1570. Pearl Jam
# 1571. The Dø
# 1572. Roxy Music
# 1573. Incubus
# 1574. Dave Gahan
# 1575. Nine Inch Nails
# 1576. Bruce Springsteen
# 1577. The Stooges
# 1578. R.E.M.
# 1579. Blondie
# 1580. Joe Bonamassa
# 1581. Scorpions
# 1582. Elvis Presley
# 1583. Red Hot Chili Peppers
# 1584. Nirvana
# 1585. Oasis
# 1586. The Chameleons
# 1587. The Byrds
# 1588. Bon Jovi
# 1589. The Animals
# 1590. Iggy Pop
# 1591. The Stranglers
# 1592. Garbage
# 1593. Feverkin
# 1594. Amber DeLaRosa
# 1595. Deb Never
# 1596. OTR
# 1597. London Grammar
# 1598. Edamame
# 1599. Oh Wonder
# 1600. Sidewalks and Skeletons
# 1601. Ford.
# 1602. Big Wild
# 1603. Kailee Morgue
# 1604. Au/Ra
# 1605. 4lienetic
# 1606. Charlie Crown
# 1607. Justin Caruso
# 1608. Porter Robinson
# 1609. Nebulae
# 1610. zabawa
# 1611. spencer.
# 1612. ODESZA
# 1613. Chloe Gendrow
# 1614. Annaland
# 1615. Bryce Vine
# 1616. Manila Killa
# 1617. Kllo
# 1618. Emmit Fenn
# 1619. Namara
# 1620. St. South
# 1621. Hop Along
# 1622. Geeta Dutt
# 1623. Shamshad Begum
# 1624. Bob Dylan
# 1625. Doug Martsch
# 1626. Nick Drake
# 1627. The Fall
# 1628. The Sea and Cake
# 1629. Pink Floyd
# 1630. The Halo Benders
# 1631. C.J. & CO.
# 1632. Hues Corporation
# 1633. S'Express
# 1634. McFadden & Whitehead
# 1635. Frankie Valli & the Four Seasons
# 1636. Kraftwerk
# 1637. Jocelyn Brown
# 1638. War
# 1639. Cameo
# 1640. Saint Etienne
# 1641. Showaddywaddy
# 1642. Wayne Smith
# 1643. Hall & Oates
# 1644. Elton John
# 1645. Carly Simon
# 1646. Chic
# 1647. George McCrae
# 1648. Electric Light Orchestra
# 1649. Limmie & The Family Cookin'
# 1650. Tom Tom Club
# 1651. Ian Dury and the Blockheads
# 1652. Combustible Edison
# 1653. The Besnard Lakes
# 1654. I, Ludicrous
# 1655. The Jesus and Mary Chain
# 1656. The Sea Urchins
# 1657. Close Lobsters
# 1658. The Popguns
# 1659. Robyn Hitchcock
# 1660. British India
# 1661. Mikkel Metal
# 1662. Cranker R
# 1663. Kryss Hypnowave
# 1664. Trajano
# 1665. Chronophone
# 1666. Advanced Dreams
# 1667. Valerio Vaudano
# 1668. PPM
# 1669. Gael F.S.
# 1670. S-Tek
# 1671. Nachtaktiv
# 1672. Babe Roots
# 1673. Float & Rütz
# 1674. Palindrom
# 1675. 2OMA
# 1676. Tender H
# 1677. Stanislav Vdovin
# 1678. HEAVENCHORD
# 1679. Deto & Gleam
# 1680. Matthias Springer
# 1681. Mitrica
# 1682. Igor Vlasov
# 1683. Gathaspar
# 1684. Giriu Dvasios
# 1685. Sonic Youth
# 1686. The Shangri-Las
# 1687. St Germain
# 1688. André Jolivet
# 1689. Marcel Landowski
# 1690. Big Black
# 1691. Helvetia
# 1692. Erasure
# 1693. Siouxsie & The Banshees
# 1694. Shellac
# 1695. Julianna Barwick
# 1696. Adrianne Lenker
# 1697. The Aliens
# 1698. Maps
# 1699. Andrew Bird
# 1700. Squirrel Flower
# 1701. Tim Heidecker
# 1702. Beirut
# 1703. Fleet Foxes
# 1704. Dirty Projectors
# 1705. Woods
# 1706. Flume
# 1707. Fink
# 1708. Grizzly Bear
# 1709. Casino Versus Japan
# 1710. Rivulets
# 1711. Julia Holter
# 1712. Olivia Rodrigo
# 1713. Bombay Bicycle Club
# 1714. Metronomy
# 1715. Camera Obscura
# 1716. Belle and Sebastian
# 1717. Hozier
# 1718. Albert Hammond, Jr.
# 1719. The Shins
# 1720. Pete Yorn
# 1721. Patrick Wolf
# 1722. Taken by Trees
# 1723. Laura Marling
# 1724. Alexz Johnson
# 1725. Wolfie
# 1726. Weyes Blood
# 1727. Local Natives
# 1728. Mumford & Sons
# 1729. Sydney Sprague
# 1730. Relient K
# 1731. Lonelyspeck
# 1732. Charlie Hickey
# 1733. Half Waif
# 1734. Eagle-Eye Cherry
# 1735. Motion City Soundtrack
# 1736. Slayyyter
# 1737. Katy Kirby
# 1738. Adult Mom
# 1739. Hand Habits
# 1740. Pompeii
# 1741. Daughter
# 1742. Young Rising Sons
# 1743. Tom Odell
# 1744. The Lumineers
# 1745. alt-J
# 1746. Alfie Templeman
# 1747. Vampire Weekend
# 1748. Gang of Youths
# 1749. Jeremy Young
# 1750. Keaton Henson
# 1751. Jackson Wang
# 1752. Stray Kids
# 1753. Seventeen
# 1754. GOT7
# 1755. GroovyRoom
# 1756. DAY6
# 1757. Yama
# 1758. Agust D
# 1759. Architects
# 1760. The Smiths
# 1761. Dio
# 1762. Black Sabbath
# 1763. Santana
# 1764. Tyga
# 1765. Kenny Wayne Shepherd
# 1766. Sonny Landreth
# 1767. Warren Haynes
# 1768. L7
# 1769. Shmu
# 1770. Fever The Ghost
# 1771. CRX
# 1772. Jlin
# 1773. The Jimi Hendrix Experience
# 1774. Jimi Hendrix
# 1775. David Bowie
# 1776. Sparks
# 1777. Syd Barrett
# 1778. Suburban Lawns
# 1779. The Weather Prophets
# 1780. The White Stripes
# 1781. The Radio Dept.
# 1782. jxdn
# 1783. P9
# 1784. Franz Liszt
# 1785. Gabriel Fauré
# 1786. Maurice Ravel
# 1787. The Jesus Lizard
# 1788. Butthole Surfers
# 1789. School of Seven Bells
# 1790. The Magnetic Fields
# 1791. Subsonic Eye
# 1792. Hazel English
# 1793. Tristen
# 1794. Mini Trees
# 1795. Hater
# 1796. Illuminati Hotties
# 1797. Slumber Party
# 1798. Geowulf
# 1799. The Raveonettes
# 1800. Barrie
# 1801. YOWLER
# 1802. Camera Shy
# 1803. Briana Marela
# 1804. Varsity
# 1805. Anna Burch
# 1806. Westkust
# 1807. Aldous Harding
# 1808. Frankie Cosmos
# 1809. Forth Wanderers
# 1810. Japanese Breakfast
# 1811. All Dogs
# 1812. The Wake
# 1813. Help Stamp Out Loneliness
# 1814. Echo Lake
# 1815. Alvvays
# 1816. The Flatmates
# 1817. Cumulus
# 1818. Alice Boman
# 1819. Beach Fossils
# 1820. Sambassadeur
# 1821. flatsound
# 1822. Bring Me the Horizon
# 1823. Asking Alexandria
# 1824. The Used
# 1825. The Style Council
# 1826. Pierce the Veil
# 1827. Mindless Self Indulgence
# 1828. Our Last Night
# 1829. Aiden
# 1830. Every Time I Die
# 1831. Sleeping with Sirens
# 1832. Earl Sweatshirt
# 1833. Pineapple StormTV
# 1834. Delacruz
# 1835. LUDMILLA
# 1836. Mc Beyonce
# 1837. OneRepublic
# 1838. The Chainsmokers
# 1839. Nothing But Thieves
# 1840. Halsey
# 1841. Dear Gravity
# 1842. Hallowell
# 1843. Holy Hope
# 1844. ReVamp
# 1845. Theatre of Tragedy
# 1846. Therion
# 1847. Elvellon
# 1848. Cellar Darling
# 1849. Amberian Dawn
# 1850. Elori Saxl
# 1851. Midlake
# 1852. Candidate
# 1853. Anna B Savage
# 1854. Niko
# 1855. âme
# 1856. Hello Seahorse!
# 1857. Gustavo Cerati
# 1858. beabadoobee
# 1859. Madame Récamier
# 1860. Mark Ronson
# 1861. Charlotte Gainsbourg
# 1862. Jess Williamson
# 1863. Basement Jaxx
# 1864. Mew
# 1865. The National
# 1866. Alizée
# 1867. Broods
# 1868. The Who
# 1869. New Order
# 1870. Flock of Dimes
# 1871. The Japanese House
# 1872. Pomplamoose
# 1873. Tomás Barreiro
# 1874. Jim Sturgess
# 1875. BØRNS
# 1876. Zoé
# 1877. Cami
# 1878. The Civil Wars
# 1879. Lous and The Yakuza
# 1880. Cat Power
# 1881. The Kooks
# 1882. Ennio Morricone
# 1883. Cavetown
# 1884. Laura Murcia
# 1885. Ace of Base
# 1886. Eric Clapton
# 1887. Enigma
# 1888. Aphex Twin
# 1889. Django Reinhardt
# 1890. Dizzy Gillespie
# 1891. Billie Holiday
# 1892. Ethel Waters
# 1893. Galt Macdermot
# 1894. Glenn Miller
# 1895. The Dave Brubeck Quartet
# 1896. Billy Strayhorn
# 1897. Oscar Peterson
# 1898. Duke Ellington
# 1899. Original Dixieland Jazz Band
# 1900. James Reese Europe
# 1901. Joanna Newsom
# 1902. Waylon Jennings & Willie Nelson
# 1903. Manaka Kataoka
# 1904. Joe Henderson & Alice Coltrane
# 1905. Alice Coltrane
# 1906. Celer
# 1907. Underworld
# 1908. Anna & Elizabeth
# 1909. Not Waving
# 1910. The Legendary Pink Dots
# 1911. Jesse Osborne-Lanthier
# 1912. Bathsheba
# 1913. Koudlam
# 1914. Radar Men from the Moon
# 1915. Clark
# 1916. Nev Cottee
# 1917. Charlie Hilton
# 1918. Martin Denny
# 1919. Scott Walker
# 1920. Jan Jelinek
# 1921. Susumu Yokota
# 1922. she-devils
# 1923. Miharu Koshi & Harry Hosono Jr.
# 1924. Miharu Koshi
# 1925. Flipper's Guitar
# 1926. Towa Tei
# 1927. Fishmans
# 1928. Kahimi Karie
# 1929. Helen Love
# 1930. Signal
# 1931. Piroshka
# 1932. Holy Fawn
# 1933. DIIV
# 1934. Puddle of Mudd
# 1935. The Clash
# 1936. Black Stone Cherry
# 1937. Tom Swoon, Kerano
# 1938. Kings of Leon
# 1939. Red
# 1940. The Cars
# 1941. The Knocks Feat. Sam Nelson Harris
# 1942. Plain White T's
# 1943. AWOLNATION
# 1944. For King And Country
# 1945. Emphatic
# 1946. Mount Farewell
# 1947. Frank Sinatra
# 1948. Sofi Tukker
# 1949. Civil Twilight
# 1950. The Icarus Account
# 1951. Royal Teeth Feat. Tunde Olaniran
# 1952. Kaleo
# 1953. Barnes Courtney
# 1954. Men at Work
# 1955. Canned Heat
# 1956. D.A. Wallach
# 1957. Mozart
# 1958. State of Sound
# 1959. Jess Kent
# 1960. Joseph
# 1961. The Lighthouse & The Whaler
# 1962. James Bay
# 1963. The Record Company
# 1964. Switchfoot
# 1965. Jeff Buckley
# 1966. The Alchemist
# 1967. Lupe Fiasco
# 1968. Alessandro Cortini
# 1969. Silver Mt. Zion
# 1970. Apparat
# 1971. Flying Lotus
# 1972. Oval
# 1973. The Tradewinds
# 1974. The Superfine Dandelion
# 1975. The Ballroom
# 1976. The Elastik Band
# 1977. The Aggregation
# 1978. Morning Glory
# 1979. Federal Duck
# 1980. Chaz Jankel
# 1981. Bill Nelson
# 1982. Patti Smith
# 1983. Cabaret Voltaire
# 1984. Chrome
# 1985. Current 93
# 1986. Mick Karn
# 1987. Trisomie 21
# 1988. Ryan Adams
# 1989. George Michael
# 1990. Alice in Chains
# 1991. Soundgarden
# 1992. Temple of the Dog
# 1993. Hayley Williams
# 1994. The Antlers
# 1995. Portugal. The Man
# 1996. Led Zeppelin
# 1997. Archive
# 1998. Blackfield
# 1999. U2
# 2000. King Gizzard And The Lizard Wizard
# 2001. Built to Spill
# 2002. Alex Ebert
# 2003. Roberta Costantino
# 2004. Quatuor Ébène
# 2005. John Lennon
# 2006. Yoko Ono
# 2007. Animal Collective
# 2008. Cate Le Bon
# 2009. Kevin Morby
# 2010. Bobby
# 2011. Alpha Wann
# 2012. Nekfeu
# 2013. Lesram
# 2014. Marie Laforêt
# 2015. Josephine Foster
# 2016. Cabane
# 2017. Mattiel
# 2018. Fontaines D.C.
# 2019. Amen Dunes
# 2020. Lebanon Hanover
# 2021. Nothing
# 2022. Los Outsaiders
# 2023. Márcio Local
# 2024. Morcheeba
# 2025. DEAD * POP
# 2026. Mystic Braves
# 2027. Palace
# 2028. Thom Yorke
# 2029. Richie Campbell
# 2030. The xx
# 2031. O Terno
# 2032. Neon Dominik
# 2033. Blossoms
# 2034. Natiruts
# 2035. John Mayer
# 2036. Spacemen 3
# 2037. Krakow Philharmonic Chorus
# 2038. Quantic
# 2039. Paul McCartney
# 2040. Vegyn
# 2041. Dennis Wilson
# 2042. Gia Margaret
# 2043. Joachim Cooder
# 2044. Black Country, New Road
# 2045. Other Lives
# 2046. Lanterns on the Lake
# 2047. The Innocence Mission
# 2048. Julian Lage
# 2049. The Meters
# 2050. Ann Peebles
# 2051. Funkadelic
# 2052. Dinah Washington
# 2053. Tito Puente
# 2054. Wes Montgomery
# 2055. Abbey Lincoln
# 2056. The Metronome All-Stars
# 2057. Tommy Flanagan Trio
# 2058. Louis Armstrong
# 2059. John Coltrane
# 2060. The Gil Evans Orchestra
# 2061. Thelonious Monk
# 2062. Sonny Clark
# 2063. Charles Mingus
# 2064. Peggy Lee
# 2065. Blundetto
# 2066. Nina Simone
# 2067. Chris Stapleton
# 2068. CCCP Fedeli Alla Linea
# 2069. Clams Casino & Imogen Heap
# 2070. Atoms for Peace
# 2071. Ella Fitzgerald & Louis Armstrong
# 2072. Jorge Ben
# 2073. The Cinematic Orchestra
# 2074. Cigarettes After Sex
# 2075. Gal Costa
# 2076. Secos e Molhados
# 2077. Szabó Benedek és a Galaxisok
# 2078. Mazzy Star, Hope Sandoval & David Roback
# 2079. City and Colour
# 2080. Luciano Ligabue
# 2081. Lescop
# 2082. CSS
# 2083. Sarah McLachlan
# 2084. Thea Gilmore
# 2085. Jen Cloher & The Endless Sea
# 2086. Tebi Rex
# 2087. Alanis Morissette
# 2088. Gemma dunleavy
# 2089. Ian Brown
# 2090. The Field Mice
# 2091. James
# 2092. Alex Turner
# 2093. The Rolling Stones
# 2094. Ella Fitzgerald
# 2095. Kevin Penkin
# 2096. She & Him
# 2097. Travis
# 2098. Chromatics
# 2099. Shushu
# 2100. Phill Niblock
# 2101. Horațiu Rădulescu
# 2102. Igor Stravinsky
# 2103. This Heat
# 2104. The Murder Capital
# 2105. Arthur Russell
# 2106. T-SQUARE
# 2107. Casiopea
# 2108. 岸正之
# 2109. チューリップ
# 2110. The Black Crowes
# 2111. Megadeth
# 2112. Tribulation
# 2113. Satchel
# 2114. Dead Kennedys
# 2115. Misfits
# 2116. T. Rex
# 2117. The Get Up Kids
# 2118. The County Liners
# 2119. Smog
# 2120. You Man
# 2121. Paul McCartney & Wings
# 2122. Electric Jalaba
# 2123. Chicarica
# 2124. Polocorp
# 2125. Melby
# 2126. SMANDEM.
# 2127. Pahua
# 2128. The Notwist
# 2129. Sibusile Xaba
# 2130. King Gizzard & The Lizard Wizard
# 2131. Xiu Xiu
# 2132. Amor
# 2133. Mindy Meng Wang 王萌
# 2134. The Afro Soul Prophecy
# 2135. 한상원
# 2136. 빛과 소금
# 2137. Madeline Kenney
# 2138. Nagasaki Swim
# 2139. No sé a quién matar
# 2140. Emily A. Sprague
# 2141. Gigi Masin
# 2142. Khotin
# 2143. Hiroshi Yoshimura
# 2144. Domenique Dumont
# 2145. Satoshi & Makoto
# 2146. Green-House
# 2147. Laraaji
# 2148. Suso Saiz
# 2149. Shinichi Atobe
# 2150. Yasuaki Shimizu
# 2151. Ulla
# 2152. Jonny Nash
# 2153. H.Takahashi
# 2154. Pauline Anna Strom
# 2155. FEMM
# 2156. Dokken
# 2157. No Buses
# 2158. Renata Przemyk
# 2159. Front 242
# 2160. Daria Zawiałow
# 2161. Clan of Xymox
# 2162. Aqua
# 2163. GusGus
# 2164. 2raumwohnung
# 2165. Jonathan Shelly
# 2166. The Daysleepers
# 2167. lovesliescrushing
# 2168. Noble Oak
# 2169. Dreams We've Had
# 2170. Sticky Patterns
# 2171. Auscultation
# 2172. Blood Cultures
# 2173. Hammock
# 2174. Lightcraft
# 2175. Glaciaere
# 2176. Skit
# 2177. Megabyte
# 2178. Raener
# 2179. e.vax
# 2180. Lux Ultra
# 2181. Com Truise
# 2182. Donkeyboy
# 2183. Lush
# 2184. Ilya Kuznetsov
# 2185. Henry Green
# 2186. River Tiber
# 2187. Matthew J. Rolin
# 2188. Harry Nilsson
# 2189. Gordon Lightfoot
# 2190. Nana Yamato
# 2191. Sharon Van Etten
# 2192. Karen Dalton
# 2193. Renée Reed
# 2194. Blanck Mass
# 2195. Rachika Nayar
# 2196. Cory Hanson
# 2197. Jessica Pratt
# 2198. The Avalanches
# 2199. Donor Lens
# 2200. Paul Simon
# 2201. Joni Mitchell
# 2202. Julie Byrne
# 2203. Dan Hicks & His Hot Licks
# 2204. Linda Perhacs
# 2205. Missy Elliott
# 2206. The Books
# 2207. Avey Tare's Slasher Flicks
# 2208. Battles
# 2209. Sleater-Kinney
# 2210. 斉藤ノブ
# 2211. Hiram Bullock
# 2212. 鳥山雄司
# 2213. Cesar Mariano & Cia.
# 2214. 森園勝敏
# 2215. Kiyoshi Sugimoto
# 2216. Terumasa Hino Quartet
# 2217. Hiroshi Fukumura & Sadao Watanabe
# 2218. Donald Byrd
# 2219. Prism
# 2220. JIRO INAGAKI & Soul Media
# 2221. Yoshihiro Naruse
# 2222. Jun Miyake
# 2223. Naoya Matsuoka & Hidefumi Toki
# 2224. Akira Wada
# 2225. You & Explosion Band
# 2226. Himiko Kikuchi (菊池ひみこ)
# 2227. Toshiyuki Honda
# 2228. Chikara Ueda & The Power Station
# 2229. Naniwa Express
# 2230. Boy Katindig
# 2231. NORIKI
# 2232. Colgen Band
# 2233. Yoshiaki Masuo
# 2234. 大村憲司
# 2235. Akira Ishikawa & Count Buffalos
# 2236. Toshiyuki Honda & Burning Waves
# 2237. Space Circus
# 2238. Black Fly
# 2239. Otto
# 2240. Cliff Martinez
# 2241. Riz Ortolani
# 2242. Electric Youth
# 2243. Desire
# 2244. Kavinsky
# 2245. Petey
# 2246. Special Interest
# 2247. Mother Mother
# 2248. Salem
# 2249. Zheani
# 2250. Ecco2K
# 2251. Shovels & Rope
# 2252. LustSickPuppy
# 2253. Juno Roome
# 2254. Jónsi
# 2255. Lovedrug
# 2256. Rickolus
# 2257. Eddy Baker
# 2258. Manuel Straube
# 2259. The Blaze
# 2260. Kishi Bashi
# 2261. Il Ghost
# 2262. Snakehips
# 2263. Big Thief
# 2264. Marteria
# 2265. Ethan Fields
# 2266. Poshlaja Molli
# 2267. Sheryl Crow
# 2268. Angèle
# 2269. Wild Rivers
# 2270. Sega Bodega
# 2271. Lake Street Dive
# 2272. Shawn Mendes
# 2273. Swan Lingo
# 2274. Nicholas Britell
# 2275. Pusha T
# 2276. St. Paul & The Broken Bones
# 2277. Mommy Long Legs
# 2278. Hurray For The Riff Raff
# 2279. Best Coast
# 2280. Killer Mike
# 2281. Run the Jewels
# 2282. BROCKHAMPTON
# 2283. Injury Reserve
# 2284. Joey Purp
# 2285. clipping.
# 2286. Czarface
# 2287. THEY.
# 2288. Stephen Barton
# 2289. They Might Be Giants
# 2290. Guided by Voices
# 2291. Marty Robbins
# 2292. White Reaper
# 2293. Plumtree
# 2294. Heatmiser
# 2295. Speedy Ortiz
# 2296. Charly Bliss
# 2297. Liz Phair
# 2298. Whitmer Thomas
# 2299. The Angels of Light
# 2300. Crash Test Dummies
# 2301. Delerium
# 2302. Hardwell
# 2303. Converge
# 2304. Eric B. & Rakim
# 2305. Bone Thugs-N-Harmony
# 2306. Big Daddy Kane
# 2307. Ice Cube
# 2308. Ice-T
# 2309. Eazy-E
# 2310. Souls of Mischief
# 2311. Pete Rock
# 2312. Artifacts
# 2313. GZA
# 2314. Gang Starr
# 2315. Mobb Deep
# 2316. Sir Mix-A-Lot
# 2317. Fugees
# 2318. Nas
# 2319. Scarface
# 2320. Danny Brown
# 2321. Bella Boo
# 2322. Ringo Deathstarr
# 2323. The Brat
# 2324. The Bilinda Butchers
# 2325. Laibach
# 2326. Jorge Elbrecht
# 2327. The Dead Texan
# 2328. Slim Guerilla
# 2329. Johanna's House of Glamour
# 2330. The Boo Radleys
# 2331. The United States of America
# 2332. Rumskib
# 2333. The Death Of Money
# 2334. Technotronic
# 2335. Akaitsuki
# 2336. Sewerslvt
# 2337. The Mamas & the Papas
# 2338. Lycia
# 2339. Crash City Saints
# 2340. Tegan Northwood
# 2341. Ariel Pink
# 2342. Lil B
# 2343. Mario Judah
# 2344. Marissa Nadler
# 2345. Lawrence Rothman
# 2346. Motörhead
# 2347. John Prine
# 2348. 池田典代
# 2349. Ino Hidefumi
# 2350. 松任谷由実
# 2351. S. Kiyotaka & Omega Tribe
# 2352. Akina Nakamori
# 2353. Momoko Kikuchi
# 2354. Akiko Wada
# 2355. Yuri Tanaka
# 2356. 杏里
# 2357. Kingo Hamada
# 2358. Naomi Akimoto
# 2359. Junko Ohashi
# 2360. Taeko Onuki
# 2361. Makoto Matsushita
# 2362. Sadistics
# 2363. MINAKO YOSHIDA
# 2364. 1986 OMEGA TRIBE
# 2365. Jamiroquai
# 2366. 工藤静香
# 2367. Sumiko Yamagata
# 2368. Junko Hirotani
# 2369. Yumi Murata
# 2370. 今井裕
# 2371. Masayoshi Takanaka
# 2372. Piper
# 2373. Akira Terao
# 2374. Yuki Saitou
# 2375. Iyo Matsumoto
# 2376. Yu Hayami
# 2377. Spectrum
# 2378. Kei Ishiguro
# 2379. Hiroshi Sato
# 2380. 尾崎亜美
# 2381. 秋元薫
# 2382. 鄧麗君
# 2383. 岩代太郎
# 2384. 장현
# 2385. 윤승희
# 2386. Banda Calypso
# 2387. MC Kevin O Chris
# 2388. O Playboy
# 2389. Bree Runway
# 2390. MC Loma e as Gêmeas Lacração
# 2391. MC Abalo
# 2392. Biel Xcamoso
# 2393. Santigold
# 2394. Banda Sentimentos
# 2395. Luísa Sonza
# 2396. Shevchenko e Elloco
# 2397. Ms Nina
# 2398. Sebastian Yatra
# 2399. Luísa e Os Alquimistas
# 2400. MC Dricka
# 2401. Jhay Cortez
# 2402. Os Barões Da Pisadinha
# 2403. Maria Gadú
# 2404. Dover
# 2405. Los Bravos
# 2406. Shamir
# 2407. cupcakKe
# 2408. Destiny's Child
# 2409. Mabel
# 2410. Caroline Polachek
# 2411. Kelela
# 2412. Hannah Diamond
# 2413. Stoned Mazes
# 2414. MØ
# 2415. Ross From Friends
# 2416. Shed
# 2417. Azealia Banks
# 2418. Claude Fontaine
# 2419. Adrenalize
# 2420. Bat for Lashes
# 2421. Dougal / Da Tweekaz
# 2422. Da Tweekaz / Code Black / GPF
# 2423. Rooler
# 2424. La Oreja de Van Gogh
# 2425. Bob Marley
# 2426. Nana Mouskouri
# 2427. IAM
# 2428. makla
# 2429. Carla dal Forno
# 2430. Kaoma
# 2431. Glee Cast
# 2432. Dan Black feat. Kelis
# 2433. Computer Magic
# 2434. Da Tweekaz
# 2435. Janie
# 2436. Céline Dion
# 2437. Greazy Puzzy Fuckerz
# 2438. Sickmode
# 2439. Bill Medley
# 2440. Psyko Punkz
# 2441. Major Lazer
# 2442. Jasper Forks
# 2443. Barely Alive
# 2444. Clara Luciani
# 2445. Sato Goldschlag
# 2446. MIZZ BEHAVE
# 2447. Lost Horizons
# 2448. LNY TNZ
# 2449. Jenny Lewis
# 2450. Inquisitive
# 2451. Ganges
# 2452. Funky Craig
# 2453. FRUTi
# 2454. DuckworthSound
# 2455. Dither
# 2456. Mourning A Blkstar
# 2457. Barker
# 2458. Peel Dream Magazine
# 2459. Moses Boyd
# 2460. His Name Is Alive
# 2461. Non Square
# 2462. ZELMA STONE
# 2463. omma
# 2464. Vula Viel
# 2465. Caribou
# 2466. Sky Civilian
# 2467. Rival Consoles
# 2468. Lightning Bug
# 2469. Fools
# 2470. Matt Karmil
# 2471. BOOF
# 2472. Beastie Boys
# 2473. Carne Doce
# 2474. Boy
# 2475. Boogarins
# 2476. Moby
# 2477. Little Dragon
# 2478. Johnny Hooker
# 2479. Djo
# 2480. Vanguart
# 2481. Tiago Iorc
# 2482. Rubel
# 2483. Onze:20
# 2484. 安東ウメ子
# 2485. 東海林修指揮 コロムビア・ミリオン・ポップ管弦楽団
# 2486. DATS
# 2487. Jesse Kivel
# 2488. SPC ECO
# 2489. Peace
# 2490. Beryl Booker
# 2491. The KLF
# 2492. The Justified Ancients of Mu Mu
# 2493. Blind Willie Johnson
# 2494. Mission of Burma
# 2495. Akhlys
# 2496. Oceansize
# 2497. Osi
# 2498. Riverside
# 2499. Katatonia
# 2500. Sandy Denny
# 2501. Marianne Faithfull
# 2502. Sinéad O'Connor
# 2503. Fotheringay
# 2504. Fairport Convention
# 2505. 秋本奈緒美
# 2506. Mico
# 2507. 南沙織
# 2508. The 5.6.7.8's
# 2509. Urszula Dudziak
# 2510. Basia
# 2511. 浜崎あゆみ
# 2512. Rosalia
# 2513. THE CARTERS
# 2514. Faith Evans
# 2515. EXO
# 2516. SHINee (샤이니)
# 2517. Grace Jones
# 2518. Utada Hikaru
# 2519. Paradis
# 2520. Crystal Kay
# 2521. Matsubara Miki
# 2522. Matsutoya Yumi
# 2523. 빈지노 (Beenzino)
# 2524. 프라이머리, 오혁
# 2525. Teyana Taylor, Kehlani
# 2526. 아이유
# 2527. 八神純子
# 2528. Alessandra Mussolini
# 2529. 国分友里恵
# 2530. Prefab Sprout
# 2531. Janet Jackson
# 2532. The Doors
# 2533. Biosphere
# 2534. Rachel's
# 2535. Laura Stevenson
# 2536. Molly Sarlé
# 2537. Mimi Gilbert
# 2538. Damien Jurado
# 2539. Samantha Crain
# 2540. The Slaps
# 2541. Hope Sandoval and The Warm Inventions
# 2542. Bon Iver
# 2543. Sun Kil Moon
# 2544. Black Marble
# 2545. Tears for Fears
# 2546. Deacon Blue
# 2547. Talk Talk
# 2548. Shriekback
# 2549. Propaganda
# 2550. Blancmange
# 2551. It's Immaterial
# 2552. Orchestral Manoeuvres in the Dark
# 2553. The Human League
# 2554. The Cult
# 2555. Frankie Goes to Hollywood
# 2556. Tubeway Army
# 2557. Ultravox
# 2558. Visage
# 2559. Mobiles
# 2560. Poco
# 2561. Seal
# 2562. Four Tet
# 2563. Macross 82-99
# 2564. The Rapture
# 2565. Eurythmics
# 2566. Natalie Imbruglia
# 2567. Roxette
# 2568. Chaka Khan
# 2569. Minnie Riperton
# 2570. Cheryl Lynn
# 2571. Matt Berninger
# 2572. Rubio
# 2573. Shy Boys
# 2574. Interpol
# 2575. Julia Stone
# 2576. The Postal Service
# 2577. The Cribs
# 2578. VENUS BLEEDS
# 2579. ✝✝✝ (Crosses)
# 2580. Lou Phelps
# 2581. Rainbow Kitten Surprise
# 2582. Andy Shauf
# 2583. Monocular Man
# 2584. Brooke Candy
# 2585. Ghostemane
# 2586. Kim Carnes
# 2587. Guy Mitchell
# 2588. Extreme
# 2589. Brides of Destruction
# 2590. Red Simpson
# 2591. Johnny Horton
# 2592. The Brothers Johnson
# 2593. Internet Money
# 2594. The Kid LAROI
# 2595. 6ix9ine
# 2596. Tommy Bolin
# 2597. Michael Angelo Batio
# 2598. Mr. Big
# 2599. White Lion
# 2600. Three Days Grace
# 2601. Breaking Benjamin
# 2602. Hinder
# 2603. Theory of a Deadman
# 2604. Slim Dusty
# 2605. Richard Pryor
# 2606. The 12th Man
# 2607. Rodney Rude
# 2608. The Meatmen
# 2609. The Gothic Archies
# 2610. The Stone Roses
# 2611. Courtney Love
# 2612. Velvet Revolver
# 2613. The ARC Gospel Choir
# 2614. Ed Askew
# 2615. Hackamore Brick
# 2616. Cheryl Dilcher
# 2617. Massacre
# 2618. Michael Brun
# 2619. Devil Sold His Soul
# 2620. Alcest
# 2621. Steven Wilson
# 2622. Bill Wurtz
# 2623. Melt Yourself Down
# 2624. KonstruKt
# 2625. Last Exit
# 2626. Albatre
# 2627. Merkabah
# 2628. Lonker See
# 2629. The Comet Is Coming
# 2630. Fire!
# 2631. Blood Quartet
# 2632. U.S. Maple
# 2633. Cardiacs
# 2634. Lena Raine
# 2635. Emilie Nicolas
# 2636. Joesef
# 2637. superb lyres
# 2638. Izumi Makura
# 2639. Charlotte dos Santos
# 2640. Henry Mancini
# 2641. Girls Names
# 2642. 小久保隆
# 2643. Warmth
# 2644. Lauren Auder
# 2645. Nathy Peluso
# 2646. John Carroll Kirby
# 2647. Alice Dj
# 2648. Television
# 2649. Katie Dey & Lonelyspeck
# 2650. Derrick Harriott
# 2651. Barry Biggs
# 2652. Dennis Brown
# 2653. Devon Russell
# 2654. Don Carlos
# 2655. Michael Kiwanuka
# 2656. Yves Jarvis
# 2657. Ana Roxanne
# 2658. Jyoti
# 2659. Buck Meek
# 2660. Lomelda
# 2661. Snow Patrol
# 2662. Dessa
# 2663. The Cranberries
# 2664. Cem Karaca
# 2665. Steve Earle
# 2666. Yellow Ostrich
# 2667. Amy Annelle
# 2668. Jason Isbell
# 2669. Small Faces
# 2670. The Amazing
# 2671. Son Volt
# 2672. Cody Canada & The Departed
# 2673. The Magic Numbers
# 2674. Doug Seegers
# 2675. Vic Chesnutt, Jack Logan, and Mr. and Mrs. Keneipp
# 2676. Plants and Animals
# 2677. Stone Temple Pilots
# 2678. The Kills
# 2679. The Thermals
# 2680. Dark Dark Dark
# 2681. Valerie June
# 2682. Stevie Ray Vaughan
# 2683. The Pines
# 2684. Laura Cantrell
# 2685. El-P
# 2686. Kula Shaker
# 2687. Sturgill Simpson
# 2688. Colvin & Earle
# 2689. Marshall Crenshaw
# 2690. Van Morrison
# 2691. Ezra Feinberg
# ...
# 22251. Christopher Cross
# 22252. tofubeats
# 22253. OKAMOTO'S
# 22254. mitsume
# 22255. odd foot works
# 22256. Omoinotake
# 22257. DISH//
# 22258. chelmico
# 22259. クボタカイ
# 22260. Kaho Nakamura
# 22261. She Her Her Hers
# 22262. BREIMEN
# 22263. yonawo
# 22264. The Sunnys
# 22265. Dannie May
# 22266. Yusuke Ono
# 22267. Nao Kodama
# 22268. DADARAY
# 22269. TATEANAS
# 22270. Tendre
# 22271. Mizuki Ohira
# 22272. New oil deals
# 22273. DinoJr.
# 22274. illiomote
# 22275. Fyfe
# 22276. Low Roar
# 22277. Odezenne
# 22278. Feu! Chatterton
# 22279. Oklou
# 22280. Girl Ray
# 22281. Saya
# 22282. The Bad Plus
# 22283. Daniel T.
# 22284. Babe Corner
# 22285. Monogem
# 22286. Lee SuHyun
# 22287. Xelli Island
# 22288. 171
# 22289. Tommy Genesis
# 22290. Marcy Playground
# 22291. Rodox
# 22292. Malfunkshun
# 22293. Menswear
# 22294. Social Distortion
# 22295. THE MARIACHIS
# 22296. Urban Dance Squad
# 22297. Love Battery
# 22298. Seven Mary Three
# 22299. Pirâmide Perdida
# 22300. Djonga
# 22301. Filhos da Grávida de Taubaté
# 22302. Sr. Nescau
# 22303. DJ Gabriel Do Borel
# 22304. Josh Levi
# 22305. Santino Le Saint
# 22306. Chasinbens
# 22307. Bionic
# 22308. PriyaTheMystic
# 22309. Almondmilkhunni
# 22310. Um Milkshake Chamado Wanda
# 22311. Igor
# 22312. FP do Trem bala
# 22313. Needle Points
# 22314. The King Khan & BBQ Show
# 22315. Broncho
# 22316. Spendtime Palace
# 22317. The Wytches
# 22318. The Strange Boys
# 22319. Wavves
# 22320. The Shivas
# 22321. sandy pussy
# 22322. The Black Angels
# 22323. Hinds
# 22324. Dumbo Gets Mad
# 22325. The Spyrals
# 22326. Summer Salt
# 22327. The Black Belles
# 22328. King Tuff
# 22329. Tijuana Panthers
# 22330. Gap Dream
# 22331. Dan Luke and the Raid
# 22332. Good Shoes
# 22333. Nio Garcia
# 22334. Paulo Londra
# 22335. dj Luian
# 22336. Nicky Jam
# 22337. Jay Wheeler
# 22338. Metro Station
# 22339. Soulja Boy
# 22340. House Boulevard
# 22341. Jamie Foxx
# 22342. Yves Larock feat. Jaba
# 22343. LMFAO
# 22344. Tina Charles
# 22345. Sanny X
# 22346. Ms Project
# 22347. L'Orchestra Cinematique
# 22348. Chor Filharmonii Narodowej
# 22349. Indigo Girls
# 22350. Noah Guthrie
# 22351. Faith Hill
# 22352. Glen Hansard
# 22353. Tyler Hilton & Bethany Joy Lenz
# 22354. The Davey Brothers
# 22355. Random Soul
# 22356. Musti
# 22357. B-Boy Myhre
# 22358. Kapteinen
# 22359. Henrik Felipe
# 22360. Briskeby
# 22361. Emily Osment
# 22362. Hawthorne Heights
# 22363. Vanessa Rangel
# 22364. Vitroles
# 22365. Carriages
# 22366. TransViolet
# 22367. The Pack A.D.
# 22368. Maurice Williams & The Zodiacs
# 22369. Turbowolf
# 22370. KingJet
# 22371. Pickwick
# 22372. Bruce Channel
# 22373. Johnny Cosmic
# 22374. The Red Arrows
# 22375. Dwight Yoakam
# 22376. Alison Krauss
# 22377. The Reminders
# 22378. breathe.
# 22379. Xperience
# 22380. Ghetto Kumbé
# 22381. Iska Dhaaf
# 22382. Daisies
# 22383. Shade Sheist
# 22384. Murs
# 22385. Non Phixion
# 22386. Styles
# 22387. Screwball
# 22388. Bahamadia
# 22389. Phat Kat
# 22390. Paula Perry
# 22391. Mood
# 22392. Jaz-O & The Immobilarie
# 22393. Saukrates
# 22394. D.I.T.C.
# 22395. Frankie Rose
# 22396. MUNYA
# 22397. Yeah But No
# 22398. THE DIABOLICAL LIBERTIES
# 22399. Holy Wave
# 22400. COUSIN KULA
# 22401. LEADWASH
# 22402. Otzeki
# 22403. Lyrica Anderson
# 22404. Justine Skye
# 22405. Chiiild
# 22406. Ralph Tresvant
# 22407. DJ Chose
# 22408. Fivio Foreign
# 22409. Camp Lo
# 22410. Durand Bernarr
# 22411. DaniLeigh
# 22412. Ann Marie
# 22413. Givēon
# 22414. Styles P
# 22415. Ella Mai
# 22416. Summer Walker, London On Da Track & Chris Brown
# 22417. Larry June & Harry Fraud
# 22418. Dave East
# 22419. Ne-Yo & Jeremih
# 22420. Jeremih & Ty Dolla $ign
# 22421. PRINCESS PRINCESS
# 22422. LINDBERG
# 22423. TRF
# 22424. Sam Brookes
# 22425. Beta Radio
# 22426. Mighty Oaks
# 22427. Sons of the East
# 22428. Blanco White
# 22429. Eddie Berman
# 22430. Adam French
# 22431. Allman Brown
# 22432. Duke Boara
# 22433. Ezequiel Arias
# 22434. Braxton
# 22435. Nox Vahn
# 22436. Focal Sun
# 22437. The Bellamy Brothers
# 22438. Captain & Tennille
# 22439. Anne Murray
# 22440. Lewis Carroll
# 22441. Elizabeth Falconer
# 22442. David Shaw-Parker
# 22443. Beatrix Potter
# 22444. Roald Dahl
# 22445. Eve Karpf
# 22446. Rendezvous At Two
# 22447. Jeff Bernat
# 22448. Kolateral
# 22449. Ivy Sole
# 22450. Eryn Allen Kane
# 22451. Coeli
# 22452. Cid
# 22453. Makaya McCraven
# 22454. Wynton Marsalis
# 22455. Belong
# 22456. Glenn Astro
# 22457. Carsten Jost
# 22458. Indian Wells
# 22459. Barney Mcall
# 22460. Bruce MacCombie
# 22461. Jackson and His Computer Band
# 22462. Prodigal
# 22463. Kindred The Family Soul
# 22464. Kaidi Tatham
# 22465. Mike Will Made-It
# 22466. Juventa
# 22467. Pet Lions
# 22468. Amaury Faye Trio
# 22469. Cootie Williams & his Rug Cutters
# 22470. Barney Bigard & His Jazzopators
# 22471. Rex Stewart & His 52nd St. Stompers
# 22472. Fletcher Henderson
# 22473. Fletcher Henderson & His Orchestra
# 22474. Duke Ellington And His Kentucky Club Orchestra
# 22475. Duke Ellington & His Harlem Footwarmers
# 22476. Mills' Ten Black Berries
# 22477. Duke Ellington & His Washingtonians
# 22478. Clifford Jordan
# 22479. Gene Ammons
# 22480. Dizzy Reece
# 22481. Clifford Brown
# 22482. Dexter Gordon
# 22483. Jackie McLean
# 22484. Pete La Roca
# 22485. Tina Brooks
# 22486. Cliff Jordan
# 22487. Freddie Redd
# 22488. Nat Adderley
# 22489. 鈴木 弘
# 22490. Marvel Boy
# 22491. Simon la letra
# 22492. La propia
# 22493. Hot16
# 22494. Natural Child
# 22495. Widespread Panic
# 22496. Ulrika Spacek
# 22497. Fly Golden Eagle
# 22498. Porno for Pyros
# 22499. The Glands
# 22500. Oliver Wilde
# 22501. Thurston Moore
# 22502. Future Funk Squad
# 22503. The Symposium
# 22504. Inner Wave
# 22505. Asian Dub Foundation
# 22506. Datassette
# 22507. Any Trouble
# 22508. Future Generations
# 22509. Clubfeet
# 22510. Young Galaxy
# 22511. Brad Sucks
# 22512. Janelle Monae
# 22513. Realpeople
# 22514. The Mavericks
# 22515. Van She
# 22516. Psychic Twin
# 22517. Mark Lee Scott
# 22518. Peter Lang
# 22519. Stark Sands with Punch Brothers
# 22520. Incredible Hog
# 22521. Fort Worth Doughboys
# 22522. East River Pipe
# 22523. Dead Moon
# 22524. Souled American
# 22525. King Nawahi's Hawaiians
# 22526. The Donner Party
# 22527. Elmore Williams
# 22528. Jonathan Richman
# 22529. Sam Dees
# 22530. Mason Ruffner
# 22531. Madisonville String Band
# 22532. Keith Tippett
# 22533. Walter And Family
# 22534. Roy Smeck
# 22535. John Fahey as Blind Thomas
# 22536. Willard Grant Conspiracy
# 22537. Captain Beefheart and the Magic Band
# 22538. Larry Williams
# 22539. Ian Hunter
# 22540. The Crooked Jades
# 22541. Ass Ponys
# 22542. Jennifer Gentle
# 22543. Opal
# 22544. The Stumblin Blox
# 22545. Nicki Minaj & Anuel AA
# 22546. Dave Edmunds (The Stray Cats)
# 22547. Split Ends
# 22548. Bonde do Role
# 22549. The Canadian Squires
# 22550. The Be Good Tanyas
# 22551. Marion
# 22552. Northern Uproar
# 22553. Shed Seven
# 22554. Mike Viola
# 22555. Gigolo Aunts
# 22556. Cleaners From Venus
# 22557. The Rulers
# 22558. General Public
# 22559. Ash
# 22560. Christoph Willibald Gluck
# 22561. Regina Carter
# 22562. The Modern Jazz Quartet
# 22563. Eddie Daniels
# 22564. David Hazeltine
# 22565. Cover Kid
# 22566. Loony
# 22567. Art Blakey & The Jazz Messengers
# 22568. Mal Waldron
# 22569. Dave Holland Quartet
# 22570. Geotic
# 22571. Gatas Parlament
# 22572. Strauss Sr.
# 22573. Karen O and the Kids
# 22574. Handel
# 22575. Kikujiro
# 22576. Fresku
# 22577. Alex Kresovich
# 22578. Bill Staines
# 22579. The Hood Internet
# 22580. Rick Zieff
# 22581. Kat Cressida
# 22582. Eternal Tapestry
# 22583. Umberto
# 22584. Life Coach
# 22585. Marisa Anderson
# 22586. Plankton Wat
# 22587. Sarah Louise
# 22588. George Clanton, Nick Hexum
# 22589. Donell Jones
# 22590. Sisqo
# 22591. Covet
# 22592. Title Fight
# 22593. Patti Lasalle
# 22594. *Ancients
# 22595. Anja Schneider
# 22596. Casey Edwards
# 22597. Stone from the Sky
# 22598. Radio Bagdad
# 22599. Už Jsme Doma
# 22600. Melissa Etheridge
# 22601. Joseph Arthur
# 22602. Mike Mains & The Branches
# 22603. Minmae
# 22604. Spoek Mathambo
# 22605. Xperiment
# 22606. Tyagaraja
# 22607. Thee Headcoatees
# 22608. Masked Intruder
# 22609. The Interrupters
# 22610. Carlos Ponce
# 22611. Example
# 22612. Bowland
# 22613. Måneskin
# 22614. Erreway
# 22615. Robosonic
# 22616. Jonathan Johansson
# 22617. Menahan Street Band
# 22618. Dorothy Ashby
# 22619. David Axelrod
# 22620. Powder! Go Away
# 22621. Mekong Airlines
# 22622. Slow Grave
# 22623. When the Sky Sleeps
# 22624. Exxasens
# 22625. hubris.
# 22626. Tesa
# 22627. Distant Dream
# 22628. DJ Didilong
# 22629. Shanique Marie
# 22630. Ani Glass
# 22631. Alemayehu Eshete
# 22632. salami rose joe louis
# 22633. Låpsley
# 22634. Tanerélle
# 22635. phazz
# 22636. CRÁNEO
# 22637. Cupido
# 22638. Soto Asa
# 22639. Pimp Flaco
# 22640. Lindsay Lohan
# 22641. Asobi Seksu
# 22642. Miserable
# 22643. Horse Jumper of Love
# 22644. Mannequin Pussy
# 22645. Tyler Burkhart
# 22646. Salvia Plath
# 22647. John Andrews & The Yawns
# 22648. Cullen Omori
# 22649. The Moore Family Band
# 22650. Carlos Casas
# 22651. Wynonna
# 22652. Nate Trillo
# 22653. SuBoi
# 22654. Bhai Avtar Singh Ragi
# 22655. Taylor Deupree & Marcus Fischer
# 22656. Paul Schütze
# 22657. Bodywash
# 22658. Alex Metric
# 22659. The Galleria
# 22660. White Poppy
# 22661. Elkka
# 22662. Jasmine Infiniti
# 22663. Catch Fire
# 22664. throes
# 22665. The Offering
# 22666. Bury Me Alive
# 22667. The Bottom Line
# 22668. Lost in Life
# 22669. Lena, Felix & die Kita-Kids
# 22670. Deutsche Laichen
# 22671. Delta Sleep
# 22672. Defying Decay
# 22673. Deafhex
# 22674. KitschKrieg
# 22675. Anna Ternheim
# 22676. London Symphony Orchestra
# 22677. Dolce Diablo
# 22678. Chris Jeday
# 22679. Sky Rompiendo
# 22680. Sfera Ebbasta
# 22681. Rainer Brüninghaus
# 22682. Steve Roden
# 22683. Aoki Takamasa
# 22684. Gaetano Partipilo
# 22685. Denys Lable
# 22686. Louis V Vierk
# 22687. Donnacha Dennehy
# 22688. The Fear Ratio
# 22689. Stella Vander
# 22690. Belarisk
# 22691. Wouter Veldhuis
# 22692. Loess
# 22693. Downliners Sekt
# 22694. Mad Season
# 22695. peter zimmermann
# 22696. 1000 Homo DJs
# 22697. Spiritual Beggars
# 22698. James Ferraro
# 22699. Fastgraph
# 22700. The Hacker
# 22701. Japanese Telecom
# 22702. Station Rose
# 22703. Pezet-Noon
# 22704. Renata Lewandowska
# 22705. Les Rythmes Digitales
# 22706. Darwin Deez
# 22707. D.A.R.K.
# 22708. Sr. Chinarro
# 22709. Extremoduro
# 22710. El Último Vecino
# 22711. Cosmen Adelaida
# 22712. Cut Your Hair
# 22713. Crystal Fighters
# 22714. Bran Van 3000
# 22715. Tiny Tim
# 22716. Phil Phillips & The Twilights
# 22717. The Fleetwoods
# 22718. Johnny Tillotson
# 22719. Ricky Nelson
# 22720. Cookiee Kawaii
# 22721. Drakkar Nowhere
# 22722. Jazz Katt Louis Barnsånger
# 22723. Cybotron
# 22724. Merit Hemmingson
# 22725. Lisa Ekdahl
# 22726. Babblarna
# 22727. Mora Träsk
# 22728. Kompisbandet
# 22729. Jujja och Tomas Wieslander
# 22730. Astrid Lindgren
# 22731. Bjorn Palmberg
# 22732. Elever ur Täby Musikklasser
# 22733. Homayra
# 22734. Elodie Lauten
# 22735. Harmonia & Eno '76
# 22736. Grace Mitchell
# 22737. Max Manie
# 22738. Straitjacket Fits
# 22739. Hi-5
# 22740. Chucho
# 22741. Count Basie with His Orchestra
# 22742. Andy Ash
# 22743. Ike Quebec
# 22744. The Night Monitor
# 22745. Furniture
# 22746. Skylar Gudasz
# 22747. Illiterate Light
# 22748. Dale Hollow
# 22749. Vincent Neil Emerson
# 22750. Low Cut Connie
# 22751. Aaron Lee Tasjan
# 22752. Corb Lund
# 22753. Waylon Payne
# 22754. Logan Ledger
# 22755. The Dirty Knobs
# 22756. The Band of Heathens
# 22757. Claire Guerreso
# 22758. Star Anna
# 22759. Les Ya Toupas du Zaire
# 22760. Shooter Jennings
# 22761. BassBoy
# 22762. Anabel Englund
# 22763. Reason
# 22764. Strawberry Guy
# 22765. Tia Gostelow
# 22766. The Ben Shapiro Show
# 22767. The Postmarks
# 22768. Peter Case
# 22769. Ben Harper and The Innocent Criminals
# 22770. Samson & Gert
# 22771. moscoman
# 22772. Cam Cole
# 22773. illuminati hotties
# 22774. Novo Amor
# 22775. Gurrumul
# 22776. Kučka
# 22777. baiuca
# 22778. Roma Radz
# 22779. Steel Banglez
# 22780. Deptford Goth
# 22781. Solid Fever
# 22782. Bell Orchestre
# 22783. Donovan Woods
# 22784. Karen Gwyer
# 22785. Blood Sport
# 22786. Harald Grosskopf
# 22787. Skúli Sverrisson
# 22788. Frankie Reyes
# 22789. Anne Briggs
# 22790. Bridget St. John
# 22791. Issam Hajali
# 22792. Off Course
# 22793. Trace Mountains
# 22794. Golden
# 22795. jerkcurb
# 22796. Ace Enders and a Million Different People
# 22797. Lydia
# 22798. Channing Cope
# 22799. Better Off
# 22800. Hot Mulligan
# 22801. Star You Star Me
# 22802. Morgan Geist
# 22803. Minizza
# 22804. Ricardo Villalobos; Robag Wruhme
# 22805. Skatebård
# 22806. Justus Köhncke
# 22807. Uusi Fantasia
# 22808. Sebastian Maschat
# 22809. Eliza Legzdina
# 22810. Millencolin
# 22811. Broken Records
# 22812. Girls
# 22813. Jimmy Shand
# 22814. Lonnie Smith
# 22815. Dr. Lonnie Smith
# 22816. Kurt Cobain
# 22817. Modern Nature
# 22818. Factory Seconds
# 22819. Timo Lassy
# 22820. Anna Domino
# 22821. edwynn page
# 22822. Roy Montgomery
# 22823. DJ Spooky
# Enter the name of the artist from the list above:  Timo Lassy
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[21], line 61
#      59 # Example of recommending tracks for a user and specific artist
#      60 username = 'Babs_05'
# ---> 61 recommended_tracks = recommend_tracks_by_artist(username, artist_name)
#      62 print(f"\nRecommended Tracks for {username} by {artist_name}:")
#      63 print(recommended_tracks)
#
# Cell In[21], line 51, in recommend_tracks_by_artist(username, artist_name, n_recommendations)
#      49 # Get predictions
#      50 with torch.no_grad():
# ---> 51     predictions = model(user_input, track_indices).squeeze()
#      53 # Get top n recommendations
#      54 top_indices = torch.argsort(predictions, descending=True)[:n_recommendations]
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# Cell In[20], line 18, in RecommenderModel.forward(self, user_ids, book_ids)
#      16 def forward(self, user_ids, book_ids):
#      17     user_embeds = self.user_embedding(user_ids)
# ---> 18     book_embeds = self.book_embedding(book_ids)
#      19     concatenated = torch.cat([user_embeds, book_embeds], dim=-1)
#      20     return self.fc(concatenated)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\sparse.py:164, in Embedding.forward(self, input)
#     163 def forward(self, input: Tensor) -> Tensor:
# --> 164     return F.embedding(
#     165         input, self.weight, self.padding_idx, self.max_norm,
#     166         self.norm_type, self.scale_grad_by_freq, self.sparse)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\functional.py:2267, in embedding(input, weight, padding_idx, max_norm, norm_type, scale_grad_by_freq, sparse)
#    2261     # Note [embedding_renorm set_grad_enabled]
#    2262     # XXX: equivalent to
#    2263     # with torch.no_grad():
#    2264     #   torch.embedding_renorm_
#    2265     # remove once script supports set_grad_enabled
#    2266     _no_grad_embedding_renorm_(weight, input, max_norm, norm_type)
# -> 2267 return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
#
# IndexError: index out of range in self

# %% [markdown]
# ### MOVIE recommendation using REPTILE

# %%
# Load your dataset from a CSV file
df = pd.read_csv("C://Users//91829//Downloads//dataset_zip//dataset//movie.csv")  # Update with your actual file name

# Check the columns in the DataFrame
print("Columns in the DataFrame:", df.columns.tolist())

# Create user and movie index mappings
user_to_idx = {user: idx for idx, user in enumerate(df['userId'].unique())}
movie_to_idx = {movie_id: idx for idx, movie_id in enumerate(df['movieId'].unique())}

# Recommender Model Definition
class RecommenderModel(nn.Module):
    def __init__(self, n_users, n_movies, embedding_dim=8):
        super(RecommenderModel, self).__init__()
        self.user_embedding = nn.Embedding(n_users, embedding_dim)
        self.movie_embedding = nn.Embedding(n_movies, embedding_dim)
        self.fc = nn.Linear(embedding_dim * 2, 1)  # Output layer for rating prediction

    def forward(self, user_ids, movie_ids):
        user_embeds = self.user_embedding(user_ids)
        movie_embeds = self.movie_embedding(movie_ids)
        concatenated = torch.cat([user_embeds, movie_embeds], dim=-1)
        return self.fc(concatenated)

# Reptile Class Definition
class Reptile:
    def __init__(self, model, inner_lr, inner_steps):
        self.model = model
        self.inner_lr = inner_lr
        self.inner_steps = inner_steps

    def inner_update(self, task_data, task_labels):
        user_ids, movie_ids = task_data  # Unpack the task data
        task_model = RecommenderModel(n_users, n_movies)
        task_model.load_state_dict(self.model.state_dict())
        optimizer = optim.SGD(task_model.parameters(), lr=self.inner_lr)

        for _ in range(self.inner_steps):
            predictions = task_model(user_ids, movie_ids)
            loss = nn.MSELoss()(predictions.squeeze(), task_labels.float())  # Adjust to squeeze for loss

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        return task_model

    def train(self, tasks):
        for task_data, task_labels in tasks:
            task_model = self.inner_update(task_data, task_labels)

# Sample task sampling function
def sample_task(df, user_to_idx, movie_to_idx, task_size=5):
    """Sample a task of user and movie pairs."""
    sampled_users = df['userId'].sample(task_size).map(user_to_idx).astype(int)
    sampled_movies = df['movieId'].sample(task_size).map(movie_to_idx).astype(int)

    # Ensure that the sampled indices are valid
    sampled_users = sampled_users[~sampled_users.isna()]
    sampled_movies = sampled_movies[~sampled_movies.isna()]

    # Get labels (ratings)
    labels = df.loc[sampled_users.index, 'rating'].values
    labels = pd.to_numeric(labels, errors='coerce')
    labels = labels[~np.isnan(labels)]

    if len(sampled_users) != len(sampled_movies) or len(sampled_users) != len(labels):
        print("Warning: Mismatch in number of users, movies, and labels!")
        return None, None

    # Convert to PyTorch tensors
    user_tensor = torch.tensor(sampled_users.values, dtype=torch.long)
    movie_tensor = torch.tensor(sampled_movies.values, dtype=torch.long)
    labels_tensor = torch.tensor(labels, dtype=torch.float32)

    return (user_tensor, movie_tensor), labels_tensor

# Hyperparameters
num_epochs = 10
tasks_per_epoch = 5
task_size = 5

# Initialize model
n_users = len(user_to_idx)
n_movies = len(movie_to_idx)
model = RecommenderModel(n_users, n_movies)

# Set hyperparameters for Reptile
inner_lr = 0.01  # Inner learning rate
inner_steps = 5  # Inner update steps

# Initialize the Reptile instance
reptile = Reptile(model, inner_lr, inner_steps)

# Training loop
for epoch in range(num_epochs):
    tasks = []
    for _ in range(tasks_per_epoch):
        task_data, task_labels = sample_task(df, user_to_idx, movie_to_idx, task_size=task_size)
        if task_data is not None and task_labels is not None:
            tasks.append((task_data, task_labels))
    
    if tasks:
        reptile.train(tasks)
        print(f"Epoch {epoch + 1}/{num_epochs} completed.")

# Function to recommend movies for a specific user
# Function to recommend movies for a specific user
def recommend_movies(user_id, n_recommendations=3):
    if user_id not in user_to_idx:
        print(f"User ID {user_id} not found.")
        return pd.DataFrame()  # Return empty DataFrame if user not found

    user_idx = user_to_idx[user_id]
    # Get all movie indices
    movie_indices = torch.tensor(list(movie_to_idx.values()))
    # Prepare the user input
    user_input = torch.full((movie_indices.size(0),), user_idx)
    
    # Get predictions
    with torch.no_grad():
        predictions = model(user_input, movie_indices).squeeze()
    
    # Get top n recommendations
    top_indices = torch.argsort(predictions, descending=True)[:n_recommendations]
    
    # Get recommended movieIds
    recommended_movie_ids = movie_indices[top_indices.numpy()]
    
    # Match movieIds back to the original DataFrame
    recommended_movies = df[df['movieId'].isin(recommended_movie_ids.numpy())]
    
    if recommended_movies.empty:
        print("No recommended movies found for User", user_id)
    return recommended_movies[['movieId', 'rating']]  # Change to desired columns

# Example of recommending movies for a user
recommended_movies = recommend_movies(3)  # Replace with the userId you want to recommend movies for
print("\nRecommended Movies for User 1:")
print(recommended_movies)
# Out:
# Columns in the DataFrame: ['userId', 'movieId', 'rating', 'genres']
# Epoch 1/10 completed.
# Epoch 2/10 completed.
# Epoch 3/10 completed.
# Epoch 4/10 completed.
# Epoch 5/10 completed.
# Epoch 6/10 completed.
# Epoch 7/10 completed.
# Epoch 8/10 completed.
# Epoch 9/10 completed.
# Epoch 10/10 completed.
#
# Recommended Movies for User 1:
#        movieId  rating
# 805       4700     3.0
# 1939      4700     3.0
# 2972      4033     4.0
# 3569      4700     4.0
# 7187      4700     3.0
# 10080     4033     3.0
# 10563     4700     3.0
# 11390     4700     4.0
# 17970     4033     3.0
# 18092     4033     3.0
# 18132     4033     3.0
# 21438     4033     4.0
# 21706     4700     3.0
# 25707     4700     3.0

# %% [markdown]
# ### MOVIE recommendation using NCF

# %%
# Load your dataset from a CSV file
df = pd.read_csv("C://Users//91829//Downloads//dataset_zip//dataset//movie.csv")  # Update with your actual file name

# Check the columns in the DataFrame
print("Columns in the DataFrame:", df.columns.tolist())

# Create user and movie index mappings
user_to_idx = {user: idx for idx, user in enumerate(df['userId'].unique())}
movie_to_idx = {movie_id: idx for idx, movie_id in enumerate(df['movieId'].unique())}

# Neural Collaborative Filtering Model Definition
class NCFModel(nn.Module):
    def __init__(self, n_users, n_movies, embedding_dim=8, hidden_layers=[64, 32, 16, 8]):
        super(NCFModel, self).__init__()
        self.user_embedding = nn.Embedding(n_users, embedding_dim)
        self.movie_embedding = nn.Embedding(n_movies, embedding_dim)
        
        # Define a feed-forward neural network
        layers = []
        input_dim = embedding_dim * 2
        for output_dim in hidden_layers:
            layers.append(nn.Linear(input_dim, output_dim))
            layers.append(nn.ReLU())
            input_dim = output_dim
        layers.append(nn.Linear(input_dim, 1))  # Final output layer for rating prediction
        self.fc_layers = nn.Sequential(*layers)

    def forward(self, user_ids, movie_ids):
        user_embeds = self.user_embedding(user_ids)
        movie_embeds = self.movie_embedding(movie_ids)
        concatenated = torch.cat([user_embeds, movie_embeds], dim=-1)
        return self.fc_layers(concatenated)

# Training the NCF Model
def train_ncf_model(model, df, user_to_idx, movie_to_idx, num_epochs=10, lr=0.001, batch_size=32):
    # Define optimizer and loss function
    optimizer = optim.Adam(model.parameters(), lr=lr)
    criterion = nn.MSELoss()

    # Convert data into torch tensors
    user_ids = torch.tensor(df['userId'].map(user_to_idx).values, dtype=torch.long)
    movie_ids = torch.tensor(df['movieId'].map(movie_to_idx).values, dtype=torch.long)
    ratings = torch.tensor(df['rating'].values, dtype=torch.float32)

    # Training loop
    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0
        for i in range(0, len(user_ids), batch_size):
            user_batch = user_ids[i:i+batch_size]
            movie_batch = movie_ids[i:i+batch_size]
            ratings_batch = ratings[i:i+batch_size]

            # Forward pass
            predictions = model(user_batch, movie_batch).squeeze()
            loss = criterion(predictions, ratings_batch)

            # Backward pass and optimization
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            epoch_loss += loss.item()
        
        avg_loss = epoch_loss / (len(user_ids) // batch_size)
        print(f"Epoch {epoch + 1}/{num_epochs}, Loss: {avg_loss:.4f}")

# Initialize model
n_users = len(user_to_idx)
n_movies = len(movie_to_idx)
embedding_dim = 8
hidden_layers = [64, 32, 16, 8]  # Define the layers for the NCF model
model = NCFModel(n_users, n_movies, embedding_dim=embedding_dim, hidden_layers=hidden_layers)

# Train the NCF model
train_ncf_model(model, df, user_to_idx, movie_to_idx, num_epochs=10, lr=0.001, batch_size=32)

# Function to recommend movies for a specific user using the trained NCF model
def recommend_movies_ncf(user_id, model, n_recommendations=3):
    if user_id not in user_to_idx:
        print(f"User ID {user_id} not found.")
        return pd.DataFrame()  # Return empty DataFrame if user not found

    user_idx = user_to_idx[user_id]
    # Get all movie indices
    movie_indices = torch.tensor(list(movie_to_idx.values()))
    # Prepare the user input
    user_input = torch.full((movie_indices.size(0),), user_idx)
    
    # Get predictions
    model.eval()
    with torch.no_grad():
        predictions = model(user_input, movie_indices).squeeze()
    
    # Get top n recommendations
    top_indices = torch.argsort(predictions, descending=True)[:n_recommendations]
    
    # Get recommended movieIds
    recommended_movie_ids = movie_indices[top_indices.numpy()]
    
    # Match movieIds back to the original DataFrame
    recommended_movies = df[df['movieId'].isin(recommended_movie_ids.numpy())]
    
    if recommended_movies.empty:
        print("No recommended movies found for User", user_id)
    return recommended_movies[['movieId', 'rating']]  # Change to desired columns

# Example of recommending movies for a user
recommended_movies_ncf = recommend_movies_ncf(3, model)  # Replace with the userId you want to recommend movies for
print("\nRecommended Movies for User 1:")
print(recommended_movies_ncf)
# Out:
# Columns in the DataFrame: ['userId', 'movieId', 'rating', 'genres']
# Epoch 1/10, Loss: 2.3078
# Epoch 2/10, Loss: 1.2557
# Epoch 3/10, Loss: 1.1494
# Epoch 4/10, Loss: 1.0875
# Epoch 5/10, Loss: 1.0339
# Epoch 6/10, Loss: 0.9833
# Epoch 7/10, Loss: 0.9354
# Epoch 8/10, Loss: 0.8934
# Epoch 9/10, Loss: 0.8554
# Epoch 10/10, Loss: 0.8226
#
# Recommended Movies for User 1:
#        movieId  rating
# 181        266     5.0
# 840        266     5.0
# 1522       266     5.0
# 2575       266     5.0
# 3184       266     3.0
# 3232       266     4.0
# 3302       266     1.0
# 3394       266     4.0
# 4647      2186     3.5
# 5180       266     4.0
# 6159       266     4.0
# 6382       266     4.0
# 6679      2186     5.0
# 7693       266     4.0
# 9191       266     1.0
# 9665       266     3.5
# 10376      266     3.5
# 12065     2186     3.0
# 12490     2186     3.0
# 14421      266     3.0
# 15503      266     4.0
# 18479      266     4.0
# 18709     2186     4.0
# 19960      266     5.0
# 22031      266     5.0
# 22406      266     2.0
# 22611     2186     3.5
# 22910      266     3.0
# 23086     2186     5.0
# 23531      266     3.0
# 25267      266     3.0
# 26329     2186     4.0

# %% [markdown]
# ### MUSIC recommendation using NCF

# %%
# Load your dataset
df = pd.read_csv("C://Users//91829//Downloads//dataset_zip//dataset//Last.fm_data.csv")

# Create user and track index mappings
user_to_idx = {user: idx for idx, user in enumerate(df['Username'].unique())}
track_to_idx = {track: idx for idx, track in enumerate(df['Track'].unique())}

# Define Neural Collaborative Filtering Model
class NCFModel(nn.Module):
    def __init__(self, n_users, n_tracks, embedding_dim=16, hidden_dims=[64, 32, 16]):
        super(NCFModel, self).__init__()
        # Embeddings for users and tracks
        self.user_embedding = nn.Embedding(n_users, embedding_dim)
        self.track_embedding = nn.Embedding(n_tracks, embedding_dim)

        # Define fully connected layers
        self.fc_layers = nn.Sequential(
            nn.Linear(embedding_dim * 2, hidden_dims[0]),
            nn.ReLU(),
            nn.Linear(hidden_dims[0], hidden_dims[1]),
            nn.ReLU(),
            nn.Linear(hidden_dims[1], hidden_dims[2]),
            nn.ReLU()
        )
        
        # Final layer to output a single rating prediction
        self.output_layer = nn.Linear(hidden_dims[2], 1)

    def forward(self, user_ids, track_ids):
        user_embeds = self.user_embedding(user_ids)
        track_embeds = self.track_embedding(track_ids)
        # Concatenate user and track embeddings
        x = torch.cat([user_embeds, track_embeds], dim=-1)
        # Pass through fully connected layers
        x = self.fc_layers(x)
        return self.output_layer(x).squeeze()  # Output single rating prediction

# Sample task sampling function
def sample_task(df, user_to_idx, track_to_idx, task_size=5):
    """Sample a task of user and track pairs."""
    sampled_users = df['Username'].sample(task_size).map(user_to_idx).astype(int)
    sampled_tracks = df['Track'].sample(task_size).map(track_to_idx).astype(int)

    # Ensure that the sampled indices are valid
    sampled_users = sampled_users[~sampled_users.isna()]
    sampled_tracks = sampled_tracks[~sampled_tracks.isna()]

    # Get labels
    labels = df.loc[sampled_users.index, 'rating'].values
    labels = pd.to_numeric(labels, errors='coerce')
    labels = labels[~np.isnan(labels)]

    if len(sampled_users) != len(sampled_tracks) or len(sampled_users) != len(labels):
        print("Warning: Mismatch in number of users, tracks, and labels!")
        return None, None  # Or handle the size mismatch according to your logic

    # Convert to PyTorch tensors
    user_tensor = torch.tensor(sampled_users.values, dtype=torch.long)
    track_tensor = torch.tensor(sampled_tracks.values, dtype=torch.long)
    labels_tensor = torch.tensor(labels, dtype=torch.float32)

    return (user_tensor, track_tensor), labels_tensor

# Hyperparameters
embedding_dim = 16
num_epochs = 10
tasks_per_epoch = 5
task_size = 5

# Initialize model
n_users = len(user_to_idx)
n_tracks = len(track_to_idx)
model = NCFModel(n_users, n_tracks, embedding_dim=embedding_dim)

# Optimizer and loss function
optimizer = optim.Adam(model.parameters(), lr=0.001)
loss_function = nn.MSELoss()

# Training loop
for epoch in range(num_epochs):
    total_loss = 0
    for _ in range(tasks_per_epoch):
        task_data, task_labels = sample_task(df, user_to_idx, track_to_idx, task_size=task_size)
        if task_data is None or task_labels is None:
            continue
        
        user_ids, track_ids = task_data
        optimizer.zero_grad()
        
        # Forward pass
        predictions = model(user_ids, track_ids)
        loss = loss_function(predictions, task_labels)
        
        # Backward pass and optimization
        loss.backward()
        optimizer.step()
        
        total_loss += loss.item()
    
    avg_loss = total_loss / tasks_per_epoch
    print(f"Epoch {epoch + 1}/{num_epochs}, Average Loss: {avg_loss:.4f}")

# Function to recommend tracks for a specific user
def recommend_tracks(username, n_recommendations=3):
    user_idx = user_to_idx[username]
    # Get all track indices
    track_indices = torch.tensor(list(track_to_idx.values()))
    # Prepare the user input
    user_input = torch.full((track_indices.size(0),), user_idx, dtype=torch.long)
    
    # Get predictions
    with torch.no_grad():
        predictions = model(user_input, track_indices).squeeze()
    
    # Get top n recommendations
    top_indices = torch.argsort(predictions, descending=True)[:n_recommendations]
    recommended_track_ids = [list(track_to_idx.keys())[i] for i in top_indices]
    
    # Filter recommended tracks from DataFrame
    recommended_tracks = df[df['Track'].isin(recommended_track_ids)]
    return recommended_tracks[['Track', 'Artist', 'Album', 'rating']]

# Example of recommending tracks for a user
recommended_tracks = recommend_tracks('Babs_05')
print("\nRecommended Tracks for Babs_05:")
print(recommended_tracks)
# Out:
# Epoch 1/10, Average Loss: 10.8480
# Epoch 2/10, Average Loss: 14.0929
# Epoch 3/10, Average Loss: 12.3185
# Epoch 4/10, Average Loss: 13.1272
# Epoch 5/10, Average Loss: 12.0197
# Epoch 6/10, Average Loss: 9.2109
# Epoch 7/10, Average Loss: 11.7861
# Epoch 8/10, Average Loss: 11.9006
# Epoch 9/10, Average Loss: 12.4079
# Epoch 10/10, Average Loss: 10.9385
#
# Recommended Tracks for Babs_05:
#                                                 Track             Artist  \
# 16564   Please, Please, Please Let Me Get What I Want         The Smiths
# 131273  Please, Please, Please Let Me Get What I Want         The Smiths
# 142691                          Citizen of the Planet  Alanis Morissette
# 143058                                The Perfect One             16volt
#
#                                    Album  rating
# 16564                  Louder Than Bombs     4.0
# 131273                 Louder Than Bombs     3.0
# 142691  Flavors Of Entanglement (Deluxe)     3.0
# 143058                The Negative Space     4.0

# %% [markdown]
# ### BOOK recommendation using NCF

# %%
# Load your dataset from a CSV file
df = pd.read_csv('book.csv')  # Replace with your actual file name

# Create user and book index mappings
user_to_idx = {user: idx for idx, user in enumerate(df['userId'].unique())}
book_to_idx = {book: idx for idx, book in enumerate(df['bookID'].unique())}

# NCF Model Definition
class NCFModel(nn.Module):
    def __init__(self, n_users, n_books, embedding_dim=8, hidden_dim=16):
        super(NCFModel, self).__init__()
        # Embeddings for GMF and MLP
        self.user_embedding_gmf = nn.Embedding(n_users, embedding_dim)
        self.book_embedding_gmf = nn.Embedding(n_books, embedding_dim)
        
        self.user_embedding_mlp = nn.Embedding(n_users, embedding_dim)
        self.book_embedding_mlp = nn.Embedding(n_books, embedding_dim)

        # MLP layers
        self.mlp = nn.Sequential(
            nn.Linear(embedding_dim * 2, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim // 2),
            nn.ReLU()
        )

        # Final layer
        self.fc = nn.Linear(embedding_dim + hidden_dim // 2, 1)

    def forward(self, user_ids, book_ids):
        # GMF pathway
        user_embeds_gmf = self.user_embedding_gmf(user_ids)
        book_embeds_gmf = self.book_embedding_gmf(book_ids)
        gmf_output = user_embeds_gmf * book_embeds_gmf

        # MLP pathway
        user_embeds_mlp = self.user_embedding_mlp(user_ids)
        book_embeds_mlp = self.book_embedding_mlp(book_ids)
        concatenated = torch.cat([user_embeds_mlp, book_embeds_mlp], dim=-1)
        mlp_output = self.mlp(concatenated)

        # Concatenate GMF and MLP outputs
        final_output = torch.cat([gmf_output, mlp_output], dim=-1)
        return self.fc(final_output)

# Reptile Class Definition
class NCF:
    def __init__(self, model, inner_lr, inner_steps):
        self.model = model
        self.inner_lr = inner_lr
        self.inner_steps = inner_steps

    def inner_update(self, task_data, task_labels):
        user_ids, book_ids = task_data
        task_model = NCFModel(n_users, n_books)  # Initialize a fresh task model
        task_model.load_state_dict(self.model.state_dict())  # Copy weights
        optimizer = optim.SGD(task_model.parameters(), lr=self.inner_lr)

        for _ in range(self.inner_steps):
            predictions = task_model(user_ids, book_ids)
            loss = nn.MSELoss()(predictions.squeeze(), task_labels.float())
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        return task_model

    def train(self, tasks):
        for task_data, task_labels in tasks:
            task_model = self.inner_update(task_data, task_labels)
            # Meta-update can be implemented here if needed

# Task sampling function
def sample_task(df, user_to_idx, book_to_idx, task_size=5):
    sampled_users = df['userId'].sample(task_size).map(user_to_idx).astype(int)
    sampled_books = df['bookID'].sample(task_size).map(book_to_idx).dropna().astype(int)
    
    if len(sampled_users) != len(sampled_books):
        print("Warning: Mismatch in number of users and books!")
        return None, None

    labels = df.loc[sampled_books.index, 'average_rating'].values
    labels = pd.to_numeric(labels, errors='coerce')
    labels = labels[~np.isnan(labels)]

    user_tensor = torch.tensor(sampled_users.values, dtype=torch.long)
    book_tensor = torch.tensor(sampled_books.values, dtype=torch.long)
    labels_tensor = torch.tensor(labels, dtype=torch.float32)

    return (user_tensor, book_tensor), labels_tensor

# Hyperparameters
num_epochs = 10
tasks_per_epoch = 5
task_size = 5

# Initialize model
n_users = len(user_to_idx)
n_books = len(book_to_idx)
model = NCFModel(n_users, n_books)

# Set hyperparameters for Reptile
inner_lr = 0.01
inner_steps = 5

# Initialize the Reptile instance
ncf_mod = NCF(model, inner_lr, inner_steps)

# Training loop
for epoch in range(num_epochs):
    tasks = []
    for _ in range(tasks_per_epoch):
        task_data, task_labels = sample_task(df, user_to_idx, book_to_idx, task_size=task_size)
        if task_data is not None:
            tasks.append((task_data, task_labels))
    
    ncf_mod.train(tasks)
    print(f"Epoch {epoch + 1}/{num_epochs} completed.")

# Function to recommend books for a specific user
def recommend_books(user_id, n_recommendations=3):
    user_idx = user_to_idx[user_id]
    book_indices = torch.tensor(list(book_to_idx.values()))
    user_input = torch.full((book_indices.size(0),), user_idx, dtype=torch.long)
    
    with torch.no_grad():
        predictions = model(user_input, book_indices).squeeze()
    top_indices = torch.argsort(predictions, descending=True)[:n_recommendations]
    recommended_books = df.iloc[top_indices.numpy()]
    return recommended_books[['bookID', 'title', 'average_rating']]

# Example of recommending books for userId 1
recommended_books = recommend_books(1)
print("\nRecommended Books for User 1:")
print(recommended_books)
# Out:
# Epoch 1/10 completed.
# Epoch 2/10 completed.
# Epoch 3/10 completed.
# Epoch 4/10 completed.
# Epoch 5/10 completed.
# Epoch 6/10 completed.
# Epoch 7/10 completed.
# Epoch 8/10 completed.
# Epoch 9/10 completed.
# Epoch 10/10 completed.
#
# Recommended Books for User 1:
#        bookID                              title average_rating
# 10325   41814                          I. Asimov            4.2
# 7552    28977  The Littles and the Lost Children           3.76
# 9593    38238                          Australia           4.07
